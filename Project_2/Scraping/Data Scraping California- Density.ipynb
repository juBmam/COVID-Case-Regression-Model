# %%
from bs4 import BeautifulSoup
import requests
import csv
from IPython.core.display import display, HTML

# %%
url = 'http://www.usa.com/rank/california-state--land-area--county-rank.htm'

response = requests.get(url)

response.status_code

soup = BeautifulSoup(response.text, "lxml")
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <title>
#    California Land Area County Rank
#   </title>
#   <meta content="California Land Area County Rank" name="description"/>
#   <script src="rank-js.php" type="text/javascript">
#   </script>
#   <script src="search-form.js" type="text/javascript">
#   </script>
#   <link href="http://www.usa.com/rank/california-state--land-area--county-rank.htm" rel="canonical"/>
#   <link href="/g.css" rel="stylesheet" type="text/css"/>
#   <script src="/js/common.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div id="h">
#    <div id="hinlogo">
#     <a href="/">
#      <img alt="USA.com" height="46" src="/img/USA.png" width="193"/>
#     </a>
#    </div>
#    <div class="topsearchc">
#     <div class="topsearchhead">
#      Local Data Search
#     </div>
#     <div class="search_div">
#      <table>
#       <form action="/locations.php" method="get" name="tsm">
#        <tr>
#         <td>
#          <input name="Submit" onclick="return tyhOnSubmit();" style="width:1px;height:1px;color:#fff;padding:0px;" type="submit" value="Submit"/>
#          <input autocomplete="off" name="q" onblur="searchinputprocess(0);" onfocus="searchinputprocess(1);" type="text" value="Search State, County, City, Zip Code, or Area Code"/>
#         </td>
#         <td>
#          <a href="#" onclick="document.tsm.submit();">
#           <div class="navsearch">
#           </div>
#          </a>
#         </td>
#        </tr>
#       </form>
#      </table>
#     </div>
#     <div class="tyhshadow" id="tyhshadow">
#      <div class="tyhoutput" id="tyhoutput">
#      </div>
#     </div>
#     <script>
#      tyhInit();
#     </script>
#    </div>
#   </div>
#   <div>
#   </div>
#   <div id="mo">
#    <div id="m">
#     <div id="hcontent">
#      <div class="small">
#       <a href="/">
#        USA.com
#       </a>
#       /
#       <a href="/rank/">
#        Ranks
#       </a>
#       /
#       <a href="california-state--land-area--county-rank.htm">
#        California Land Area County Rank
#       </a>
#      </div>
#      <h1>
#       California Land Area County Rank
#      </h1>
#      <p>
#       A total of 58 results found.
#       <span id="highlightOnTheTop">
#       </span>
#       <span id="showonmaptext">
#        <b>
#         <a href="#" onclick="loadFullMap();gObj('showonmaptext').style.display='none';return false;">
#          Show Results on Map
#         </a>
#        </b>
#       </span>
#       .
#      </p>
#      <div id="mapwrapper" style="display:none;">
#       <div id="mapoutput">
#       </div>
#       <div id="map_canvas2" style="height: 500px;">
#       </div>
#      </div>
#      <table width="648">
#       <tr valign="bottom">
#        <td width="48">
#         <b>
#          Rank
#         </b>
#        </td>
#        <td width="150">
#         <b>
#          <a href="#" onclick="rsf('sb','ASC');">
#           Land Area ▼
#          </a>
#         </b>
#        </td>
#        <td width="450">
#         <b>
#          County / Population
#         </b>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         1.
#        </td>
#        <td>
#         20,056.92 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-san-bernardino">
#          San Bernardino, CA
#         </a>
#         / 2,078,586
#        </td>
#       </tr>
#       <tr>
#        <td>
#         2.
#        </td>
#        <td>
#         10,180.87 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-inyo">
#          Inyo, CA
#         </a>
#         / 18,439
#        </td>
#       </tr>
#       <tr>
#        <td>
#         3.
#        </td>
#        <td>
#         8,131.91 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-kern">
#          Kern, CA
#         </a>
#         / 857,730
#        </td>
#       </tr>
#       <tr>
#        <td>
#         4.
#        </td>
#        <td>
#         7,206.47 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-riverside">
#          Riverside, CA
#         </a>
#         / 2,266,899
#        </td>
#       </tr>
#       <tr>
#        <td>
#         5.
#        </td>
#        <td>
#         6,277.88 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-siskiyou">
#          Siskiyou, CA
#         </a>
#         / 44,261
#        </td>
#       </tr>
#       <tr>
#        <td>
#         6.
#        </td>
#        <td>
#         5,957.99 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-fresno">
#          Fresno, CA
#         </a>
#         / 948,844
#        </td>
#       </tr>
#       <tr>
#        <td>
#         7.
#        </td>
#        <td>
#         4,824.21 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-tulare">
#          Tulare, CA
#         </a>
#         / 451,108
#        </td>
#       </tr>
#       <tr>
#        <td>
#         8.
#        </td>
#        <td>
#         4,541.18 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-lassen">
#          Lassen, CA
#         </a>
#         / 33,356
#        </td>
#       </tr>
#       <tr>
#        <td>
#         9.
#        </td>
#        <td>
#         4,206.63 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-san-diego">
#          San Diego, CA
#         </a>
#         / 3,183,143
#        </td>
#       </tr>
#       <tr>
#        <td>
#         10.
#        </td>
#        <td>
#         4,176.60 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-imperial">
#          Imperial, CA
#         </a>
#         / 177,026
#        </td>
#       </tr>
#       <tr>
#        <td>
#         11.
#        </td>
#        <td>
#         4,057.88 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-los-angeles">
#          Los Angeles, CA
#         </a>
#         / 9,974,203
#        </td>
#       </tr>
#       <tr>
#        <td>
#         12.
#        </td>
#        <td>
#         3,917.77 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-modoc">
#          Modoc, CA
#         </a>
#         / 9,335
#        </td>
#       </tr>
#       <tr>
#        <td>
#         13.
#        </td>
#        <td>
#         3,775.40 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-shasta">
#          Shasta, CA
#         </a>
#         / 178,520
#        </td>
#       </tr>
#       <tr>
#        <td>
#         14.
#        </td>
#        <td>
#         3,567.98 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-humboldt">
#          Humboldt, CA
#         </a>
#         / 134,876
#        </td>
#       </tr>
#       <tr>
#        <td>
#         15.
#        </td>
#        <td>
#         3,506.34 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-mendocino">
#          Mendocino, CA
#         </a>
#         / 87,612
#        </td>
#       </tr>
#       <tr>
#        <td>
#         16.
#        </td>
#        <td>
#         3,298.56 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-san-luis-obispo">
#          San Luis Obispo, CA
#         </a>
#         / 274,184
#        </td>
#       </tr>
#       <tr>
#        <td>
#         17.
#        </td>
#        <td>
#         3,280.59 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-monterey">
#          Monterey, CA
#         </a>
#         / 424,927
#        </td>
#       </tr>
#       <tr>
#        <td>
#         18.
#        </td>
#        <td>
#         3,179.25 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-trinity">
#          Trinity, CA
#         </a>
#         / 13,515
#        </td>
#       </tr>
#       <tr>
#        <td>
#         19.
#        </td>
#        <td>
#         3,048.98 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-mono">
#          Mono, CA
#         </a>
#         / 14,193
#        </td>
#       </tr>
#       <tr>
#        <td>
#         20.
#        </td>
#        <td>
#         2,949.71 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-tehama">
#          Tehama, CA
#         </a>
#         / 63,284
#        </td>
#       </tr>
#       <tr>
#        <td>
#         21.
#        </td>
#        <td>
#         2,735.08 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-santa-barbara">
#          Santa Barbara, CA
#         </a>
#         / 431,555
#        </td>
#       </tr>
#       <tr>
#        <td>
#         22.
#        </td>
#        <td>
#         2,553.04 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-plumas">
#          Plumas, CA
#         </a>
#         / 19,286
#        </td>
#       </tr>
#       <tr>
#        <td>
#         23.
#        </td>
#        <td>
#         2,220.88 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-tuolumne">
#          Tuolumne, CA
#         </a>
#         / 54,347
#        </td>
#       </tr>
#       <tr>
#        <td>
#         24.
#        </td>
#        <td>
#         2,137.07 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-madera">
#          Madera, CA
#         </a>
#         / 152,452
#        </td>
#       </tr>
#       <tr>
#        <td>
#         25.
#        </td>
#        <td>
#         1,934.97 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-merced">
#          Merced, CA
#         </a>
#         / 261,609
#        </td>
#       </tr>
#       <tr>
#        <td>
#         26.
#        </td>
#        <td>
#         1,843.13 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-ventura">
#          Ventura, CA
#         </a>
#         / 835,790
#        </td>
#       </tr>
#       <tr>
#        <td>
#         27.
#        </td>
#        <td>
#         1,707.88 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-el-dorado">
#          El Dorado, CA
#         </a>
#         / 181,465
#        </td>
#       </tr>
#       <tr>
#        <td>
#         28.
#        </td>
#        <td>
#         1,636.46 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-butte">
#          Butte, CA
#         </a>
#         / 221,578
#        </td>
#       </tr>
#       <tr>
#        <td>
#         29.
#        </td>
#        <td>
#         1,575.85 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-sonoma">
#          Sonoma, CA
#         </a>
#         / 491,790
#        </td>
#       </tr>
#       <tr>
#        <td>
#         30.
#        </td>
#        <td>
#         1,494.83 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-stanislaus">
#          Stanislaus, CA
#         </a>
#         / 522,794
#        </td>
#       </tr>
#       <tr>
#        <td>
#         31.
#        </td>
#        <td>
#         1,448.82 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-mariposa">
#          Mariposa, CA
#         </a>
#         / 17,946
#        </td>
#       </tr>
#       <tr>
#        <td>
#         32.
#        </td>
#        <td>
#         1,407.01 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-placer">
#          Placer, CA
#         </a>
#         / 361,518
#        </td>
#       </tr>
#       <tr>
#        <td>
#         33.
#        </td>
#        <td>
#         1,391.32 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-san-joaquin">
#          San Joaquin, CA
#         </a>
#         / 701,050
#        </td>
#       </tr>
#       <tr>
#        <td>
#         34.
#        </td>
#        <td>
#         1,389.42 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-kings">
#          Kings, CA
#         </a>
#         / 151,390
#        </td>
#       </tr>
#       <tr>
#        <td>
#         35.
#        </td>
#        <td>
#         1,388.71 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-san-benito">
#          San Benito, CA
#         </a>
#         / 56,888
#        </td>
#       </tr>
#       <tr>
#        <td>
#         36.
#        </td>
#        <td>
#         1,313.95 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-glenn">
#          Glenn, CA
#         </a>
#         / 28,019
#        </td>
#       </tr>
#       <tr>
#        <td>
#         37.
#        </td>
#        <td>
#         1,290.10 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-santa-clara">
#          Santa Clara, CA
#         </a>
#         / 1,841,569
#        </td>
#       </tr>
#       <tr>
#        <td>
#         38.
#        </td>
#        <td>
#         1,256.46 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-lake">
#          Lake, CA
#         </a>
#         / 64,209
#        </td>
#       </tr>
#       <tr>
#        <td>
#         39.
#        </td>
#        <td>
#         1,150.73 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-colusa">
#          Colusa, CA
#         </a>
#         / 21,424
#        </td>
#       </tr>
#       <tr>
#        <td>
#         40.
#        </td>
#        <td>
#         1,020.01 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-calaveras">
#          Calaveras, CA
#         </a>
#         / 44,921
#        </td>
#       </tr>
#       <tr>
#        <td>
#         41.
#        </td>
#        <td>
#         1,014.69 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-yolo">
#          Yolo, CA
#         </a>
#         / 204,162
#        </td>
#       </tr>
#       <tr>
#        <td>
#         42.
#        </td>
#        <td>
#         1,006.37 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-del-norte">
#          Del Norte, CA
#         </a>
#         / 28,066
#        </td>
#       </tr>
#       <tr>
#        <td>
#         43.
#        </td>
#        <td>
#         964.64 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-sacramento">
#          Sacramento, CA
#         </a>
#         / 1,450,277
#        </td>
#       </tr>
#       <tr>
#        <td>
#         44.
#        </td>
#        <td>
#         957.77 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-nevada">
#          Nevada, CA
#         </a>
#         / 98,606
#        </td>
#       </tr>
#       <tr>
#        <td>
#         45.
#        </td>
#        <td>
#         953.21 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-sierra">
#          Sierra, CA
#         </a>
#         / 3,019
#        </td>
#       </tr>
#       <tr>
#        <td>
#         46.
#        </td>
#        <td>
#         821.76 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-solano">
#          Solano, CA
#         </a>
#         / 421,624
#        </td>
#       </tr>
#       <tr>
#        <td>
#         47.
#        </td>
#        <td>
#         790.57 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-orange">
#          Orange, CA
#         </a>
#         / 3,086,331
#        </td>
#       </tr>
#       <tr>
#        <td>
#         48.
#        </td>
#        <td>
#         748.36 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-napa">
#          Napa, CA
#         </a>
#         / 139,253
#        </td>
#       </tr>
#       <tr>
#        <td>
#         49.
#        </td>
#        <td>
#         739.02 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-alameda">
#          Alameda, CA
#         </a>
#         / 1,559,308
#        </td>
#       </tr>
#       <tr>
#        <td>
#         50.
#        </td>
#        <td>
#         738.33 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-alpine">
#          Alpine, CA
#         </a>
#         / 1,202
#        </td>
#       </tr>
#       <tr>
#        <td>
#         51.
#        </td>
#        <td>
#         715.94 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-contra-costa">
#          Contra Costa, CA
#         </a>
#         / 1,081,232
#        </td>
#       </tr>
#       <tr>
#        <td>
#         52.
#        </td>
#        <td>
#         631.84 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-yuba">
#          Yuba, CA
#         </a>
#         / 73,059
#        </td>
#       </tr>
#       <tr>
#        <td>
#         53.
#        </td>
#        <td>
#         602.41 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-sutter">
#          Sutter, CA
#         </a>
#         / 95,067
#        </td>
#       </tr>
#       <tr>
#        <td>
#         54.
#        </td>
#        <td>
#         594.58 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-amador">
#          Amador, CA
#         </a>
#         / 37,159
#        </td>
#       </tr>
#       <tr>
#        <td>
#         55.
#        </td>
#        <td>
#         520.31 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-marin">
#          Marin, CA
#         </a>
#         / 256,802
#        </td>
#       </tr>
#       <tr>
#        <td>
#         56.
#        </td>
#        <td>
#         448.41 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-san-mateo">
#          San Mateo, CA
#         </a>
#         / 739,837
#        </td>
#       </tr>
#       <tr>
#        <td>
#         57.
#        </td>
#        <td>
#         445.17 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-santa-cruz">
#          Santa Cruz, CA
#         </a>
#         / 267,203
#        </td>
#       </tr>
#       <tr>
#        <td>
#         58.
#        </td>
#        <td>
#         46.87 sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ca-san-francisco">
#          San Francisco, CA
#         </a>
#         / 829,072
#        </td>
#       </tr>
#      </table>
#      <p>
#       Please note that we only rank locations with 'Land Area' data. The rank above might not be a complete list. Locations without 'Land Area' data are not listed.
#      </p>
#      <script src="http://maps.google.com/maps/api/js?sensor=false" type="text/javascript">
#      </script>
#      <script>
#       var infowindow;
# var map;
# var showDataFact = 0.2;
# var markers=[];
# var curDataTLat = 0;
# var curDataBLat = 0;
# var curDataLLng = 0;
# var curDataRLng = 0;
# var reboundmap = 1;
#
# var allPlaces = [];
# var placestr = "1|34.8572198|-116.181196|<b># 1.</b><br><a href='r.php?i=30-ca-san-bernardino' target='_blank'>San Bernardino, CA / 2,078,586</a><br>20,056.92 sq mi||2|36.561977|-117.403926|<b># 2.</b><br><a href='r.php?i=30-ca-inyo' target='_blank'>Inyo, CA / 18,439</a><br>10,180.87 sq mi||3|35.3466288|-118.729506|<b># 3.</b><br><a href='r.php?i=30-ca-kern' target='_blank'>Kern, CA / 857,730</a><br>8,131.91 sq mi||4|33.7298275|-116.002238|<b># 4.</b><br><a href='r.php?i=30-ca-riverside' target='_blank'>Riverside, CA / 2,266,899</a><br>7,206.47 sq mi||5|41.5879861|-122.533286|<b># 5.</b><br><a href='r.php?i=30-ca-siskiyou' target='_blank'>Siskiyou, CA / 44,261</a><br>6,277.88 sq mi||6|36.7610058|-119.655019|<b># 6.</b><br><a href='r.php?i=30-ca-fresno' target='_blank'>Fresno, CA / 948,844</a><br>5,957.99 sq mi||7|36.2304529|-118.780542|<b># 7.</b><br><a href='r.php?i=30-ca-tulare' target='_blank'>Tulare, CA / 451,108</a><br>4,824.21 sq mi||8|40.7210889|-120.629931|<b># 8.</b><br><a href='r.php?i=30-ca-lassen' target='_blank'>Lassen, CA / 33,356</a><br>4,541.18 sq mi||9|33.0236041|-116.776117|<b># 9.</b><br><a href='r.php?i=30-ca-san-diego' target='_blank'>San Diego, CA / 3,183,143</a><br>4,206.63 sq mi||10|33.0408155|-115.355394|<b># 10.</b><br><a href='r.php?i=30-ca-imperial' target='_blank'>Imperial, CA / 177,026</a><br>4,176.60 sq mi||11|34.1963983|-118.261861|<b># 11.</b><br><a href='r.php?i=30-ca-los-angeles' target='_blank'>Los Angeles, CA / 9,974,203</a><br>4,057.88 sq mi||12|41.5929185|-120.71837|<b># 12.</b><br><a href='r.php?i=30-ca-modoc' target='_blank'>Modoc, CA / 9,335</a><br>3,917.77 sq mi||13|40.7605215|-122.043549|<b># 13.</b><br><a href='r.php?i=30-ca-shasta' target='_blank'>Shasta, CA / 178,520</a><br>3,775.40 sq mi||14|40.7066731|-123.925818|<b># 14.</b><br><a href='r.php?i=30-ca-humboldt' target='_blank'>Humboldt, CA / 134,876</a><br>3,567.98 sq mi||15|39.4323876|-123.442881|<b># 15.</b><br><a href='r.php?i=30-ca-mendocino' target='_blank'>Mendocino, CA / 87,612</a><br>3,506.34 sq mi||16|35.3852268|-120.44754|<b># 16.</b><br><a href='r.php?i=30-ca-san-luis-obispo' target='_blank'>San Luis Obispo, CA / 274,184</a><br>3,298.56 sq mi||17|36.240107|-121.315573|<b># 17.</b><br><a href='r.php?i=30-ca-monterey' target='_blank'>Monterey, CA / 424,927</a><br>3,280.59 sq mi||18|40.6477241|-123.114404|<b># 18.</b><br><a href='r.php?i=30-ca-trinity' target='_blank'>Trinity, CA / 13,515</a><br>3,179.25 sq mi||19|37.9158363|-118.875166|<b># 19.</b><br><a href='r.php?i=30-ca-mono' target='_blank'>Mono, CA / 14,193</a><br>3,048.98 sq mi||20|40.1261561|-122.232275|<b># 20.</b><br><a href='r.php?i=30-ca-tehama' target='_blank'>Tehama, CA / 63,284</a><br>2,949.71 sq mi||21|34.5373784|-120.038485|<b># 21.</b><br><a href='r.php?i=30-ca-santa-barbara' target='_blank'>Santa Barbara, CA / 431,555</a><br>2,735.08 sq mi||22|39.9951699|-120.829515|<b># 22.</b><br><a href='r.php?i=30-ca-plumas' target='_blank'>Plumas, CA / 19,286</a><br>2,553.04 sq mi||23|38.021451|-119.964708|<b># 23.</b><br><a href='r.php?i=30-ca-tuolumne' target='_blank'>Tuolumne, CA / 54,347</a><br>2,220.88 sq mi||24|37.2100387|-119.749851|<b># 24.</b><br><a href='r.php?i=30-ca-madera' target='_blank'>Madera, CA / 152,452</a><br>2,137.07 sq mi||25|37.1948063|-120.722801|<b># 25.</b><br><a href='r.php?i=30-ca-merced' target='_blank'>Merced, CA / 261,609</a><br>1,934.97 sq mi||26|34.3587415|-119.133143|<b># 26.</b><br><a href='r.php?i=30-ca-ventura' target='_blank'>Ventura, CA / 835,790</a><br>1,843.13 sq mi||27|38.785532|-120.534398|<b># 27.</b><br><a href='r.php?i=30-ca-el-dorado' target='_blank'>El Dorado, CA / 181,465</a><br>1,707.88 sq mi||28|39.6659588|-121.601918|<b># 28.</b><br><a href='r.php?i=30-ca-butte' target='_blank'>Butte, CA / 221,578</a><br>1,636.46 sq mi||29|38.532574|-122.945194|<b># 29.</b><br><a href='r.php?i=30-ca-sonoma' target='_blank'>Sonoma, CA / 491,790</a><br>1,575.85 sq mi||30|37.5623842|-121.002655|<b># 30.</b><br><a href='r.php?i=30-c ...
# var places=placestr.split("||");
# for (var i = 0; i < places.length; i++) {
# 	if ((""+places[i]).length>0){
# 		allPlaces.push(places[i].split("|"));
# 	}
# }
#
# function plotMarkers(curDataTLatin, curDataBLatin, curDataLLngin, curDataRLngin){
# 	var placeToUse = [];
# 	var foundCounter=0;
# 	for (var i = 0; i < allPlaces.length; i++) {
# 		if ((allPlaces[i][1]>curDataBLatin)&&(allPlaces[i][1]<curDataTLatin)&&(allPlaces[i][2]>curDataLLngin)&&(allPlaces[i][2]<curDataRLngin)){
# 			placeToUse.push(allPlaces[i]);
# 			foundCounter++;
# 			if (foundCounter>150){
# 				foundCounter=-1;
# 				break;
# 			}
# 		}
# 	}
#
# 	if (placeToUse.length>0){
# 		var bounds = new google.maps.LatLngBounds ();
# 		for (var i = 0; i < placeToUse.length; i++) {
# 			var oneplace = placeToUse[i];
# 			var latLng = new google.maps.LatLng(parseFloat(oneplace[1]), parseFloat(oneplace[2]));
# 			bounds.extend(latLng);
# 			var iconCmp = parseInt(oneplace[0]);
# 			if (iconCmp>99) iconCmp = 0;
# 			var marker = new google.maps.Marker({
# 				position: latLng,
# 				map: map,
# 				title: oneplace[0],
# 				icon: new google.maps.MarkerImage(
# 					'/img/n.png',
# 					new google.maps.Size(21, 22),
# 					new google.maps.Point((31*iconCmp), 0)
# 				)
# 			});
#
# 			contInfo = oneplace[3];
# 			(function(i, marker, contInfo) {
# 				google.maps.event.addListener(marker, 'click', function() {
# 					if (!infowindow) {
# 						infowindow = new google.maps.InfoWindow();
# 					}
# 					infowindow.setContent(contInfo);
# 					infowindow.open(map, marker);
# 				});
# 			})(i, marker, contInfo);
# 			markers.push(marker);
# 		}
# 		if (reboundmap==1){
# 			reboundmap=-1;
# 			map.fitBounds(bounds);
# 		}
# 	}
# 	if (foundCounter>0){
# 		document.getElementById("mapoutput").innerHTML = "Full Results. Zoom in to refine. Click icon to show name.";
# 	}else{
# 		document.getElementById("mapoutput").innerHTML = "<font color='Red'>Partial Results</font>. Zoom in to see more. Click icon to show name.";
# 	}
# }
#
# function showOnMap(map, doReload){
# 	var zoom = map.getZoom();
# 	var bounds = map.getBounds();
# 	var southWest = bounds.getSouthWest();
# 	var northEast = bounds.getNorthEast();
#
# 	var latSpan = northEast.lat() - southWest.lat();
# 	var lngSpan = northEast.lng() - southWest.lng();
# 	if (lngSpan<0) lngSpan = lngSpan + 360;
# 	var thisTLat = northEast.lat();
# 	var thisBLat = southWest.lat();
# 	var thisLLng = southWest.lng();
# 	var thisRLng = northEast.lng();
#
# 	if ((doReload==1)||(thisTLat>curDataTLat)||(thisBLat<curDataBLat)||(thisLLng<curDataLLng)||(thisRLng>curDataRLng)){
# 		curDataTLat = northEast.lat() + latSpan*showDataFact;
# 		curDataBLat = southWest.lat() - latSpan*showDataFact;
# 		curDataLLng = southWest.lng() - lngSpan*showDataFact;
# 		curDataRLng = northEast.lng() + lngSpan*showDataFact;
# 		if (reboundmap==-1){
# 			reboundmap = 0;
# 		}else{
# 			clearMarkers();
# 			plotMarkers(curDataTLat, curDataBLat, curDataLLng, curDataRLng);
# 		}
# 	}
# }
# function loadFullMap(){
# 	gObj("mapwrapper").style.display = 'block';
# 	var options = {
# 		zoom: 3,
# 		center: new google.maps.LatLng(37.148573, -119.540651),
# 		scrollwheel: false,
# 		mapTypeId: google.maps.MapTypeId.ROADMAP
# 	};
# 	map = new google.maps.Map(document.getElementById('map_canvas2'), options);
# 	google.maps.event.addListener(map, 'zoom_changed', function() {
# 		showOnMap(map, 1);
# 	});
# 	google.maps.event.addListener(map, 'bounds_changed', function() {
# 		showOnMap(map, 0);
# 	});
# }
# function clearMarkers() {
# 	if (markers) {
# 		for (i in markers) {
# 			markers[i].setMap(null);
# 		}
# 	}
# 	markers=[];
# }
#      </script>
#      <form action="california-state--land-area--county-rank.htm" method="get" name="hsF">
#       <input name="hl" type="hidden" value=""/>
#       <input name="hlst" type="hidden" value=""/>
#       <input name="wist" type="hidden" value=""/>
#       <input name="yr" type="hidden" value=""/>
#       <input name="dis" type="hidden" value=""/>
#       <input name="sb" type="hidden" value="DESC"/>
#       <input name="plow" type="hidden" value=""/>
#       <input name="phigh" type="hidden" value=""/>
#       <input name="ps" type="hidden" value=""/>
#      </form>
#     </div>
#     <div id="hmenu">
#      <script type="text/javascript">
#       <!--
# window.google_analytics_uacct = "UA-12906387-4";
# google_ad_client = "ca-pub-1187797442630842";
# /* USA.com_main_right_300x250 */
# google_ad_slot = "6987722783";
# google_ad_width = 300;
# google_ad_height = 250;
# //-->
#      </script>
#      <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#      </script>
#      <style>
#       border-radius:3px;
# 	border: 1px solid #4fa4c3;
# 	background: #deedf2;
# 	padding: 5px;
#
# .tpcitem{
# 	margin-left:10px;
# 	display:block;
# 	font-size:10px;
# }
# .searchbox{
# 	border-radius:3px;
# 	background: #ecf4f6;
# 	border: 1px solid #1d5895;
# 	margin-top:5px;
# }
# .searchboxhead{
# 	font-size: 16px;
# 	font-weight: bold;
# 	color: #ffffff;
# 	background: #1d5895;
# 	padding: 3px;
# 	font-weight:bold;
# }
# .bigsubmit{
# 	font-size: 14px;
# 	font-weight: bold;
# 	width:100px;
# 	height:30px;
# }
#      </style>
#      <form action="#" method="get" name="rsF">
#       <div class="searchbox">
#        <div class="searchboxhead">
#         Refine Your Ranking
#        </div>
#        <div style="padding-left:4px;">
#         <input name="itemtorank" type="hidden" value=""/>
#         <span id="itemtorankerror">
#         </span>
#         <div id="itemtorankcontent">
#         </div>
#         <br/>
#         <span id="rankingscopeerror">
#         </span>
#         <div class="big">
#          <b>
#           Pick Your Location:
#          </b>
#         </div>
#         <div style="padding-left:5px;">
#          <label for="withinloc">
#           <input checked="" id="withinloc" name="rankingscope" onclick="switchScope('1')" type="radio" value="1"/>
#           Within a Location
#          </label>
#         </div>
#         <div id="withinLocationDiv" style="padding-top:5px;padding-left:31px;">
#          <select name="rankWithin" onchange="changeScope(1,'');">
#           <option value="us">
#            The Entire U.S.
#           </option>
#           <option selected="" value="state">
#            State
#           </option>
#           <option value="metro-area">
#            Metro Area
#           </option>
#           <option value="county">
#            County
#           </option>
#           <option value="city">
#            City
#           </option>
#           <option value="school-district">
#            School District
#           </option>
#           <option value="zip-code">
#            Zip
#           </option>
#          </select>
#          <select id="rankWithin2" name="rankWithin2" onchange="changeScope(2,'');" style="display:none;width:260px;">
#          </select>
#          <select id="rankWithin3" name="rankWithin3" style="display:none;width:260px;">
#          </select>
#         </div>
#         <div style="padding-left:5px;">
#          <label for="withinpoint">
#           <input id="withinpoint" name="rankingscope" onclick="switchScope('0')" type="radio" value="0"/>
#           Rank within a Distance of a Point
#          </label>
#         </div>
#         <div id="withinPointDiv" style="display:none;padding-top:5px;padding-left:26px;">
#          within
#          <input name="ml" size="1" type="text" value=""/>
#          miles of
#          <input name="lc" size="5" type="text" value="california-state"/>
#          (e.g. a zip code)
#         </div>
#         <span id="rankoferror">
#         </span>
#         <div style="padding-top:15px;">
#          <span class="big">
#           <b>
#            Rank By:
#           </b>
#          </span>
#         </div>
#         <div style="padding-top:5px;padding-left:15px;">
#          <select name="rankOf" onchange="loadItemsToRank(document.rsF.itemtorank.value);">
#           <option value="state">
#            State
#           </option>
#           <option value="metro-area">
#            Metro Area
#           </option>
#           <option selected="" value="county">
#            County
#           </option>
#           <option value="city">
#            City
#           </option>
#           <option value="school-district">
#            School District
#           </option>
#           <option value="zip-code">
#            Zip
#           </option>
#           <option value="census-tract">
#            Census Tract
#           </option>
#           <option value="block-group">
#            Census Block Group
#           </option>
#           <option value="block">
#            Census Block
#           </option>
#          </select>
#         </div>
#         <div>
#          <div id="datadateDiv" style="padding-top:15px;">
#           <span class="big">
#            <b>
#             Select Date of Data:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <select name="datadate" style="width:270px;">
#             <option value="9000">
#              American Community Survey 2010-2014
#             </option>
#             <option value="8000">
#              U.S. Census 2010
#             </option>
#             <option value="6000">
#              American Community Survey 2008-2012
#             </option>
#             <option value="3000">
#              American Community Survey 2006-2010
#             </option>
#             <option value="2000">
#              American Community Survey 2005-2009
#             </option>
#             <option value="1000">
#              U.S. Census 2000
#             </option>
#            </select>
#           </div>
#          </div>
#          <div id="limitToStateDiv" style="display:none;padding-top:15px;">
#           <span class="big">
#            <b>
#             Limit to the State of:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <select name="limitToState">
#             <option value="">
#              Please Select
#             </option>
#             <option value="AL">
#              Alabama
#             </option>
#             <option value="AK">
#              Alaska
#             </option>
#             <option value="AZ">
#              Arizona
#             </option>
#             <option value="AR">
#              Arkansas
#             </option>
#             <option value="CA">
#              California
#             </option>
#             <option value="CO">
#              Colorado
#             </option>
#             <option value="CT">
#              Connecticut
#             </option>
#             <option value="DE">
#              Delaware
#             </option>
#             <option value="DC">
#              District of Columbia
#             </option>
#             <option value="FL">
#              Florida
#             </option>
#             <option value="GA">
#              Georgia
#             </option>
#             <option value="HI">
#              Hawaii
#             </option>
#             <option value="ID">
#              Idaho
#             </option>
#             <option value="IL">
#              Illinois
#             </option>
#             <option value="IN">
#              Indiana
#             </option>
#             <option value="IA">
#              Iowa
#             </option>
#             <option value="KS">
#              Kansas
#             </option>
#             <option value="KY">
#              Kentucky
#             </option>
#             <option value="LA">
#              Louisiana
#             </option>
#             <option value="ME">
#              Maine
#             </option>
#             <option value="MD">
#              Maryland
#             </option>
#             <option value="MA">
#              Massachusetts
#             </option>
#             <option value="MI">
#              Michigan
#             </option>
#             <option value="MN">
#              Minnesota
#             </option>
#             <option value="MS">
#              Mississippi
#             </option>
#             <option value="MO">
#              Missouri
#             </option>
#             <option value="MT">
#              Montana
#             </option>
#             <option value="NE">
#              Nebraska
#             </option>
#             <option value="NV">
#              Nevada
#             </option>
#             <option value="NH">
#              New Hampshire
#             </option>
#             <option value="NJ">
#              New Jersey
#             </option>
#             <option value="NM">
#              New Mexico
#             </option>
#             <option value="NY">
#              New York
#             </option>
#             <option value="NC">
#              North Carolina
#             </option>
#             <option value="ND">
#              North Dakota
#             </option>
#             <option value="OH">
#              Ohio
#             </option>
#             <option value="OK">
#              Oklahoma
#             </option>
#             <option value="OR">
#              Oregon
#             </option>
#             <option value="PA">
#              Pennsylvania
#             </option>
#             <option value="RI">
#              Rhode Island
#             </option>
#             <option value="SC">
#              South Carolina
#             </option>
#             <option value="SD">
#              South Dakota
#             </option>
#             <option value="TN">
#              Tennessee
#             </option>
#             <option value="TX">
#              Texas
#             </option>
#             <option value="UT">
#              Utah
#             </option>
#             <option value="VT">
#              Vermont
#             </option>
#             <option value="VA">
#              Virginia
#             </option>
#             <option value="WA">
#              Washington
#             </option>
#             <option value="WV">
#              West Virginia
#             </option>
#             <option value="WI">
#              Wisconsin
#             </option>
#             <option value="WY">
#              Wyoming
#             </option>
#            </select>
#           </div>
#          </div>
#          <div style="padding-top:10px;">
#           <span class="big">
#            <b>
#             Limit to Locations with Population:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <input name="poplow" size="3" type="text" value=""/>
#            to
#            <input name="pophigh" size="3" type="text" value=""/>
#            (number only, can be blank)
#           </div>
#          </div>
#         </div>
#         <p align="center">
#          <input class="bigsubmit" onclick="sendForm();return false;" type="submit" value="Submit"/>
#         </p>
#        </div>
#       </div>
#      </form>
#      <script>
#       rankOfChanged = 1;
# loadItemsToRank("land-area",-1);
# switchScope('1');
# highlightScope1='california-state';
# highlightScope2='';
# changeScope(1,'');
#      </script>
#      <br/>
#      <div id="hotranking">
#       Popular Rankings
#      </div>
#      <div class="hotranks">
#       <div>
#        <a href="/rank/us--population-growth-rate--state-rank.htm?tag=Fastest+Growing+States+in+U.S.">
#         Fastest
#        </a>
#        /
#        <a href="/rank/us--population-growth-rate--state-rank.htm?sb=ASC&amp;tag=Slowest+Growing+States+in+U.S.">
#         Slowest
#        </a>
#        Growing States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--employed-male-civilian-population-percentage--state-rank.htm?yr=3000&amp;tag=Best+States+in+U.S.+by+%+of+Males+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/us--employed-male-civilian-population-percentage--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Worst+States+in+U.S.+by+%+of+Males+Employed">
#         Worst
#        </a>
#        States in U.S. by % of Males Employed
#       </div>
#       <div>
#        <a href="/rank/us--employed-female-civilian-population-percentage--state-rank.htm?yr=3000&amp;tag=Best+States+in+U.S.+by+%+of+Females+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/us--employed-female-civilian-population-percentage--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Worst+States+in+U.S.+by+%+of+Females+Employed">
#         Worst
#        </a>
#        States in U.S. by % of Females Employed
#       </div>
#       <div>
#        <a href="/rank/us--crime-index--state-rank.htm?tag=Best+States+by+Crime+Rate+in+U.S.">
#         Best
#        </a>
#        /
#        <a href="/rank/us--crime-index--state-rank.htm?sb=DESC&amp;tag=Worst+States+by+Crime+Rate+in+U.S.">
#         Worst
#        </a>
#        States by Crime Rate in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-household-income--state-rank.htm?yr=3000&amp;tag=Richest+States+by+Income+in+U.S.">
#         Richest
#        </a>
#        /
#        <a href="/rank/us--median-household-income--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Poorest+States+by+Income+in+U.S.">
#         Poorest
#        </a>
#        States by Income in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--house-median-value--state-rank.htm?yr=3000&amp;tag=Most+Expensive+Homes+by+State+in+U.S.">
#         Most Expensive
#        </a>
#        /
#        <a href="/rank/us--house-median-value--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Cheapest+Homes+by+State+in+U.S.">
#         Cheapest
#        </a>
#        Homes by State in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--average-education-index--state-rank.htm?yr=3000&amp;tag=Most+Educated+States+in+U.S.">
#         Most
#        </a>
#        /
#        <a href="/rank/us--average-education-index--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Least+Educated+States+in+U.S.">
#         Least
#        </a>
#        Educated States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--total-population--state-rank.htm?tag=Most+Populated+States+in+U.S.">
#         Most
#        </a>
#        /
#        <a href="/rank/us--total-population--state-rank.htm?sb=ASC&amp;tag=Least+Populated+States+in+U.S.">
#         Least
#        </a>
#        Populated States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--land-area--state-rank.htm?tag=Largest+States+by+Area+in+U.S.">
#         Largest
#        </a>
#        /
#        <a href="/rank/us--land-area--state-rank.htm?sb=ASC&amp;tag=Smallest+States+by+Area+in+U.S.">
#         Smallest
#        </a>
#        States by Area in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-household-income--county-rank.htm?tag=Richest+Counties+by+Income+in+U.S.">
#         Richest
#        </a>
#        /
#        <a href="/rank/us--median-household-income--county-rank.htm?sb=ASC&amp;tag=Poorest+Counties+by+Income+in+U.S.">
#         Poorest
#        </a>
#        Counties by Income in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--population-growth-rate--county-rank.htm?tag=Fastest+Growing+Counties+in+U.S.">
#         Fastest
#        </a>
#        /
#        <a href="/rank/us--population-growth-rate--county-rank.htm?sb=ASC&amp;tag=Slowest+Growing+Counties+in+U.S.">
#         Slowest
#        </a>
#        Growing Counties in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--average-education-index--county-rank.htm?yr=3000&amp;tag=Most+Educated+Counties+in+U.S.">
#         Most
#        </a>
#        /
#        <a href="/rank/us--average-education-index--county-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Least+Educated+Counties+in+U.S.">
#         Least
#        </a>
#        Educated Counties in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-age--state-rank.htm?tag=Youngest+States+in+U.S.">
#         Youngest
#        </a>
#        /
#        <a href="/rank/us--median-age--state-rank.htm?sb=DESC&amp;tag=Oldest+States+in+U.S.">
#         Oldest
#        </a>
#        States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-age--county-rank.htm?tag=Youngest+Counties+in+U.S.">
#         Youngest
#        </a>
#        /
#        <a href="/rank/us--median-age--county-rank.htm?sb=DESC&amp;tag=Oldest+Counties+in+U.S.">
#         Oldest
#        </a>
#        Counties in U.S.
#       </div>
#      </div>
#     </div>
#     <div id="clear">
#     </div>
#    </div>
#   </div>
#   <div id="fo">
#    <div id="ftop">
#    </div>
#    <div id="f">
#     <div class="fleft">
#      The
#      <a href="http://www.usa.com">
#       USA.com
#      </a>
#      website and domain are privately owned and are not operated by or affiliated with any government or municipal authority.
#      <br/>
#      © 2020 World Media Group, LLC.
#      <!--(0.003493070602417)-->
#     </div>
#     <div class="fmenu">
#      <a href="/about-us.php">
#       about us
#      </a>
#      |
#      <a href="/contact-us.php">
#       contact us
#      </a>
#      |
#      <a href="/scam-warning.php">
#       usa.com alerts
#      </a>
#      |
#      <a href="/terms-of-use.php">
#       terms of use
#      </a>
#      |
#      <a href="/privacy-policy.php">
#       privacy policy
#      </a>
#     </div>
#     <div id="clear">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-12906387-4']);
# _gaq.push(['_setDomainName', 'www.usa.com']);
# _gaq.push(['_trackPageview']);
# (function() {
# 	var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# })();
#   </script>
#  </body>
# </html>

# %%
table = soup.find_all('table')[1]
table
# Out:
# <table width="648"><tr valign="bottom"><td width="48"><b>Rank</b></td><td width="150"><b><a href="#" onclick="rsf('sb','ASC');">Land Area ▼</a></b></td><td width="450"><b>County / Population</b></td></tr><tr><td>1.</td><td>20,056.92 sq mi</td><td><a href="r.php?i=30-ca-san-bernardino">San Bernardino, CA</a> / 2,078,586</td></tr>
# <tr><td>2.</td><td>10,180.87 sq mi</td><td><a href="r.php?i=30-ca-inyo">Inyo, CA</a> / 18,439</td></tr>
# <tr><td>3.</td><td>8,131.91 sq mi</td><td><a href="r.php?i=30-ca-kern">Kern, CA</a> / 857,730</td></tr>
# <tr><td>4.</td><td>7,206.47 sq mi</td><td><a href="r.php?i=30-ca-riverside">Riverside, CA</a> / 2,266,899</td></tr>
# <tr><td>5.</td><td>6,277.88 sq mi</td><td><a href="r.php?i=30-ca-siskiyou">Siskiyou, CA</a> / 44,261</td></tr>
# <tr><td>6.</td><td>5,957.99 sq mi</td><td><a href="r.php?i=30-ca-fresno">Fresno, CA</a> / 948,844</td></tr>
# <tr><td>7.</td><td>4,824.21 sq mi</td><td><a href="r.php?i=30-ca-tulare">Tulare, CA</a> / 451,108</td></tr>
# <tr><td>8.</td><td>4,541.18 sq mi</td><td><a href="r.php?i=30-ca-lassen">Lassen, CA</a> / 33,356</td></tr>
# <tr><td>9.</td><td>4,206.63 sq mi</td><td><a href="r.php?i=30-ca-san-diego">San Diego, CA</a> / 3,183,143</td></tr>
# <tr><td>10.</td><td>4,176.60 sq mi</td><td><a href="r.php?i=30-ca-imperial">Imperial, CA</a> / 177,026</td></tr>
# <tr><td>11.</td><td>4,057.88 sq mi</td><td><a href="r.php?i=30-ca-los-angeles">Los Angeles, CA</a> / 9,974,203</td></tr>
# <tr><td>12.</td><td>3,917.77 sq mi</td><td><a href="r.php?i=30-ca-modoc">Modoc, CA</a> / 9,335</td></tr>
# <tr><td>13.</td><td>3,775.40 sq mi</td><td><a href="r.php?i=30-ca-shasta">Shasta, CA</a> / 178,520</td></tr>
# <tr><td>14.</td><td>3,567.98 sq mi</td><td><a href="r.php?i=30-ca-humboldt">Humboldt, CA</a> / 134,876</td></tr>
# <tr><td>15.</td><td>3,506.34 sq mi</td><td><a href="r.php?i=30-ca-mendocino">Mendocino, CA</a> / 87,612</td></tr>
# <tr><td>16.</td><td>3,298.56 sq mi</td><td><a href="r.php?i=30-ca-san-luis-obispo">San Luis Obispo, CA</a> / 274,184</td></tr>
# <tr><td>17.</td><td>3,280.59 sq mi</td><td><a href="r.php?i=30-ca-monterey">Monterey, CA</a> / 424,927</td></tr>
# <tr><td>18.</td><td>3,179.25 sq mi</td><td><a href="r.php?i=30-ca-trinity">Trinity, CA</a> / 13,515</td></tr>
# <tr><td>19.</td><td>3,048.98 sq mi</td><td><a href="r.php?i=30-ca-mono">Mono, CA</a> / 14,193</td></tr>
# <tr><td>20.</td><td>2,949.71 sq mi</td><td><a href="r.php?i=30-ca-tehama">Tehama, CA</a> / 63,284</td></tr>
# <tr><td>21.</td><td>2,735.08 sq mi</td><td><a href="r.php?i=30-ca-santa-barbara">Santa Barbara, CA</a> / 431,555</td></tr>
# <tr><td>22.</td><td>2,553.04 sq mi</td><td><a href="r.php?i=30-ca-plumas">Plumas, CA</a> / 19,286</td></tr>
# <tr><td>23.</td><td>2,220.88 sq mi</td><td><a href="r.php?i=30-ca-tuolumne">Tuolumne, CA</a> / 54,347</td></tr>
# <tr><td>24.</td><td>2,137.07 sq mi</td><td><a href="r.php?i=30-ca-madera">Madera, CA</a> / 152,452</td></tr>
# <tr><td>25.</td><td>1,934.97 sq mi</td><td><a href="r.php?i=30-ca-merced">Merced, CA</a> / 261,609</td></tr>
# <tr><td>26.</td><td>1,843.13 sq mi</td><td><a href="r.php?i=30-ca-ventura">Ventura, CA</a> / 835,790</td></tr>
# <tr><td>27.</td><td>1,707.88 sq mi</td><td><a href="r.php?i=30-ca-el-dorado">El Dorado, CA</a> / 181,465</td></tr>
# <tr><td>28.</td><td>1,636.46 sq mi</td><td><a href="r.php?i=30-ca-butte">Butte, CA</a> / 221,578</td></tr>
# <tr><td>29.</td><td>1,575.85 sq mi</td><td><a href="r.php?i=30-ca-sonoma">Sonoma, CA</a> / 491,790</td></tr>
# <tr><td>30.</td><td>1,494.83 sq mi</td><td><a href="r.php?i=30-ca-stanislaus">Stanislaus, CA</a> / 522,794</td></tr>
# <tr><td>31.</td><td>1,448.82 sq mi</td><td><a href="r.php?i=30-ca-mariposa">Mariposa, CA</a> / 17,946</td></tr>
# <tr><td>32.</td><td>1,407.01 sq mi</td><td><a href="r.php?i=30-ca-placer">Placer, CA</a> / 361,518</td></tr>
# <tr><td>33.</td><td>1,391.32 sq mi</td><td><a href="r.php?i=30-ca-san-joaquin">San Joaquin, CA</a> / 701,050</td></tr>
# <tr><td>34.</td><td>1,389.42 sq mi</td><td><a href="r.php?i=30-ca-kings">Kings, CA</a> / 151,390</td></tr>
# <tr><td>35.</td><td>1,388.71 sq mi</td><td><a href="r.php?i=30-ca-san-benito">San Benito, CA</a> / 56,888</td></tr>
# <tr><td>36.</td><td>1,313.95 sq mi</td><td><a href="r.php?i=30-ca-glenn">Glenn, CA</a> / 28,019</td></tr>
# <tr><td>37.</td><td>1,290.10 sq mi</td><td><a href="r.php?i=30-ca-santa-clara">Santa Clara, CA</a> / 1,841,569</td></tr>
# <tr><td>38.</td><td>1,256.46 sq mi</td><td><a href="r.php?i=30-ca-lake">Lake, CA</a> / 64,209</td></tr>
# <tr><td>39.</td><td>1,150.73 sq mi</td><td><a href="r.php?i=30-ca-colusa">Colusa, CA</a> / 21,424</td></tr>
# <tr><td>40.</td><td>1,020.01 sq mi</td><td><a href="r.php?i=30-ca-calaveras">Calaveras, CA</a> / 44,921</td></tr>
# <tr><td>41.</td><td>1,014.69 sq mi</td><td><a href="r.php?i=30-ca-yolo">Yolo, CA</a> / 204,162</td></tr>
# <tr><td>42.</td><td>1,006.37 sq mi</td><td><a href="r.php?i=30-ca-del-norte">Del Norte, CA</a> / 28,066</td></tr>
# <tr><td>43.</td><td>964.64 sq mi</td><td><a href="r.php?i=30-ca-sacramento">Sacramento, CA</a> / 1,450,277</td></tr>
# <tr><td>44.</td><td>957.77 sq mi</td><td><a href="r.php?i=30-ca-nevada">Nevada, CA</a> / 98,606</td></tr>
# <tr><td>45.</td><td>953.21 sq mi</td><td><a href="r.php?i=30-ca-sierra">Sierra, CA</a> / 3,019</td></tr>
# <tr><td>46.</td><td>821.76 sq mi</td><td><a href="r.php?i=30-ca-solano">Solano, CA</a> / 421,624</td></tr>
# <tr><td>47.</td><td>790.57 sq mi</td><td><a href="r.php?i=30-ca-orange">Orange, CA</a> / 3,086,331</td></tr>
# <tr><td>48.</td><td>748.36 sq mi</td><td><a href="r.php?i=30-ca-napa">Napa, CA</a> / 139,253</td></tr>
# <tr><td>49.</td><td>739.02 sq mi</td><td><a href="r.php?i=30-ca-alameda">Alameda, CA</a> / 1,559,308</td></tr>
# <tr><td>50.</td><td>738.33 sq mi</td><td><a href="r.php?i=30-ca-alpine">Alpine, CA</a> / 1,202</td></tr>
# <tr><td>51.</td><td>715.94 sq mi</td><td><a href="r.php?i=30-ca-contra-costa">Contra Costa, CA</a> / 1,081,232</td></tr>
# <tr><td>52.</td><td>631.84 sq mi</td><td><a href="r.php?i=30-ca-yuba">Yuba, CA</a> / 73,059</td></tr>
# <tr><td>53.</td><td>602.41 sq mi</td><td><a href="r.php?i=30-ca-sutter">Sutter, CA</a> / 95,067</td></tr>
# <tr><td>54.</td><td>594.58 sq mi</td><td><a href="r.php?i=30-ca-amador">Amador, CA</a> / 37,159</td></tr>
# <tr><td>55.</td><td>520.31 sq mi</td><td><a href="r.php?i=30-ca-marin">Marin, CA</a> / 256,802</td></tr>
# <tr><td>56.</td><td>448.41 sq mi</td><td><a href="r.php?i=30-ca-san-mateo">San Mateo, CA</a> / 739,837</td></tr>
# <tr><td>57.</td><td>445.17 sq mi</td><td><a href="r.php?i=30-ca-santa-cruz">Santa Cruz, CA</a> / 267,203</td></tr>
# <tr><td>58.</td><td>46.87 sq mi</td><td><a href="r.php?i=30-ca-san-francisco">San Francisco, CA</a> / 829,072</td></tr>
# </table>

# %%
output_rows = []
for table_row in table.findAll('tr'):
    columns = table_row.findAll('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    output_rows.append(output_row)
    
with open('output.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(output_rows)

# %%
output_rows
# Out:
# [['Rank', 'Land Area ▼', 'County / Population'],
#  ['1.', '20,056.92 sq mi', 'San Bernardino, CA / 2,078,586'],
#  ['2.', '10,180.87 sq mi', 'Inyo, CA / 18,439'],
#  ['3.', '8,131.91 sq mi', 'Kern, CA / 857,730'],
#  ['4.', '7,206.47 sq mi', 'Riverside, CA / 2,266,899'],
#  ['5.', '6,277.88 sq mi', 'Siskiyou, CA / 44,261'],
#  ['6.', '5,957.99 sq mi', 'Fresno, CA / 948,844'],
#  ['7.', '4,824.21 sq mi', 'Tulare, CA / 451,108'],
#  ['8.', '4,541.18 sq mi', 'Lassen, CA / 33,356'],
#  ['9.', '4,206.63 sq mi', 'San Diego, CA / 3,183,143'],
#  ['10.', '4,176.60 sq mi', 'Imperial, CA / 177,026'],
#  ['11.', '4,057.88 sq mi', 'Los Angeles, CA / 9,974,203'],
#  ['12.', '3,917.77 sq mi', 'Modoc, CA / 9,335'],
#  ['13.', '3,775.40 sq mi', 'Shasta, CA / 178,520'],
#  ['14.', '3,567.98 sq mi', 'Humboldt, CA / 134,876'],
#  ['15.', '3,506.34 sq mi', 'Mendocino, CA / 87,612'],
#  ['16.', '3,298.56 sq mi', 'San Luis Obispo, CA / 274,184'],
#  ['17.', '3,280.59 sq mi', 'Monterey, CA / 424,927'],
#  ['18.', '3,179.25 sq mi', 'Trinity, CA / 13,515'],
#  ['19.', '3,048.98 sq mi', 'Mono, CA / 14,193'],
#  ['20.', '2,949.71 sq mi', 'Tehama, CA / 63,284'],
#  ['21.', '2,735.08 sq mi', 'Santa Barbara, CA / 431,555'],
#  ['22.', '2,553.04 sq mi', 'Plumas, CA / 19,286'],
#  ['23.', '2,220.88 sq mi', 'Tuolumne, CA / 54,347'],
#  ['24.', '2,137.07 sq mi', 'Madera, CA / 152,452'],
#  ['25.', '1,934.97 sq mi', 'Merced, CA / 261,609'],
#  ['26.', '1,843.13 sq mi', 'Ventura, CA / 835,790'],
#  ['27.', '1,707.88 sq mi', 'El Dorado, CA / 181,465'],
#  ['28.', '1,636.46 sq mi', 'Butte, CA / 221,578'],
#  ['29.', '1,575.85 sq mi', 'Sonoma, CA / 491,790'],
#  ['30.', '1,494.83 sq mi', 'Stanislaus, CA / 522,794'],
#  ['31.', '1,448.82 sq mi', 'Mariposa, CA / 17,946'],
#  ['32.', '1,407.01 sq mi', 'Placer, CA / 361,518'],
#  ['33.', '1,391.32 sq mi', 'San Joaquin, CA / 701,050'],
#  ['34.', '1,389.42 sq mi', 'Kings, CA / 151,390'],
#  ['35.', '1,388.71 sq mi', 'San Benito, CA / 56,888'],
#  ['36.', '1,313.95 sq mi', 'Glenn, CA / 28,019'],
#  ['37.', '1,290.10 sq mi', 'Santa Clara, CA / 1,841,569'],
#  ['38.', '1,256.46 sq mi', 'Lake, CA / 64,209'],
#  ['39.', '1,150.73 sq mi', 'Colusa, CA / 21,424'],
#  ['40.', '1,020.01 sq mi', 'Calaveras, CA / 44,921'],
#  ['41.', '1,014.69 sq mi', 'Yolo, CA / 204,162'],
#  ['42.', '1,006.37 sq mi', 'Del Norte, CA / 28,066'],
#  ['43.', '964.64 sq mi', 'Sacramento, CA / 1,450,277'],
#  ['44.', '957.77 sq mi', 'Nevada, CA / 98,606'],
#  ['45.', '953.21 sq mi', 'Sierra, CA / 3,019'],
#  ['46.', '821.76 sq mi', 'Solano, CA / 421,624'],
#  ['47.', '790.57 sq mi', 'Orange, CA / 3,086,331'],
#  ['48.', '748.36 sq mi', 'Napa, CA / 139,253'],
#  ['49.', '739.02 sq mi', 'Alameda, CA / 1,559,308'],
#  ['50.', '738.33 sq mi', 'Alpine, CA / 1,202'],
#  ['51.', '715.94 sq mi', 'Contra Costa, CA / 1,081,232'],
#  ['52.', '631.84 sq mi', 'Yuba, CA / 73,059'],
#  ['53.', '602.41 sq mi', 'Sutter, CA / 95,067'],
#  ['54.', '594.58 sq mi', 'Amador, CA / 37,159'],
#  ['55.', '520.31 sq mi', 'Marin, CA / 256,802'],
#  ['56.', '448.41 sq mi', 'San Mateo, CA / 739,837'],
#  ['57.', '445.17 sq mi', 'Santa Cruz, CA / 267,203'],
#  ['58.', '46.87 sq mi', 'San Francisco, CA / 829,072']]
