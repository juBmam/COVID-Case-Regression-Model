# %%
from bs4 import BeautifulSoup
import requests
from IPython.core.display import display, HTML
import csv

# %%
url = 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/'

response = requests.get(url)

response.status_code

page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
script_soup = [row for row in soup.find_all('script')]
cases_dict = script_soup[8]

# %%
county_stats = script_soup[8].contents[0][30204:39489]

# %%
county_stats = county_stats.replace("}", "")
county_stats = county_stats.replace("{", "")
county_list = []
county_list = county_stats.split(',')
county_list
# Out:
# ['"stateFips":"06"',
#  '"countyFips":"001"',
#  '"statePopulation":39512223',
#  '"countyPopulation":1671329',
#  '"confirmed":21508',
#  '"confirmedPopulation":1286.8800816595656',
#  '"deaths":420',
#  '"stateFips":"06"',
#  '"countyFips":"003"',
#  '"statePopulation":39512223',
#  '"countyPopulation":1129',
#  '"confirmed":2',
#  '"confirmedPopulation":177.1479185119575',
#  '"deaths":0',
#  '"stateFips":"06"',
#  '"countyFips":"005"',
#  '"statePopulation":39512223',
#  '"countyPopulation":39752',
#  '"confirmed":259',
#  '"confirmedPopulation":651.5395451801168',
#  '"deaths":16',
#  '"stateFips":"06"',
#  '"countyFips":"007"',
#  '"statePopulation":39512223',
#  '"countyPopulation":219186',
#  '"confirmed":2840',
#  '"confirmedPopulation":1295.7031927221628',
#  '"deaths":45',
#  '"stateFips":"06"',
#  '"countyFips":"009"',
#  '"statePopulation":39512223',
#  '"countyPopulation":45905',
#  '"confirmed":324',
#  '"confirmedPopulation":705.8054678139636',
#  '"deaths":14',
#  '"stateFips":"06"',
#  '"countyFips":"011"',
#  '"statePopulation":39512223',
#  '"countyPopulation":21547',
#  '"confirmed":538',
#  '"confirmedPopulation":2496.8673133150787',
#  '"deaths":6',
#  '"stateFips":"06"',
#  '"countyFips":"013"',
#  '"statePopulation":39512223',
#  '"countyPopulation":1153526',
#  '"confirmed":17069',
#  '"confirmedPopulation":1479.723907393505',
#  '"deaths":211',
#  '"stateFips":"06"',
#  '"countyFips":"015"',
#  '"statePopulation":39512223',
#  '"countyPopulation":27812',
#  '"confirmed":146',
#  '"confirmedPopulation":524.9532575866533',
#  '"deaths":1',
#  '"stateFips":"06"',
#  '"countyFips":"017"',
#  '"statePopulation":39512223',
#  '"countyPopulation":192843',
#  '"confirmed":1180',
#  '"confirmedPopulation":611.8967242782988',
#  '"deaths":4',
#  '"stateFips":"06"',
#  '"countyFips":"019"',
#  '"statePopulation":39512223',
#  '"countyPopulation":999101',
#  '"confirmed":28796',
#  '"confirmedPopulation":2882.191089789721',
#  '"deaths":399',
#  '"stateFips":"06"',
#  '"countyFips":"021"',
#  '"statePopulation":39512223',
#  '"countyPopulation":28393',
#  '"confirmed":603',
#  '"confirmedPopulation":2123.7628993061667',
#  '"deaths":3',
#  '"stateFips":"06"',
#  '"countyFips":"023"',
#  '"statePopulation":39512223',
#  '"countyPopulation":135558',
#  '"confirmed":518',
#  '"confirmedPopulation":382.12425677569746',
#  '"deaths":8',
#  '"stateFips":"06"',
#  '"countyFips":"025"',
#  '"statePopulation":39512223',
#  '"countyPopulation":181215',
#  '"confirmed":12002',
#  '"confirmedPopulation":6623.072041497669',
#  '"deaths":323',
#  '"stateFips":"06"',
#  '"countyFips":"027"',
#  '"statePopulation":39512223',
#  '"countyPopulation":18039',
#  '"confirmed":191',
#  '"confirmedPopulation":1058.8170075946562',
#  '"deaths":15',
#  '"stateFips":"06"',
#  '"countyFips":"029"',
#  '"statePopulation":39512223',
#  '"countyPopulation":900202',
#  '"confirmed":32343',
#  '"confirmedPopulation":3592.860269139593',
#  '"deaths":381',
#  '"stateFips":"06"',
#  '"countyFips":"031"',
#  '"statePopulation":39512223',
#  '"countyPopulation":152940',
#  '"confirmed":7851',
#  '"confirmedPopulation":5133.385641428011',
#  '"deaths":104',
#  '"stateFips":"06"',
#  '"countyFips":"033"',
#  '"statePopulation":39512223',
#  '"countyPopulation":64386',
#  '"confirmed":581',
#  '"confirmedPopulation":902.3700804522723',
#  '"deaths":11',
#  '"stateFips":"06"',
#  '"countyFips":"035"',
#  '"statePopulation":39512223',
#  '"countyPopulation":30573',
#  '"confirmed":742',
#  '"confirmedPopulation":2426.9780525300102',
#  '"deaths":0',
#  '"stateFips":"06"',
#  '"countyFips":"037"',
#  '"statePopulation":39512223',
#  '"countyPopulation":10039107',
#  '"confirmed":272653',
#  '"confirmedPopulation":2715.908895083995',
#  '"deaths":6626',
#  '"stateFips":"06"',
#  '"countyFips":"039"',
#  '"statePopulation":39512223',
#  '"countyPopulation":157327',
#  '"confirmed":4642',
#  '"confirmedPopulation":2950.5425006515093',
#  '"deaths":70',
#  '"stateFips":"06"',
#  '"countyFips":"041"',
#  '"statePopulation":39512223',
#  '"countyPopulation":258826',
#  '"confirmed":6729',
#  '"confirmedPopulation":2599.81609266457',
#  '"deaths":117',
#  '"stateFips":"06"',
#  '"countyFips":"043"',
#  '"statePopulation":39512223',
#  '"countyPopulation":17203',
#  '"confirmed":76',
#  '"confirmedPopulation":441.7834098703715',
#  '"deaths":2',
#  '"stateFips":"06"',
#  '"countyFips":"045"',
#  '"statePopulation":39512223',
#  '"countyPopulation":86749',
#  '"confirmed":971',
#  '"confirmedPopulation":1119.3212601874372',
#  '"deaths":19',
#  '"stateFips":"06"',
#  '"countyFips":"047"',
#  '"statePopulation":39512223',
#  '"countyPopulation":277680',
#  '"confirmed":9033',
#  '"confirmedPopulation":3253.0250648228175',
#  '"deaths":145',
#  '"stateFips":"06"',
#  '"countyFips":"049"',
#  '"statePopulation":39512223',
#  '"countyPopulation":8841',
#  '"confirmed":27',
#  '"confirmedPopulation":305.39531727180184',
#  '"deaths":0',
#  '"stateFips":"06"',
#  '"countyFips":"051"',
#  '"statePopulation":39512223',
#  '"countyPopulation":14444',
#  '"confirmed":169',
#  '"confirmedPopulation":1170.0360011077262',
#  '"deaths":2',
#  '"stateFips":"06"',
#  '"countyFips":"053"',
#  '"statePopulation":39512223',
#  '"countyPopulation":434061',
#  '"confirmed":10219',
#  '"confirmedPopulation":2354.277394191139',
#  '"deaths":74',
#  '"stateFips":"06"',
#  '"countyFips":"055"',
#  '"statePopulation":39512223',
#  '"countyPopulation":137744',
#  '"confirmed":1734',
#  '"confirmedPopulation":1258.8570101057032',
#  '"deaths":13',
#  '"stateFips":"06"',
#  '"countyFips":"057"',
#  '"statePopulation":39512223',
#  '"countyPopulation":99755',
#  '"confirmed":543',
#  '"confirmedPopulation":544.3336173625382',
#  '"deaths":7',
#  '"stateFips":"06"',
#  '"countyFips":"059"',
#  '"statePopulation":39512223',
#  '"countyPopulation":3175692',
#  '"confirmed":54118',
#  '"confirmedPopulation":1704.1325166294464',
#  '"deaths":1281',
#  '"stateFips":"06"',
#  '"countyFips":"061"',
#  '"statePopulation":39512223',
#  '"countyPopulation":398329',
#  '"confirmed":3628',
#  '"confirmedPopulation":910.8048874171852',
#  '"deaths":49',
#  '"stateFips":"06"',
#  '"countyFips":"063"',
#  '"statePopulation":39512223',
#  '"countyPopulation":18807',
#  '"confirmed":50',
#  '"confirmedPopulation":265.85845695751584',
#  '"deaths":0',
#  '"stateFips":"06"',
#  '"countyFips":"065"',
#  '"statePopulation":39512223',
#  '"countyPopulation":2470546',
#  '"confirmed":59934',
#  '"confirmedPopulation":2425.94147204707',
#  '"deaths":1231',
#  '"stateFips":"06"',
#  '"countyFips":"067"',
#  '"statePopulation":39512223',
#  '"countyPopulation":1552058',
#  '"confirmed":22855',
#  '"confirmedPopulation":1472.560948108898',
#  '"deaths":430',
#  '"stateFips":"06"',
#  '"countyFips":"069"',
#  '"statePopulation":39512223',
#  '"countyPopulation":62808',
#  '"confirmed":1358',
#  '"confirmedPopulation":2162.144949687938',
#  '"deaths":11',
#  '"stateFips":"06"',
#  '"countyFips":"071"',
#  '"statePopulation":39512223',
#  '"countyPopulation":2180085',
#  '"confirmed":55671',
#  '"confirmedPopulation":2553.6160287328244',
#  '"deaths":962',
#  '"stateFips":"06"',
#  '"countyFips":"073"',
#  '"statePopulation":39512223',
#  '"countyPopulation":3338330',
#  '"confirmed":47791',
#  '"confirmedPopulation":1431.5840555008044',
#  '"deaths":794',
#  '"stateFips":"06"',
#  '"countyFips":"075"',
#  '"statePopulation":39512223',
#  '"countyPopulation":881549',
#  '"confirmed":11360',
#  '"confirmedPopulation":1288.640790245352',
#  '"deaths":107',
#  '"stateFips":"06"',
#  '"countyFips":"077"',
#  '"statePopulation":39512223',
#  '"countyPopulation":762148',
#  '"confirmed":20485',
#  '"confirmedPopulation":2687.798170434089',
#  '"deaths":470',
#  '"stateFips":"06"',
#  '"countyFips":"079"',
#  '"statePopulation":39512223',
#  '"countyPopulation":283111',
#  '"confirmed":3685',
#  '"confirmedPopulation":1301.609616016333',
#  '"deaths":31',
#  '"stateFips":"06"',
#  '"countyFips":"081"',
#  '"statePopulation":39512223',
#  '"countyPopulation":766573',
#  '"confirmed":10126',
#  '"confirmedPopulation":1320.9439935922605',
#  '"deaths":152',
#  '"stateFips":"06"',
#  '"countyFips":"083"',
#  '"statePopulation":39512223',
#  '"countyPopulation":446499',
#  '"confirmed":9249',
#  '"confirmedPopulation":2071.4492081729186',
#  '"deaths":115',
#  '"stateFips":"06"',
#  '"countyFips":"085"',
#  '"statePopulation":39512223',
#  '"countyPopulation":1927852',
#  '"confirmed":21605',
#  '"confirmedPopulation":1120.677313403726',
#  '"deaths":330',
#  '"stateFips":"06"',
#  '"countyFips":"087"',
#  '"statePopulation":39512223',
#  '"countyPopulation":273213',
#  '"confirmed":2481',
#  '"confirmedPopulation":908.082704702924',
#  '"deaths":12',
#  '"stateFips":"06"',
#  '"countyFips":"089"',
#  '"statePopulation":39512223',
#  '"countyPopulation":180080',
#  '"confirmed":953',
#  '"confirmedPopulation":529.2092403376278',
#  '"deaths":22',
#  '"stateFips":"06"',
#  '"countyFips":"091"',
#  '"statePopulation":39512223',
#  '"countyPopulation":3005',
#  '"confirmed":6',
#  '"confirmedPopulation":199.66722129783693',
#  '"deaths":0',
#  '"stateFips":"06"',
#  '"countyFips":"093"',
#  '"statePopulation":39512223',
#  '"countyPopulation":43539',
#  '"confirmed":167',
#  '"confirmedPopulation":383.5641608672684',
#  '"deaths":0',
#  '"stateFips":"06"',
#  '"countyFips":"095"',
#  '"statePopulation":39512223',
#  '"countyPopulation":447643',
#  '"confirmed":6520',
#  '"confirmedPopulation":1456.5178054833875',
#  '"deaths":71',
#  '"stateFips":"06"',
#  '"countyFips":"097"',
#  '"statePopulation":39512223',
#  '"countyPopulation":494336',
#  '"confirmed":7668',
#  '"confirmedPopulation":1551.171672708441',
#  '"deaths":122',
#  '"stateFips":"06"',
#  '"countyFips":"099"',
#  '"statePopulation":39512223',
#  '"countyPopulation":550660',
#  '"confirmed":16628',
#  '"confirmedPopulation":3019.6491482947736',
#  '"deaths":368',
#  '"stateFips":"06"',
#  '"countyFips":"101"',
#  '"statePopulation":39512223',
#  '"countyPopulation":96971',
#  '"confirmed":1748',
#  '"confirmedPopulation":1802.6007775520518',
#  '"deaths":11',
#  '"stateFips":"06"',
#  '"countyFips":"103"',
#  '"statePopulation":39512223',
#  '"countyPopulation":65084',
#  '"confirmed":605',
#  '"confirmedPopulation":929.5679429660132',
#  '"deaths":6',
#  '"stateFips":"06"',
#  '"countyFips":"105"',
#  '"statePopulation":39512223',
#  '"countyPopulation":12285',
#  '"confirmed":16',
#  '"confirmedPopulation":130.24013024013024',
#  '"deaths":0',
#  '"stateFips":"06"',
#  '"countyFips":"107"',
#  '"statePopulation":39512223',
#  '"countyPopulation":466195',
#  '"confirmed":16399',
#  '"confirmedPopulation":3517.6267441735754',
#  '"deaths":265',
#  '"stateFips":"06"',
#  '"countyFips":"109"',
#  '"statePopulation":39512223',
#  '"countyPopulation":54478',
#  '"confirmed":230',
#  '"confirmedPopulation":422.1887734498329',
#  '"deaths":4',
#  '"stateFips":"06"',
#  '"countyFips":"111"',
#  '"statePopulation":39512223',
#  '"countyPopulation":846006',
#  '"confirmed":12943',
#  '"confirmedPopulation":1529.8945870360258',
#  '"deaths":153',
#  '"stateFips":"06"',
#  '"countyFips":"113"',
#  '"statePopulation":39512223',
#  '"countyPopulation":220500',
#  '"confirmed":2847',
#  '"confirmedPopulation":1291.156462585034',
#  '"deaths":55',
#  '"stateFips":"06"',
#  '"countyFips":"115"',
#  '"statePopulation":39512223',
#  '"countyPopulation":78668',
#  '"confirmed":1188',
#  '"confirmedPopulation":1510.1438958661718',
#  '"deaths":9']

# %%
csv_table = []
for i in range(58):
    csv_nested = []
    csv_nested = county_list[i*7:i*7+7]
    csv_table.append(csv_nested)

csv_table
# Out:
# [['"stateFips":"06"',
#   '"countyFips":"001"',
#   '"statePopulation":39512223',
#   '"countyPopulation":1671329',
#   '"confirmed":21508',
#   '"confirmedPopulation":1286.8800816595656',
#   '"deaths":420'],
#  ['"stateFips":"06"',
#   '"countyFips":"003"',
#   '"statePopulation":39512223',
#   '"countyPopulation":1129',
#   '"confirmed":2',
#   '"confirmedPopulation":177.1479185119575',
#   '"deaths":0'],
#  ['"stateFips":"06"',
#   '"countyFips":"005"',
#   '"statePopulation":39512223',
#   '"countyPopulation":39752',
#   '"confirmed":259',
#   '"confirmedPopulation":651.5395451801168',
#   '"deaths":16'],
#  ['"stateFips":"06"',
#   '"countyFips":"007"',
#   '"statePopulation":39512223',
#   '"countyPopulation":219186',
#   '"confirmed":2840',
#   '"confirmedPopulation":1295.7031927221628',
#   '"deaths":45'],
#  ['"stateFips":"06"',
#   '"countyFips":"009"',
#   '"statePopulation":39512223',
#   '"countyPopulation":45905',
#   '"confirmed":324',
#   '"confirmedPopulation":705.8054678139636',
#   '"deaths":14'],
#  ['"stateFips":"06"',
#   '"countyFips":"011"',
#   '"statePopulation":39512223',
#   '"countyPopulation":21547',
#   '"confirmed":538',
#   '"confirmedPopulation":2496.8673133150787',
#   '"deaths":6'],
#  ['"stateFips":"06"',
#   '"countyFips":"013"',
#   '"statePopulation":39512223',
#   '"countyPopulation":1153526',
#   '"confirmed":17069',
#   '"confirmedPopulation":1479.723907393505',
#   '"deaths":211'],
#  ['"stateFips":"06"',
#   '"countyFips":"015"',
#   '"statePopulation":39512223',
#   '"countyPopulation":27812',
#   '"confirmed":146',
#   '"confirmedPopulation":524.9532575866533',
#   '"deaths":1'],
#  ['"stateFips":"06"',
#   '"countyFips":"017"',
#   '"statePopulation":39512223',
#   '"countyPopulation":192843',
#   '"confirmed":1180',
#   '"confirmedPopulation":611.8967242782988',
#   '"deaths":4'],
#  ['"stateFips":"06"',
#   '"countyFips":"019"',
#   '"statePopulation":39512223',
#   '"countyPopulation":999101',
#   '"confirmed":28796',
#   '"confirmedPopulation":2882.191089789721',
#   '"deaths":399'],
#  ['"stateFips":"06"',
#   '"countyFips":"021"',
#   '"statePopulation":39512223',
#   '"countyPopulation":28393',
#   '"confirmed":603',
#   '"confirmedPopulation":2123.7628993061667',
#   '"deaths":3'],
#  ['"stateFips":"06"',
#   '"countyFips":"023"',
#   '"statePopulation":39512223',
#   '"countyPopulation":135558',
#   '"confirmed":518',
#   '"confirmedPopulation":382.12425677569746',
#   '"deaths":8'],
#  ['"stateFips":"06"',
#   '"countyFips":"025"',
#   '"statePopulation":39512223',
#   '"countyPopulation":181215',
#   '"confirmed":12002',
#   '"confirmedPopulation":6623.072041497669',
#   '"deaths":323'],
#  ['"stateFips":"06"',
#   '"countyFips":"027"',
#   '"statePopulation":39512223',
#   '"countyPopulation":18039',
#   '"confirmed":191',
#   '"confirmedPopulation":1058.8170075946562',
#   '"deaths":15'],
#  ['"stateFips":"06"',
#   '"countyFips":"029"',
#   '"statePopulation":39512223',
#   '"countyPopulation":900202',
#   '"confirmed":32343',
#   '"confirmedPopulation":3592.860269139593',
#   '"deaths":381'],
#  ['"stateFips":"06"',
#   '"countyFips":"031"',
#   '"statePopulation":39512223',
#   '"countyPopulation":152940',
#   '"confirmed":7851',
#   '"confirmedPopulation":5133.385641428011',
#   '"deaths":104'],
#  ['"stateFips":"06"',
#   '"countyFips":"033"',
#   '"statePopulation":39512223',
#   '"countyPopulation":64386',
#   '"confirmed":581',
#   '"confirmedPopulation":902.3700804522723',
#   '"deaths":11'],
#  ['"stateFips":"06"',
#   '"countyFips":"035"',
#   '"statePopulation":39512223',
#   '"countyPopulation":30573',
#   '"confirmed":742',
#   '"confirmedPopulation":2426.9780525300102',
#   '"deaths":0'],
#  ['"stateFips":"06"',
#   '"countyFips":"037"',
#   '"statePopulation":39512223',
#   '"countyPopulation":10039107',
#   '"confirmed":272653',
#   '"confirmedPopulation":2715.908895083995',
#   '"deaths":6626'],
#  ['"stateFips":"06"',
#   '"countyFips":"039"',
#   '"statePopulation":39512223',
#   '"countyPopulation":157327',
#   '"confirmed":4642',
#   '"confirmedPopulation":2950.5425006515093',
#   '"deaths":70'],
#  ['"stateFips":"06"',
#   '"countyFips":"041"',
#   '"statePopulation":39512223',
#   '"countyPopulation":258826',
#   '"confirmed":6729',
#   '"confirmedPopulation":2599.81609266457',
#   '"deaths":117'],
#  ['"stateFips":"06"',
#   '"countyFips":"043"',
#   '"statePopulation":39512223',
#   '"countyPopulation":17203',
#   '"confirmed":76',
#   '"confirmedPopulation":441.7834098703715',
#   '"deaths":2'],
#  ['"stateFips":"06"',
#   '"countyFips":"045"',
#   '"statePopulation":39512223',
#   '"countyPopulation":86749',
#   '"confirmed":971',
#   '"confirmedPopulation":1119.3212601874372',
#   '"deaths":19'],
#  ['"stateFips":"06"',
#   '"countyFips":"047"',
#   '"statePopulation":39512223',
#   '"countyPopulation":277680',
#   '"confirmed":9033',
#   '"confirmedPopulation":3253.0250648228175',
#   '"deaths":145'],
#  ['"stateFips":"06"',
#   '"countyFips":"049"',
#   '"statePopulation":39512223',
#   '"countyPopulation":8841',
#   '"confirmed":27',
#   '"confirmedPopulation":305.39531727180184',
#   '"deaths":0'],
#  ['"stateFips":"06"',
#   '"countyFips":"051"',
#   '"statePopulation":39512223',
#   '"countyPopulation":14444',
#   '"confirmed":169',
#   '"confirmedPopulation":1170.0360011077262',
#   '"deaths":2'],
#  ['"stateFips":"06"',
#   '"countyFips":"053"',
#   '"statePopulation":39512223',
#   '"countyPopulation":434061',
#   '"confirmed":10219',
#   '"confirmedPopulation":2354.277394191139',
#   '"deaths":74'],
#  ['"stateFips":"06"',
#   '"countyFips":"055"',
#   '"statePopulation":39512223',
#   '"countyPopulation":137744',
#   '"confirmed":1734',
#   '"confirmedPopulation":1258.8570101057032',
#   '"deaths":13'],
#  ['"stateFips":"06"',
#   '"countyFips":"057"',
#   '"statePopulation":39512223',
#   '"countyPopulation":99755',
#   '"confirmed":543',
#   '"confirmedPopulation":544.3336173625382',
#   '"deaths":7'],
#  ['"stateFips":"06"',
#   '"countyFips":"059"',
#   '"statePopulation":39512223',
#   '"countyPopulation":3175692',
#   '"confirmed":54118',
#   '"confirmedPopulation":1704.1325166294464',
#   '"deaths":1281'],
#  ['"stateFips":"06"',
#   '"countyFips":"061"',
#   '"statePopulation":39512223',
#   '"countyPopulation":398329',
#   '"confirmed":3628',
#   '"confirmedPopulation":910.8048874171852',
#   '"deaths":49'],
#  ['"stateFips":"06"',
#   '"countyFips":"063"',
#   '"statePopulation":39512223',
#   '"countyPopulation":18807',
#   '"confirmed":50',
#   '"confirmedPopulation":265.85845695751584',
#   '"deaths":0'],
#  ['"stateFips":"06"',
#   '"countyFips":"065"',
#   '"statePopulation":39512223',
#   '"countyPopulation":2470546',
#   '"confirmed":59934',
#   '"confirmedPopulation":2425.94147204707',
#   '"deaths":1231'],
#  ['"stateFips":"06"',
#   '"countyFips":"067"',
#   '"statePopulation":39512223',
#   '"countyPopulation":1552058',
#   '"confirmed":22855',
#   '"confirmedPopulation":1472.560948108898',
#   '"deaths":430'],
#  ['"stateFips":"06"',
#   '"countyFips":"069"',
#   '"statePopulation":39512223',
#   '"countyPopulation":62808',
#   '"confirmed":1358',
#   '"confirmedPopulation":2162.144949687938',
#   '"deaths":11'],
#  ['"stateFips":"06"',
#   '"countyFips":"071"',
#   '"statePopulation":39512223',
#   '"countyPopulation":2180085',
#   '"confirmed":55671',
#   '"confirmedPopulation":2553.6160287328244',
#   '"deaths":962'],
#  ['"stateFips":"06"',
#   '"countyFips":"073"',
#   '"statePopulation":39512223',
#   '"countyPopulation":3338330',
#   '"confirmed":47791',
#   '"confirmedPopulation":1431.5840555008044',
#   '"deaths":794'],
#  ['"stateFips":"06"',
#   '"countyFips":"075"',
#   '"statePopulation":39512223',
#   '"countyPopulation":881549',
#   '"confirmed":11360',
#   '"confirmedPopulation":1288.640790245352',
#   '"deaths":107'],
#  ['"stateFips":"06"',
#   '"countyFips":"077"',
#   '"statePopulation":39512223',
#   '"countyPopulation":762148',
#   '"confirmed":20485',
#   '"confirmedPopulation":2687.798170434089',
#   '"deaths":470'],
#  ['"stateFips":"06"',
#   '"countyFips":"079"',
#   '"statePopulation":39512223',
#   '"countyPopulation":283111',
#   '"confirmed":3685',
#   '"confirmedPopulation":1301.609616016333',
#   '"deaths":31'],
#  ['"stateFips":"06"',
#   '"countyFips":"081"',
#   '"statePopulation":39512223',
#   '"countyPopulation":766573',
#   '"confirmed":10126',
#   '"confirmedPopulation":1320.9439935922605',
#   '"deaths":152'],
#  ['"stateFips":"06"',
#   '"countyFips":"083"',
#   '"statePopulation":39512223',
#   '"countyPopulation":446499',
#   '"confirmed":9249',
#   '"confirmedPopulation":2071.4492081729186',
#   '"deaths":115'],
#  ['"stateFips":"06"',
#   '"countyFips":"085"',
#   '"statePopulation":39512223',
#   '"countyPopulation":1927852',
#   '"confirmed":21605',
#   '"confirmedPopulation":1120.677313403726',
#   '"deaths":330'],
#  ['"stateFips":"06"',
#   '"countyFips":"087"',
#   '"statePopulation":39512223',
#   '"countyPopulation":273213',
#   '"confirmed":2481',
#   '"confirmedPopulation":908.082704702924',
#   '"deaths":12'],
#  ['"stateFips":"06"',
#   '"countyFips":"089"',
#   '"statePopulation":39512223',
#   '"countyPopulation":180080',
#   '"confirmed":953',
#   '"confirmedPopulation":529.2092403376278',
#   '"deaths":22'],
#  ['"stateFips":"06"',
#   '"countyFips":"091"',
#   '"statePopulation":39512223',
#   '"countyPopulation":3005',
#   '"confirmed":6',
#   '"confirmedPopulation":199.66722129783693',
#   '"deaths":0'],
#  ['"stateFips":"06"',
#   '"countyFips":"093"',
#   '"statePopulation":39512223',
#   '"countyPopulation":43539',
#   '"confirmed":167',
#   '"confirmedPopulation":383.5641608672684',
#   '"deaths":0'],
#  ['"stateFips":"06"',
#   '"countyFips":"095"',
#   '"statePopulation":39512223',
#   '"countyPopulation":447643',
#   '"confirmed":6520',
#   '"confirmedPopulation":1456.5178054833875',
#   '"deaths":71'],
#  ['"stateFips":"06"',
#   '"countyFips":"097"',
#   '"statePopulation":39512223',
#   '"countyPopulation":494336',
#   '"confirmed":7668',
#   '"confirmedPopulation":1551.171672708441',
#   '"deaths":122'],
#  ['"stateFips":"06"',
#   '"countyFips":"099"',
#   '"statePopulation":39512223',
#   '"countyPopulation":550660',
#   '"confirmed":16628',
#   '"confirmedPopulation":3019.6491482947736',
#   '"deaths":368'],
#  ['"stateFips":"06"',
#   '"countyFips":"101"',
#   '"statePopulation":39512223',
#   '"countyPopulation":96971',
#   '"confirmed":1748',
#   '"confirmedPopulation":1802.6007775520518',
#   '"deaths":11'],
#  ['"stateFips":"06"',
#   '"countyFips":"103"',
#   '"statePopulation":39512223',
#   '"countyPopulation":65084',
#   '"confirmed":605',
#   '"confirmedPopulation":929.5679429660132',
#   '"deaths":6'],
#  ['"stateFips":"06"',
#   '"countyFips":"105"',
#   '"statePopulation":39512223',
#   '"countyPopulation":12285',
#   '"confirmed":16',
#   '"confirmedPopulation":130.24013024013024',
#   '"deaths":0'],
#  ['"stateFips":"06"',
#   '"countyFips":"107"',
#   '"statePopulation":39512223',
#   '"countyPopulation":466195',
#   '"confirmed":16399',
#   '"confirmedPopulation":3517.6267441735754',
#   '"deaths":265'],
#  ['"stateFips":"06"',
#   '"countyFips":"109"',
#   '"statePopulation":39512223',
#   '"countyPopulation":54478',
#   '"confirmed":230',
#   '"confirmedPopulation":422.1887734498329',
#   '"deaths":4'],
#  ['"stateFips":"06"',
#   '"countyFips":"111"',
#   '"statePopulation":39512223',
#   '"countyPopulation":846006',
#   '"confirmed":12943',
#   '"confirmedPopulation":1529.8945870360258',
#   '"deaths":153'],
#  ['"stateFips":"06"',
#   '"countyFips":"113"',
#   '"statePopulation":39512223',
#   '"countyPopulation":220500',
#   '"confirmed":2847',
#   '"confirmedPopulation":1291.156462585034',
#   '"deaths":55'],
#  ['"stateFips":"06"',
#   '"countyFips":"115"',
#   '"statePopulation":39512223',
#   '"countyPopulation":78668',
#   '"confirmed":1188',
#   '"confirmedPopulation":1510.1438958661718',
#   '"deaths":9']]

# %%
with open('most_updated.csv', 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerows(csv_table)
