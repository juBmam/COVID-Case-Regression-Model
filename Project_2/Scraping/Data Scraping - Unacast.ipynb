# %%
from bs4 import BeautifulSoup
import requests
from IPython.core.display import display, HTML

# %%
url = 'https://www.unacast.com/covid19/social-distancing-scoreboard?view=state&fips=06'

response = requests.get(url)
page = response.text
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- Last Published: Fri Oct 02 2020 21:40:05 GMT+0000 (Coordinated Universal Time) -->
# <html data-wf-domain="www.unacast.com" data-wf-page="5e767aa7e6465965a3f14283" data-wf-site="5dc3e2af6a906d9cc232e1bc" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Covid-19 Social Distancing Scoreboard â Unacast
#   </title>
#   <meta content="Social distancing is seen as the most effective way of slowing the spread of the virus causing COVID-19, and is strongly advised by the World Health Organization and the CDC. At Unacast, we wanted to understand which areas of the country are best at exhibiting social distancing behavior. Our hope is that these insights will empower organizations and companies to understand and measure social distancing initiatives and ultimately, save lives." name="description"/>
#   <meta content="Covid-19 Social Distancing Scoreboard â Unacast" property="og:title"/>
#   <meta content="Social distancing is seen as the most effective way of slowing the spread of the virus causing COVID-19, and is strongly advised by the World Health Organization and the CDC. At Unacast, we wanted to understand which areas of the country are best at exhibiting social distancing behavior. Our hope is that these insights will empower organizations and companies to understand and measure social distancing initiatives and ultimately, save lives." property="og:description"/>
#   <meta content="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5e871b20ef36111c52654627_Open-Graph-Image-1200x630-covid-19.png" property="og:image"/>
#   <meta content="Covid-19 Social Distancing Scoreboard â Unacast" property="twitter:title"/>
#   <meta content="Social distancing is seen as the most effective way of slowing the spread of the virus causing COVID-19, and is strongly advised by the World Health Organization and the CDC. At Unacast, we wanted to understand which areas of the country are best at exhibiting social distancing behavior. Our hope is that these insights will empower organizations and companies to understand and measure social distancing initiatives and ultimately, save lives." property="twitter:description"/>
#   <meta content="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5e871b20ef36111c52654627_Open-Graph-Image-1200x630-covid-19.png" property="twitter:image"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="GCKCEVSfuR7Y-vNPefFOJpmZ8gYPkAyaOzf-ozhfTGQ" name="google-site-verification"/>
#   <link href="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/css/unacast.webflow.98eea6407.min.css" rel="stylesheet" type="text/css"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    WebFont.load({  google: {    families: ["Hind:300,regular,500,600,700"]  }});
#   </script>
#   <!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" type="text/javascript"></script><![endif]-->
#   <script type="text/javascript">
#    !function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);
#   </script>
#   <link href="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc3e2af6a906d865c32e399_favicon-32x32.png" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc3e2af6a906dba9e32e21d_android-chrome-256x256.png" rel="apple-touch-icon"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <!-- Cookie Consent and prior blocking of cookies/tracking implemented via Google Tag Manager - https://www.osano.com/cookieconsent/documentation/javascript-api/ -->
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-55WBW76');
#   </script>
#   <!-- End Google Tag Manager -->
#   <link href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css" rel="stylesheet" type="text/css"/>
#   <style>
#    textarea,
#   input.text,
#   input[type="text"],
#   input[type="button"],
#   input[type="submit"],
#   .input-checkbox {
#     -webkit-appearance: none;
#   }
#   textarea,
#   input.text,
#   input[type="text"],
#   .input-checkbox {
#     border-radius: 0;
#   }
#   </style>
#   <style>
#    .navbar-link.has-children {
#   	background-position: calc(100% - 20px) 50% !important;
#   }
# 	.section-details-box-features .section-details-box-feature:last-child {
#   	border-right: none;
#   }
#   .blog-landing-post-item {
#   	flex-basis: calc(25% - 30px);
#   }
#   @media screen and (min-width: 992px) {
#     .steps-line {
#       height: calc(100% - 150px);
#     }
#     .flex-column.story {
#       flex-basis: calc(50% - 40px);
#     }
#
#     .flex-container .flex-column.remaining-space {
#       flex-basis: calc(43% - ((100vw - (100vw - 100%)) - 1200px) / 2 );
#     }
#     .flex-container.contact-content-wrapper {
#       flex-basis: calc(1200px * 0.748);
#     }
#     .flex-container .flex-column.contact-content-outer-column {
#     	flex-basis: calc(( 100% - ((100vw - (100vw - 100%)) - 1200px) / 2 ) - 310px);
#     }
# 	}
#   </style>
#   <!--<link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css"/>
# -->
#   <style>
#    ul.hs-error-msgs {
#     margin-top: -25px;
#     margin-bottom: 10px;
#     padding-left: 0px;
#     list-style: none;
#   }
#
#   .hs-error-msgs label.hs-error-msg {
#   	font-size: 14px;
#     line-height: 1.4;
#   }
#
#   .hs-input {
#   	border: none none solid;
#     border-color: #000;
#     width: 100% !important;
#     max-width: none;
#   }
#   .light .hs-input {
#   	border-color: #fff;
#   }
#   fieldset.form-columns-2 .input, fieldset.form-columns-1 .input {
#     margin: 0 !important;
#   }
#   @media screen and (min-width: 992px) {
#     .form-columns-2 > div:first-child {
#       padding-right: 10px;
#     }
#     .form-columns-2 > div:last-child {
#       padding-left: 10px;
#     }
#   }
#
#   input.hs-button.primary.large {
# 	display: inline-block;
#     margin-right: 15px;
#     margin-bottom: 20px;
#     padding: 8px 30px 6px;
#     border-radius: 5px;
#     background-color: #000;
#     color: #fff;
#     font-weight: 600;
#     text-decoration: none;
#     border: none;
#     margin-top: 30px;
#     cursor: pointer;
#   }
#   input.hs-button.primary.large:hover {
#       background: #222;
#   }
#
#   .light input.hs-button.primary.large {
#   	background-color: #ff8000;
#   }
#   .light input.hs-button.primary.large:hover {
#   	background-color: #ec6800;
#   }
#
#   .hs-input::-webkit-input-placeholder {
#     color: #333;
#   }
#   .hs-input:-ms-input-placeholder {
#     color: #333;
#   }
#   .hs-input::-ms-input-placeholder {
#     color: #333;
#   }
#   .hs-input::placeholder {
#     color: #333;
#   }
#
#   .light .hs-input::-webkit-input-placeholder {
#     color: #e2e2e2;
#   }
#   .light .hs-input:-ms-input-placeholder {
#     color: #e2e2e2;
#   }
#   .light .hs-input::-ms-input-placeholder {
#     color: #e2e2e2;
#   }
#   .light .hs-input::placeholder {
#     color: #e2e2e2;
#   }
#
#   label {
#   	display: none;
#   }
#
#   label.hs-error-msg {
#   	display: block;
#   }
#   </style>
#   <style>
#    .scoreboard-container iframe {
#    border: 0;
#    height: 100%;
#    left: 0;
#    position: absolute;
#    top: 0;
#    width: 100%;
# }
#
# /* 4x3 Aspect Ratio */
# .scoreboard-container-4x3 {
#   padding-top: 75%;
# }
#   </style>
#  </head>
#  <body>
#   <div class="section top-banner signup" id="top-banner">
#    <div class="flex-container">
#     <div class="flex-column top-banner-newsletter-text">
#      <h2 class="top-banner-newsletter-heading">
#       <span class="h1-orange-emphasize">
#        Sign up
#       </span>
#       for location data insights
#      </h2>
#      <p class="top-banner-newsletter-paragraph">
#       Human mobility insights is constantly changing! Sign up here for our newsletter to stay in the loop.
#      </p>
#     </div>
#     <div class="flex-column fill form">
#      <div class="light w-embed w-script">
#       <!--[if lte IE 8]>
# <script charset="utf-8" type="text/javascript" src="//js.hsforms.net/forms/v2-legacy.js"></script>
# <![endif]-->
#       <script charset="utf-8" src="//js.hsforms.net/forms/v2.js" type="text/javascript">
#       </script>
#       <script>
#        hbspt.forms.create({
# 	portalId: "2931123",
# 	formId: "91325dd7-e0f3-4eec-8d31-6f16440afc51"
# });
#       </script>
#       <style>
#        ul.hs-error-msgs {
#    display: none !important;
#   }
#       </style>
#      </div>
#     </div>
#    </div>
#    <div class="signup-banner-close-button" data-w-id="7e6efc51-00d9-330f-e832-d1452eeb6979">
#     <img alt="Icon x close" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc3e2af6a906d672d32e42e_close-out.svg"/>
#    </div>
#   </div>
#   <div class="site-header">
#    <div class="navbar w-nav" data-animation="default" data-collapse="medium" data-duration="400" role="banner">
#     <div class="navbar-container w-container">
#      <a class="navbar-logo-container w-nav-brand" href="/">
#       <img alt="Unacast logo" loading="lazy" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc40333dc6c0cd3ccf9407e_unacast-logo-black-dot_uc_orange-rgb%402x.png" width="145"/>
#      </a>
#      <nav class="navbar-menu-container w-nav-menu" role="navigation">
#       <div class="dropdown-trigger w-dropdown" data-delay="0" data-hover="1">
#        <div class="navbar-link has-children w-dropdown-toggle" data-menu="covid19">
#         <a class="navbar-dropdown-main-menu-link w-inline-block" href="/covid19">
#          <div>
#           COVID-19 Toolkit
#          </div>
#         </a>
#        </div>
#        <nav class="navbar-dropdown w-dropdown-list">
#         <a aria-current="page" class="dropdown-link w-dropdown-link w--current" href="/covid19/social-distancing-scoreboard">
#          Social Distancing Scoreboard
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/covid19/covid-19-retail-impact-scoreboard">
#          Retail Impact Scoreboard
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/covid19/covid-19-migration-patterns">
#          Migration Patterns
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/covid19/covid-19-neighborhood-insights">
#          Neighborhood Insights
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/covid19/custom-data">
#          Custom Data Analysis &amp; Curated Data Sets
#         </a>
#        </nav>
#       </div>
#       <div class="dropdown-trigger w-dropdown" data-delay="0" data-hover="1">
#        <div class="navbar-link has-children w-dropdown-toggle" data-menu="industries">
#         <div>
#          Industries
#         </div>
#        </div>
#        <nav class="navbar-dropdown w-dropdown-list">
#         <a class="dropdown-link w-dropdown-link" href="/industries/retail">
#          Retail
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/industries/real-estate">
#          Real Estate
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/industries/marketing">
#          Marketing
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/industries/travel-tourism">
#          Travel &amp; Tourism
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/industries/government-municipalities">
#          Government &amp;Â Municipalities
#         </a>
#        </nav>
#       </div>
#       <div class="dropdown-trigger w-dropdown" data-delay="0" data-hover="1">
#        <div class="navbar-link has-children w-dropdown-toggle" data-menu="solutions" id="mainNavSolutions">
#         <div>
#          Solutions
#         </div>
#        </div>
#        <nav class="navbar-dropdown w-dropdown-list">
#         <a class="dropdown-link w-dropdown-link" href="/solutions/human-mobility-insights">
#          Human Mobility Insights
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/solutions/data-feeds">
#          Data Feeds
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/solutions/unacast-turbine">
#          Location Processing Platform
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/solutions/report-studio">
#          Report Studio
#         </a>
#        </nav>
#       </div>
#       <div class="dropdown-trigger w-dropdown" data-delay="0" data-hover="1">
#        <div class="navbar-link has-children w-dropdown-toggle" data-menu="resources" id="mainNavResources">
#         <div>
#          Resources
#         </div>
#        </div>
#        <nav class="navbar-dropdown w-dropdown-list">
#         <a class="dropdown-link w-dropdown-link" href="/blog">
#          Blog
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/insights-guides">
#          White Papers
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/videos">
#          Videos
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/methodology">
#          Methodology
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/data-for-good">
#          Data for Good
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/press-releases">
#          Press Releases
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/category/product-release-notes">
#          Product Release Notes
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/resources/how-accurate-is-unacast-data">
#          Our Data
#         </a>
#        </nav>
#       </div>
#       <div class="dropdown-trigger w-dropdown" data-delay="0" data-hover="1">
#        <div class="navbar-link has-children w-dropdown-toggle" data-menu="privacy" id="mainNavPrivacy">
#         <div>
#          Privacy
#         </div>
#        </div>
#        <nav class="navbar-dropdown w-dropdown-list">
#         <a class="dropdown-link w-dropdown-link" href="/privacy">
#          Privacy Statement &amp; Policy
#         </a>
#         <a class="dropdown-link w-dropdown-link" href="/opt-out">
#          Opt Out
#         </a>
#        </nav>
#       </div>
#       <a class="navbar-link w-nav-link" href="/about">
#        About
#       </a>
#       <a class="button navbar-link w-nav-link" href="/contact">
#        Contact Us
#       </a>
#       <a class="search-link-block w-inline-block" data-w-id="d804bd15-30e1-994f-f056-a3f8572f3e08" href="#">
#        <img alt="Search icon
# " class="search-icon" loading="lazy" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5e7ee510a7eca17b918c2c2a_search.svg"/>
#       </a>
#      </nav>
#      <div class="mobile-nav-and-search">
#       <a class="search-link-block mobile w-inline-block" data-w-id="5918077c-c04a-5a5f-4ba6-59f3a27a7859" href="#">
#        <img alt="Search icon
# " class="search-icon" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5e7ee510a7eca17b918c2c2a_search.svg"/>
#       </a>
#       <div class="menu-button w-nav-button">
#        <div class="w-icon-nav-menu">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="search-container">
#     <h2 class="search-heading">
#      What are you looking for?
#     </h2>
#     <form action="/search" class="search-form w-form">
#      <input class="search-input w-input" id="search-input" maxlength="256" name="query" required="" type="search"/>
#      <input class="search-button w-button" type="submit" value="Search"/>
#     </form>
#    </div>
#   </div>
#   <div class="hero-section solutions">
#    <div class="hero-content-wrapper">
#     <div class="flex-container sd">
#      <div class="flex-column hero-content-wrapper">
#       <div class="before-title-hero">
#        <img alt="Hexagon" class="hexagon-icon hero" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc403326a906dfa123419eb_polygon.svg"/>
#        <a class="before-heading-link w-inline-block" href="/covid19">
#         <div class="before-title-text">
#          Covid-19 Toolkit
#         </div>
#        </a>
#       </div>
#       <h1 class="solutions-hero-heading">
#        Social Distancing Scoreboard
#       </h1>
#       <p class="hero-intro-3">
#        According to the World Health Organization and the CDC, social distancing is currently the most effective way to slow the spread of COVID-19. We created this interactive Scoreboard, updated daily, to empower organizations to measure and understand the efficacy of social distancing initiatives at the local level.
#        <strong>
#         <br/>
#        </strong>
#       </p>
#       <div class="w-dyn-list">
#        <div class="w-dyn-items" role="list">
#         <div class="flex-container w-dyn-item" role="listitem">
#          <p class="hero-intro-3 strong">
#           Please scroll down and join the 4.4 million people (and counting) who have explored this data â the more we all understand, the more lives we can save together.
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="hero-cta-buttons-container">
#        <div class="button transparent dropdown hero w-dropdown" data-delay="0" data-hover="">
#         <div class="hero-dropdown-toggle w-dropdown-toggle">
#          <div class="hero-dropdown-icon w-icon-dropdown-toggle">
#          </div>
#          <div>
#           On this page
#          </div>
#         </div>
#         <nav class="hero-dropdown-list w-dropdown-list">
#          <a class="dropdown-link w-dropdown-link" href="#scoreboard">
#           Interactive Social Distancing Scoreboard
#          </a>
#          <a class="dropdown-link w-dropdown-link" href="#scoreboard-update-summary">
#           Scoreboard Update Summary
#          </a>
#          <a class="dropdown-link hide w-dropdown-link" href="#scoring-methodology">
#           Scoring Methodology
#          </a>
#          <a class="dropdown-link w-dropdown-link" href="#methodology">
#           Methodology
#          </a>
#          <a class="dropdown-link w-dropdown-link" href="#additional-covid-19-tools">
#           Additional COVID-19 Location Data Tools
#          </a>
#          <a class="dropdown-link w-dropdown-link" href="#targeted-data-for-your-organization">
#           Targeted Data for Your Organization
#          </a>
#          <a class="dropdown-link w-dropdown-link" href="#get-started">
#           Talk to our Location Data Experts
#          </a>
#         </nav>
#        </div>
#       </div>
#      </div>
#      <div class="flex-column hero-content-wrapper not-relative report-studio-header">
#       <div class="covid-19-example-report-stack hero">
#        <div class="sd-hero-image _2">
#        </div>
#        <div class="sd-hero-image _1">
#        </div>
#        <a class="sd-hero-image _3 w-inline-block" href="#scoreboard">
#         <img alt="Graphic - COVID-19 Social Distancing Dashboard" loading="lazy" sizes="(max-width: 767px) 289.290771484375px, (max-width: 991px) 330.9154052734375px, 40vw" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5e878043bebe7d2975f8aba9_covid-19-social-distancing-scoreboard.png" srcset="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5e878043bebe7d2975f8aba9_covid-19-social-distancing-scoreboard-p-500.png 500w, https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5e878043bebe7d2975f8aba9_covid-19-social-distancing-scoreboard.png 800w"/>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section class="section dark relative less-top-padding" id="scoreboard">
#    <div class="container centered">
#     <h2>
#      Compare your community's
#      <span class="h1-orange-emphasize">
#       social distancing activity
#      </span>
#      to its activity prior to COVID-19
#      <br/>
#     </h2>
#    </div>
#    <div class="scoreboard-container hide w-embed w-script">
#     <!-- <div class='tableauPlaceholder' id='viz1585602494206' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;So&#47;SocialDistancingScoreboard&#47;Dashboard&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='SocialDistancingScoreboard&#47;Dashboard' /><param name='tabs' value='no' /><param name='toolbar' value='no' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;So&#47;SocialDistancingScoreboard&#47;Dashboard&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1585602494206');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1300px';vizElement.style.height='900px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1300px';vizElement.style.height='900px';} else { vizElement.style.width='1300px';vizElement.style.height='900px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script> -->
#    </div>
#    <div class="scoreboard-container w-embed w-iframe">
#     <iframe id="scoreboard_iframe" src="https://covid19-scoreboard.unacast.com/">
#     </iframe>
#    </div>
#    <div class="container centered top-margin even-more">
#     <h3>
#      Get easy access to sample data through one of our partners
#     </h3>
#     <div class="buttons-wrapper center">
#      <a class="button margin-both w-inline-block" href="https://aws.amazon.com/marketplace/seller-profile?id=0bd950b3-0732-427d-95a8-244a4af07c44" target="_blank">
#       <img alt="" class="logo-button-image" sizes="189.1875px" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5f35691972cfa95c7a4479ca_product-icon_AWS-Data-Exchange_lockup_horizontal_white.png" srcset="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5f35691972cfa95c7a4479ca_product-icon_AWS-Data-Exchange_lockup_horizontal_white-p-500.png 500w, https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5f35691972cfa95c7a4479ca_product-icon_AWS-Data-Exchange_lockup_horizontal_white.png 516w"/>
#      </a>
#      <a class="button margin-both w-inline-block" href="https://unacast.maps.arcgis.com/home/index.html" target="_blank">
#       <img alt="" class="logo-button-image" height="28" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5f356bdda833763d9de9ba8b_esri-logo.svg" width="112"/>
#      </a>
#      <a class="button transparent margin-both" href="#get-started">
#       Talk to our experts
#      </a>
#     </div>
#    </div>
#   </section>
#   <div class="section light-gray less-bottom-padding" id="scoreboard-update-summary">
#    <div class="flex-container top-align">
#     <div class="flex-column _33p _20pad-right">
#      <h2>
#       Scoreboard update summary
#      </h2>
#     </div>
#     <div class="flex-column _65p fill">
#      <div class="flex-column flex">
#       <div class="container-hexline nopad half">
#        <h3 class="h3-small-medium tight-bottom">
#         Online Schema Now Available
#         <br/>
#        </h3>
#        <p class="paragraph-medium">
#         Curious about exactly what data is included in the Social Distancing set?
#         <a href="https://www.unacast.com/covid19/docs/schema-for-covid-19-social-distancing-scoreboard">
#          View the full schema here
#         </a>
#         â it includes state- and county-level data for both the pro bono and extended tiers.
#         <br/>
#        </p>
#       </div>
#       <div class="container-hexline nopad half">
#        <h3 class="h3-small-medium tight-bottom">
#         Easy Data Integration
#         <br/>
#        </h3>
#        <p class="paragraph-medium">
#         Our Social Distancing Scoreboard data can be easily delivered upon request and is available at varying granularities.
#         <a href="mailto:info@unacast.com">
#          Contact us
#         </a>
#         to learn more.
#         <br/>
#        </p>
#       </div>
#      </div>
#      <div class="flex-column flex">
#       <div class="container-hexline nopad half">
#        <h3 class="h3-small-medium tight-bottom">
#         Download a Sample
#         <br/>
#        </h3>
#        <p class="paragraph-medium">
#         Take the data for a test drive! Our sample, dated from April 17, includes every county in the states of Washington and Florida â
#         <a href="https://go.unacast.com/hubfs/CSVs/sds-v3-sample-county.csv.gz">
#          click here to download a CSV flat file
#         </a>
#         .
#         <br/>
#        </p>
#       </div>
#       <div class="container-hexline nopad half">
#        <h3 class="h3-small-medium tight-bottom">
#         International Social Distancing Data
#         <br/>
#        </h3>
#        <p class="paragraph-medium">
#         By popular demand, we're expanding our data beyond the United States to countries all over the globe.
#         <a href="mailto:info@unacast.com">
#          Contact us
#         </a>
#         for details on where quality data is currently available.
#         <br/>
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="section" id="scoring-methodology">
#    <h2 class="solutions-small-section-heading">
#     Scoring Methodology
#     <br/>
#    </h2>
#    <p class="intro-paragraph wide">
#     Social Distancing is a complex behavior, and thatâs why weâve expanded our scoring to three different metrics, all of which are averaged to create the overall Social Distancing Score for each state or county.
#     <br/>
#    </p>
#    <div class="flex-container top-align narrow">
#     <div class="flex-column _33p _20pad-right">
#      <div class="container-hexline nopad">
#       <h3 class="h3-small-medium tight-bottom">
#        Percent Change in Average Distance Traveled
#        <br/>
#       </h3>
#       <div class="paragraph-medium-orangebold w-richtext">
#        <p>
#         <strong>
#          A:
#         </strong>
#         &gt;70% decrease
#         <br/>
#         <span>
#          <strong>
#           B:
#          </strong>
#         </span>
#         55-70% decrease
#         <br/>
#         <span>
#          <strong>
#           C:
#          </strong>
#         </span>
#         40-55% decrease
#         <br/>
#         <span>
#          <strong>
#           D:
#          </strong>
#         </span>
#         25-40% decrease
#         <br/>
#         <span>
#          <strong>
#           F:
#          </strong>
#         </span>
#         &lt;25% decrease or increase
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="flex-column _33p _20pad">
#      <div class="container-hexline nopad">
#       <h3 class="h3-small-medium tight-bottom">
#        Percent Change in Non-essential Visitation
#        <br/>
#       </h3>
#       <div class="paragraph-medium-orangebold w-richtext">
#        <p>
#         <strong>
#          A:
#         </strong>
#         &gt;70% decrease
#         <br/>
#         <span>
#          <strong>
#           B:
#          </strong>
#         </span>
#         65-70% decrease
#         <br/>
#         <span>
#          <strong>
#           C:
#          </strong>
#         </span>
#         60-65% decrease
#         <br/>
#         <span>
#          <strong>
#           D:
#          </strong>
#         </span>
#         55-60% decrease
#         <br/>
#         <span>
#          <strong>
#           F:
#          </strong>
#         </span>
#         &lt;55% decrease or increase
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="flex-column _33p _20pad">
#      <div class="container-hexline nopad">
#       <h3 class="h3-small-medium tight-bottom">
#        Decrease in Human Encounters (Compared to National Baseline)
#        <br/>
#       </h3>
#       <div class="paragraph-medium-orangebold w-richtext">
#        <p>
#         <strong>
#          A:
#         </strong>
#         &gt;94%
#         <strong>
#          <br/>
#          B:
#         </strong>
#         82%-94%
#         <strong>
#          <br/>
#          C:
#         </strong>
#         74%-82%
#         <strong>
#          <br/>
#          D:
#         </strong>
#         40%-74%
#         <strong>
#          <br/>
#          F:
#         </strong>
#         &lt;40%
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section class="section dark" id="methodology">
#    <div class="flex-container start">
#     <div class="flex-column fill padding-right">
#      <h2>
#       Driven by data science to maximize actionability
#      </h2>
#      <p class="w600">
#       Unacast's robust team of data scientists and PhDs focuses on data accuracy to ensure that our partners and clients get high-quality insights that reflect real-world events.
#      </p>
#      <div class="buttons-wrapper more-top-margin">
#       <a class="button" href="#get-started">
#        Talk to an expert
#       </a>
#       <a class="button transparent" href="mailto:covid19toolkit@unacast.com?subject=Feedback%3A%20COVID-19%20Toolkit%20">
#        Send your feedback
#       </a>
#       <a class="button transparent" href="mailto:press@unacast.com?subject=Press%3A%20COVID-19%20Toolkit%20">
#        Press contact
#       </a>
#      </div>
#     </div>
#     <div class="flex-column _480">
#      <ul class="polygon-list w-list-unstyled" role="list">
#       <li class="polygon-list-item">
#        <p class="polygon-list-paragraph" href="https://coronadatascraper.com/#home">
#         Please consult our blog for a deep dive into our
#         <strong>
#          â
#         </strong>
#         <a href="https://www.unacast.com/post/rounding-out-the-social-distancing-scoreboard" target="_blank">
#          <strong>
#           updated methodology
#          </strong>
#         </a>
#         (old methodology can be found
#         <a href="https://www.unacast.com/post/the-unacast-social-distancing-scoreboard">
#          <strong>
#           here
#          </strong>
#         </a>
#         ).
#         <br/>
#        </p>
#       </li>
#       <li class="polygon-list-item">
#        <p class="polygon-list-paragraph">
#         Data on reported cases of COVID-19 is sourced from:
#         <br/>
#         â¢
#         <a href="https://coronadatascraper.com/#timeseries.csv">
#          <strong>
#           Corona Data Scraper
#          </strong>
#         </a>
#         (for county-level data prior to March 22)
#         <br/>
#         â¢ The
#         <a href="https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports">
#          <strong>
#           Johns Hopkins Github Repository
#          </strong>
#         </a>
#         (for county-level data beginning March 22 and all state-level data)
#         <br/>
#        </p>
#       </li>
#       <li class="polygon-list-item">
#        <p class="polygon-list-paragraph">
#         Despite the urgency around COVID-19, privacy remains one of Unacastâs highest priorities. Please consult
#         <a href="https://www.unacast.com/privacy">
#          <strong>
#           the privacy section of our website
#          </strong>
#         </a>
#         if you wish to
#         <a href="https://www.unacast.com/privacy#statement">
#          <strong>
#           learn more
#          </strong>
#         </a>
#         or
#         <a href="https://www.unacast.com/opt-out">
#          <strong>
#           opt out
#          </strong>
#         </a>
#         .
#         <br/>
#        </p>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </section>
#   <div class="section" id="additional-covid-19-tools">
#    <h2 class="solutions-small-section-heading">
#     Additional COVID-19Â LOCATIONÂ DATAÂ TOOLS
#     <br/>
#    </h2>
#    <div class="options-container top-pad-extra">
#     <div class="options-item">
#      <div class="image-canvas covid-19-list-view">
#       <img alt="Retail Impact Scoreboard screenshot
# " class="image-fill" loading="lazy" sizes="(max-width: 479px) 85vw, (max-width: 767px) 43vw, (max-width: 991px) 45vw, 21vw" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ece08c341265739e20a564d_unacast-retail-impact-scoreboard.png" srcset="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ece08c341265739e20a564d_unacast-retail-impact-scoreboard-p-500.png 500w, https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ece08c341265739e20a564d_unacast-retail-impact-scoreboard-p-800.png 800w, https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ece08c341265739e20a564d_unacast-retail-impact-scoreboard.png 1288w"/>
#      </div>
#      <h3 class="options-heading fixed-height">
#       Retail Impact Scoreboard
#      </h3>
#      <p class="options-paragraph darker fixed-height">
#       For any given place of interest (such as airports, stadiums, and retail stores), compare traffic patterns to news cycles to determine which fluctuations are the result of COVID-19.
#      </p>
#      <a class="button center wide w-button" href="/covid19/covid-19-retail-impact-scoreboard">
#       Try the Scoreboard
#      </a>
#     </div>
#     <div class="options-item">
#      <div class="image-canvas covid-19-list-view">
#       <img alt="" class="image-fill" loading="lazy" sizes="(max-width: 479px) 85vw, (max-width: 767px) 43vw, (max-width: 991px) 45vw, 21vw" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ed9e696e93ebb7551358c8a_unacast-origin-destination-flux-dashboard.png" srcset="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ed9e696e93ebb7551358c8a_unacast-origin-destination-flux-dashboard-p-500.png 500w, https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ed9e696e93ebb7551358c8a_unacast-origin-destination-flux-dashboard-p-800.png 800w, https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ed9e696e93ebb7551358c8a_unacast-origin-destination-flux-dashboard.png 1282w"/>
#      </div>
#      <h3 class="options-heading fixed-height">
#       Migration Patterns
#      </h3>
#      <p class="options-paragraph darker fixed-height">
#       Measure changes in the human mobility patterns of larger areas, such as movement within neighborhoods or between states.
#      </p>
#      <a class="button center wide w-button" href="/covid19/covid-19-migration-patterns">
#       Try the Scoreboard
#      </a>
#     </div>
#     <div class="options-item">
#      <div class="image-canvas covid-19-list-view">
#       <img alt="Unacast Covid19 Recovery Tool" class="image-fill" loading="lazy" sizes="(max-width: 479px) 85vw, (max-width: 767px) 43vw, (max-width: 991px) 45vw, 21vw" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ece0dee0b0e390a91548ae8_unacast-covid-19-recovery-tool.png" srcset="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ece0dee0b0e390a91548ae8_unacast-covid-19-recovery-tool-p-500.png 500w, https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ece0dee0b0e390a91548ae8_unacast-covid-19-recovery-tool.png 1000w"/>
#      </div>
#      <h3 class="options-heading fixed-height">
#       Neigborhood Insights
#      </h3>
#      <p class="options-paragraph darker fixed-height">
#       Easily explore and visualize recovery insights for any area of interest, down to the CBG level.
#       <br/>
#      </p>
#      <a class="button center wide w-button" href="/covid19/covid-19-neighborhood-insights">
#       Try the Dashboard
#      </a>
#     </div>
#     <div class="options-item">
#      <div class="image-canvas covid-19-list-view">
#       <img alt="" class="image-fill half-size dimmed" loading="lazy" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5ef100967b190c3890be556b_construction-24px.svg"/>
#      </div>
#      <h3 class="options-heading fixed-height">
#       Custom Data Analysis &amp; Curated Data Sets
#      </h3>
#      <p class="options-paragraph darker fixed-height">
#       Pre-defined correlations and insights for organizations that need fast, user-friendly solutions tailored to their businesses.
#      </p>
#      <a class="button center wide w-button" href="/contact">
#       Contact us
#      </a>
#     </div>
#    </div>
#   </div>
#   <div class="section dark" id="targeted-data-for-your-organization">
#    <h2 class="solutions-small-section-heading">
#     TARGETED DATA FoR YOUr ORGANIZATION
#     <br/>
#    </h2>
#    <p class="intro-paragraph wide">
#     The dashboards on our website provide broad overviews of COVID-19 foot traffic patterns. Using our Real World GraphÂ® we can provide specific insights and greater depth of detail for any industry, brand, or venue.
#     <br/>
#    </p>
#    <div class="options-container">
#     <div class="options-item">
#      <div class="options-icon-container">
#       <img alt="Icon - Curated data sets" class="options-image" loading="lazy" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dccd1d95095d01c50e4d48a_delivery_curateddatasets.svg"/>
#      </div>
#      <h3 class="options-heading">
#       Data Packages
#      </h3>
#      <p class="options-paragraph">
#       Access our Venue or Neighborhood Packages via API or importable files.
#      </p>
#      <a class="button center w-button" href="/contact">
#       Contact us
#      </a>
#     </div>
#     <div class="options-item">
#      <div class="options-icon-container">
#       <img alt="Icon - Strategic Recommendations" class="options-image" loading="lazy" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dccd1d9137dcba37d2598e2_delivery_strategicrecommendations.svg"/>
#      </div>
#      <h3 class="options-heading">
#       Report Studio
#      </h3>
#      <p class="options-paragraph">
#       Get a report tailored for activity in your POI or neighborhood.
#      </p>
#      <a class="button center w-button" href="/solutions/report-studio">
#       Learn more
#      </a>
#     </div>
#     <div class="options-item">
#      <div class="options-icon-container extra-bottom-padding">
#       <img alt="Icon - Visualizations" class="options-image" loading="lazy" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dccd1d905abdc09604b8fd4_delivery_visualizations.svg"/>
#      </div>
#      <h3 class="options-heading">
#       Insights Dashboard
#      </h3>
#      <p class="options-paragraph">
#       Visualize insights on a browser-based interface using a unique login.
#       <br/>
#      </p>
#      <div class="small-caps-link disabled">
#       Coming Soon
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="section light-gray" id="get-started">
#    <div class="flex-container narrow steps-form">
#     <div class="flex-column middle relative top-aligned">
#      <ul class="steps-list w-list-unstyled" role="list">
#       <li class="steps-list-item">
#        <div class="steps-list-bullet">
#         1
#        </div>
#        <p class="steps-list-paragraph">
#         <strong>
#          Get in touch
#         </strong>
#         to discover how location data can help your organization measure the impact of the virus.
#         <br/>
#        </p>
#       </li>
#       <li class="steps-list-item">
#        <div class="steps-list-bullet">
#         2
#        </div>
#        <p class="steps-list-paragraph">
#         <strong>
#          Chat with our team
#         </strong>
#         to determine data strategies to tackle your particular challenges.
#         <br/>
#        </p>
#       </li>
#       <li class="steps-list-item">
#        <div class="steps-list-bullet">
#         3
#        </div>
#        <p class="steps-list-paragraph">
#         <strong>
#          Use high-quality, curated data and human mobility insights
#         </strong>
#         to create reaction strategies and identify recovery signals.
#         <br/>
#        </p>
#       </li>
#      </ul>
#      <div class="steps-line">
#      </div>
#     </div>
#     <div class="flex-column middle">
#      <h2>
#       What can human mobility insights do to combat COVID-19?
#       <br/>
#      </h2>
#      <p class="cta-paragraph">
#       Reach out to find out! One of our experts will contact you shortly.
#       <br/>
#      </p>
#      <div class="w-embed w-script">
#       <!--[if lte IE 8]>
# <script charset="utf-8" type="text/javascript" src="//js.hsforms.net/forms/v2-legacy.js"></script>
# <![endif]-->
#       <script charset="utf-8" src="//js.hsforms.net/forms/v2.js" type="text/javascript">
#       </script>
#       <script>
#        hbspt.forms.create({
# 	portalId: "2931123",
# 	formId: "c3cfcb57-bbe2-4339-a517-557960f5daba"
# });
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="site-footer">
#    <div class="flex-container footer">
#     <a class="footer-unacast-badge w-inline-block" href="/">
#      <img alt="Unacast logo badge" loading="lazy" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc3e2af6a906dceb532e551_unacast-symbol-uc_orange-rgb.png" width="55"/>
#     </a>
#     <div class="flex-column footer-column narrow first">
#      <div class="footer-nav-parent">
#       <a class="footer-nav-parent-link" href="/about">
#        About
#       </a>
#      </div>
#      <div class="footer-nav-parent">
#       <a class="footer-nav-parent-link" href="/privacy">
#        Privacy
#       </a>
#      </div>
#      <div class="footer-nav-parent">
#       <a class="footer-nav-parent-link" href="https://careers.unacast.com" target="_blank">
#        Careers
#       </a>
#      </div>
#      <div class="footer-nav-parent">
#       <a class="footer-nav-parent-link" href="/contact">
#        Contact
#       </a>
#      </div>
#      <div class="social-bar">
#       <a class="social-media-link w-inline-block" href="https://twitter.com/unacast" target="_blank">
#        <img alt="Twitter" class="social-media-icon twitter" loading="lazy" src="https://global-uploads.webflow.com/57ea8395fbbf45e8476570d0/5aaebd21e8d43c5cea2fa608_twitter.svg"/>
#       </a>
#       <a class="social-media-link w-inline-block" href="https://www.facebook.com/unacast/" target="_blank">
#        <img alt="Facebook" class="social-media-icon" loading="lazy" src="https://global-uploads.webflow.com/57ea8395fbbf45e8476570d0/5aaebd45c776cc1f868ec50d_facebook.svg"/>
#       </a>
#       <a class="social-media-link w-inline-block" href="https://no.linkedin.com/company/unacast" target="_blank">
#        <img alt="LinkedIn" class="social-media-icon" loading="lazy" src="https://global-uploads.webflow.com/57ea8395fbbf45e8476570d0/5aaebd4caf978312f8241633_linked-in.svg" width="18"/>
#       </a>
#      </div>
#     </div>
#     <div class="flex-column footer-column wide">
#      <div class="footer-nav-parent">
#       <a class="footer-nav-parent-link" href="/covid19">
#        COVID-19 Toolkit
#       </a>
#      </div>
#      <ul class="footer-nav-children w-list-unstyled" role="list">
#       <li class="footer-nav-child">
#        <a aria-current="page" class="footer-nav-child-link w--current" href="/covid19/social-distancing-scoreboard">
#         Social Distancing Scoreboard
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/covid19/covid-19-retail-impact-scoreboard">
#         Retail Impact Scoreboard
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/covid19/covid-19-migration-patterns">
#         Migration Patterns
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/covid19/covid-19-neighborhood-insights">
#         Neigborhood Insights
#         <br/>
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/covid19/custom-data">
#         Custom Data Analysis &amp; Curated Data Sets
#         <br/>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="flex-column footer-column">
#      <div class="footer-nav-parent">
#       <a class="footer-nav-parent-link" href="/#industries">
#        Industries
#       </a>
#      </div>
#      <ul class="footer-nav-children w-list-unstyled" role="list">
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/industries/retail">
#         Retail
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/industries/real-estate">
#         Real Estate
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/industries/marketing">
#         Marketing
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/industries/travel-tourism">
#         Travel &amp; Tourism
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/industries/government-municipalities">
#         Government &amp; Municipalities
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="flex-column footer-column">
#      <div class="footer-nav-parent">
#       <a class="footer-nav-parent-link" href="/#solutions">
#        Solutions
#       </a>
#      </div>
#      <ul class="footer-nav-children w-list-unstyled" role="list">
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/solutions/human-mobility-insights">
#         Human Mobility Insights
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/solutions/data-feeds">
#         Data Feeds
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/solutions/unacast-turbine">
#         Unacast Turbine
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/solutions/report-studio">
#         Report Studio
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="flex-column footer-column">
#      <div class="footer-nav-parent">
#       <div class="footer-nav-parent-link plain-text">
#        Resources
#       </div>
#      </div>
#      <ul class="footer-nav-children w-list-unstyled" role="list">
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/blog">
#         Blog
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/insights-guides">
#         Insights Guides
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/videos">
#         Videos
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/methodology">
#         Methodology
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/data-for-good">
#         Data for Good
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/press-releases">
#         Press Releases
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/category/product-release-notes">
#         Product Release Notes
#        </a>
#       </li>
#       <li class="footer-nav-child">
#        <a class="footer-nav-child-link" href="/resources/how-accurate-is-unacast-data">
#         Our Data
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="flex-column footer-column wide">
#      <div class="flex-column footer-column contact">
#       <p>
#        <strong class="semi-bold">
#         New York
#        </strong>
#        <br/>
#        245 Fifth Avenue
#        <br/>
#        Suite 1101
#        <br/>
#        New York, NY 10016
#        <br/>
#        United States
#       </p>
#      </div>
#      <div class="flex-column footer-column contact">
#       <p>
#        <strong class="semi-bold">
#         Oslo
#        </strong>
#        <br/>
#        Karl Johans Gate 21
#        <br/>
#        0159 Oslo,
#        <br/>
#        Norway
#       </p>
#      </div>
#     </div>
#    </div>
#    <div class="flex-container footer-logos hide">
#     <a class="footer-logo-link w-inline-block" href="https://www.iab.com/" target="_blank">
#      <img alt="Logo IAB" class="footer-logo" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc8be1c52f69f4b08943e20_iab-member-logo.svg"/>
#     </a>
#     <a class="footer-logo-link w-inline-block" href="http://www.mmaglobal.com/" target="_blank">
#      <img alt="Logo MMA" class="footer-logo" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc8bdeec19d43c851086d4a_mma-member-logo.svg"/>
#     </a>
#     <a class="footer-logo-link w-inline-block" href="https://iapp.org/" target="_blank">
#      <img alt="Logo IAPP" class="footer-logo" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc8bdda11520e16f9ef6446_iapp-member-logo.svg"/>
#     </a>
#     <a class="footer-logo-link w-inline-block" href="http://thelbma.com/" target="_blank">
#      <img alt="Logo LMBA" class="footer-logo" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc8be3a6ade6304a0ff0f90_lbma-member-logo.svg"/>
#     </a>
#     <a class="footer-logo-link w-inline-block" href="http://thelsa.org/" target="_blank">
#      <img alt="Logo LSA" class="footer-logo" src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/5dc8be0fd6571e35eec85da9_lsa-member-logo.svg"/>
#     </a>
#    </div>
#    <div class="flex-container footer-links">
#     <a class="footer-link" href="/opt-out">
#      Do Not Sell My Information
#     </a>
#    </div>
#    <div class="flex-container copyright">
#     <p class="footer-copyright">
#      Â© 2020 Unacast All Rights Reserved.
#     </p>
#    </div>
#   </div>
#   <div class="embeds">
#    <div class="w-embed w-script">
#     <script type="text/javascript">
#      var Webflow = Webflow || [];
#   Webflow.push(function () {
#
# 		$('.w-dropdown-link.w--current').closest('.w-dropdown').addClass('current');
#
#     $('.slides-container').each(function () {
#
# 			var arrowsContainer = $(this).siblings('.slick-slides-nav');
#
#       $(this).slick({
#         centerMode: true,
#         slidesToShow: 3,
#         infinite: true,
#         prevArrow: arrowsContainer.find('.slick-arrow.slick-prev'),
# 				nextArrow: arrowsContainer.find('.slick-arrow.slick-next'),
#         responsive: [
#           {
#             breakpoint: 991,
#             settings: {
#               slidesToShow: 1,
#               centerPadding: '0px'
#             }
#           },
#           {
#             breakpoint: 600,
#             settings: {
#               slidesToShow: 1,
#               centerPadding: '0px'
#             }
#           }
#         ]
#       });
#     });
#
#   });
#     </script>
#    </div>
#    <div class="w-embed">
#     <style>
#      /* cookie policy - hide on mobile to avoid covering up the screen */
#   @media screen and (max-width: 700px) {
#     .cc-revoke { display: none !important; }
#   }
#
#   /* general styles */
# 	.navbar-link.has-children {
#   	background-position: calc(100% - 20px) 50% !important;
#   }
# 	.section-details-box-features .section-details-box-feature:last-child {
#   	border-right: none;
#   }
#   .blog-landing-post-item {
#   	flex-basis: calc(25% - 30px);
#   }
#   @media screen and (min-width: 992px) {
#     .steps-line {
#       height: calc(100% - 150px);
#     }
#     .flex-column.story {
#       flex-basis: calc(50% - 40px);
#     }
#
#     .flex-container .flex-column.remaining-space {
#       flex-basis: calc(43% - ((100vw - (100vw - 100%)) - 1200px) / 2 );
#     }
#     .flex-container.contact-content-wrapper {
#       flex-basis: calc(1200px * 0.748);
#     }
#     .flex-container .flex-column.contact-content-outer-column {
#     	flex-basis: calc(( 100% - ((100vw - (100vw - 100%)) - 1200px) / 2 ) - 310px);
#     }
# 	}
#     </style>
#     <!--<link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css"/>
# -->
#     <style>
#      ul.hs-error-msgs {
#     margin-top: -25px;
#     margin-bottom: 10px;
#     padding-left: 0px;
#     list-style: none;
#   }
#
#   .hs-error-msgs label.hs-error-msg {
#   	font-size: 14px;
#     line-height: 1.4;
#   }
#
#   .hs-input {
#   	border: none none solid;
#     border-color: #000;
#     width: 100% !important;
#     max-width: none;
#   }
#   .light .hs-input {
#   	border-color: #fff;
#   }
#   fieldset.form-columns-2 .input, fieldset.form-columns-1 .input {
#     margin: 0 !important;
#   }
#   @media screen and (min-width: 992px) {
#     .form-columns-2 > div:first-child {
#       padding-right: 10px;
#     }
#     .form-columns-2 > div:last-child {
#       padding-left: 10px;
#     }
#   }
#
#   input.hs-button.primary.large {
# 		display: inline-block;
#     margin-right: 15px;
#     margin-bottom: 20px;
#     padding: 8px 30px 6px;
#     border-radius: 5px;
#     background-color: #000;
#     color: #fff;
#     font-weight: 600;
#     text-decoration: none;
#     border: none;
#     margin-top: 30px;
#     cursor: pointer;
#   }
#   input.hs-button.primary.large:hover {
#       background: #222;
#   }
#
#   .light input.hs-button.primary.large {
#   	background-color: #ff8000;
#   }
#   .light input.hs-button.primary.large:hover {
#   	background-color: #ec6800;
#   }
#
#   .hs-input::-webkit-input-placeholder {
#     color: #333;
#   }
#   .hs-input:-ms-input-placeholder {
#     color: #333;
#   }
#   .hs-input::-ms-input-placeholder {
#     color: #333;
#   }
#   .hs-input::placeholder {
#     color: #333;
#   }
#
#   .light .hs-input::-webkit-input-placeholder {
#     color: #e2e2e2;
#   }
#   .light .hs-input:-ms-input-placeholder {
#     color: #e2e2e2;
#   }
#   .light .hs-input::-ms-input-placeholder {
#     color: #e2e2e2;
#   }
#   .light .hs-input::placeholder {
#     color: #e2e2e2;
#   }
#
#   label {
#   	display: none;
#   }
#
#   label.hs-error-msg {
#   	display: block;
#   }
#   .top-banner.signup fieldset.form-columns-2 {
#   	flex: 1 0 auto;
#     padding-right: 30px;
#   }
#   .top-banner.signup form.hs-form {
#   	display: flex;
#     align-items: center;
#   }
#   .top-banner.signup fieldset.form-columns-2 .hs-input {
#     	margin-bottom: 0px;
#   }
#
#   @media screen and (max-width: 991px) {
#   	.top-banner.signup form.hs-form {
#     	flex-wrap: wrap;
#     }
#     .top-banner.signup fieldset.form-columns-2 {
#     	flex-basis: 100%;
#       padding-right: 0;
#     }
#     .top-banner.signup fieldset.form-columns-2 .hs-form-field {
#     	width: 100%;
#     }
#     .top-banner.signup fieldset.form-columns-2 .hs-input {
#     	margin-bottom: 20px;
#     }
#   }
#   .top-banner.signup .light input.hs-button.primary.large {
# 		display: inline-block;
# 		margin: 0;
#     padding: 8px 30px 6px;
#     border-radius: 5px;
#     background-color: transparent;
#     color: #ff8000;
#     border: 1px solid #ff8000;
#     font-weight: 600;
#     text-decoration: none;
#     cursor: pointer;
#   }
#   .top-banner.signup .light input.hs-button.primary.large:hover {
#       background: #222;
#   }
#     </style>
#    </div>
#   </div>
#   <script crossorigin="anonymous" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" src="https://d3e54v103j8qbb.cloudfront.net/js/jquery-3.5.1.min.dc5e7f18c8.js?site=5dc3e2af6a906d9cc232e1bc" type="text/javascript">
#   </script>
#   <script src="https://global-uploads.webflow.com/5dc3e2af6a906d9cc232e1bc/js/webflow.e3bac8049.js" type="text/javascript">
#   </script>
#   <!--[if lte IE 9]><script src="//cdnjs.cloudflare.com/ajax/libs/placeholders/3.0.2/placeholders.min.js"></script><![endif]-->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-55WBW76" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Slick carousel -->
#   <script src="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var Webflow = Webflow || [];
#   Webflow.push(function () {
#
#     $('.search-link-block').click(function(){
#       setTimeout(function(){
#       	$('#search-input').focus();
#       },300);
#     });
#
#     /* close dropdown with links inside on click */
#     $(".w-dropdown-list a").click(function(){
#       $(".w-dropdown-list").removeClass("w--open");
#     });
#
#   });
#   </script>
#   <script>
#    var iframe = document.getElementById('scoreboard_iframe');
# 	iframe.src = iframe.src;
#
#   function getJsonFromUrl(url) {
#     if(!url)
#       var search = location.search;
#     var query = url.substr(1);
#     var result = {};
#     query.split("&").forEach(function(part) {
#       var item = part.split("=");
#       result[item[0]] = decodeURIComponent(item[1]);
#     });
#     return result;
#   }
#
#   const scoreboard_url = "https://covid19-scoreboard.unacast.com";
#   const scoreboard_iframe = document.getElementById("scoreboard_iframe").contentWindow;
#   function sendMessage() {
#   	var query = window.location.search;
#     var parsedResult = getJsonFromUrl(query)
#     if (
#       parsedResult["view"] &&
#       parsedResult["fips"] &&
#       !Array.isArray(parsedResult.view) &&
#       !Array.isArray(parsedResult.fips)
#     ) {
#       scoreboard_iframe.postMessage(
#         window.location.search,
#         scoreboard_url
#       );
#     }
#   }
#
#   // Trigger initial post message when someone visits e.g. https://www.unacast.com/covid19/social-distancing-scoreboard/?view=state&fips=20
#   window.onload = sendMessage;
#
#   // Adds eventListener to change the Webflow URL when the url parameters in the iFrame changes
#   window.addEventListener("message", receiveMessage);
#   function receiveMessage(event) {
#     console.log("receiveMessage -> event", event);
#     if (
#       event.origin === scoreboard_url
#     ) {
#       var newurl =
#           window.location.protocol +
#           "//" +
#           window.location.host +
#           window.location.pathname +
#           event.data;
#       window.history.pushState({ path: newurl }, "", newurl);
#     }
#   }
#   </script>
#  </body>
# </html>

# %%
script_soup = [row for row in soup.find_all('div')]

# %%
script_soup[0]
# Out:
# <div id="react-entry-point">
# <div class="_dash-loading">
#         Loading...
#     </div>
# </div>
