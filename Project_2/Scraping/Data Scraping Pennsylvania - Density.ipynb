# %%
from bs4 import BeautifulSoup
import requests
import csv
from IPython.core.display import display, HTML

# %%
url = 'http://www.usa.com/rank/pennsylvania-state--population-density--county-rank.htm'

response = requests.get(url)

response.status_code

soup = BeautifulSoup(response.text, "lxml")

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <title>
#    Pennsylvania Population Density County Rank
#   </title>
#   <meta content="Pennsylvania Population Density County Rank" name="description"/>
#   <script src="rank-js.php" type="text/javascript">
#   </script>
#   <script src="search-form.js" type="text/javascript">
#   </script>
#   <link href="http://www.usa.com/rank/pennsylvania-state--population-density--county-rank.htm" rel="canonical"/>
#   <link href="/g.css" rel="stylesheet" type="text/css"/>
#   <script src="/js/common.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div id="h">
#    <div id="hinlogo">
#     <a href="/">
#      <img alt="USA.com" height="46" src="/img/USA.png" width="193"/>
#     </a>
#    </div>
#    <div class="topsearchc">
#     <div class="topsearchhead">
#      Local Data Search
#     </div>
#     <div class="search_div">
#      <table>
#       <form action="/locations.php" method="get" name="tsm">
#        <tr>
#         <td>
#          <input name="Submit" onclick="return tyhOnSubmit();" style="width:1px;height:1px;color:#fff;padding:0px;" type="submit" value="Submit"/>
#          <input autocomplete="off" name="q" onblur="searchinputprocess(0);" onfocus="searchinputprocess(1);" type="text" value="Search State, County, City, Zip Code, or Area Code"/>
#         </td>
#         <td>
#          <a href="#" onclick="document.tsm.submit();">
#           <div class="navsearch">
#           </div>
#          </a>
#         </td>
#        </tr>
#       </form>
#      </table>
#     </div>
#     <div class="tyhshadow" id="tyhshadow">
#      <div class="tyhoutput" id="tyhoutput">
#      </div>
#     </div>
#     <script>
#      tyhInit();
#     </script>
#    </div>
#   </div>
#   <div>
#   </div>
#   <div id="mo">
#    <div id="m">
#     <div id="hcontent">
#      <div class="small">
#       <a href="/">
#        USA.com
#       </a>
#       /
#       <a href="/rank/">
#        Ranks
#       </a>
#       /
#       <a href="pennsylvania-state--population-density--county-rank.htm">
#        Pennsylvania Population Density County Rank
#       </a>
#      </div>
#      <h1>
#       Pennsylvania Population Density County Rank
#      </h1>
#      <p>
#       A total of 67 results found.
#       <span id="highlightOnTheTop">
#       </span>
#       <span id="showonmaptext">
#        <b>
#         <a href="#" onclick="loadFullMap();gObj('showonmaptext').style.display='none';return false;">
#          Show Results on Map
#         </a>
#        </b>
#       </span>
#       .
#      </p>
#      <div id="mapwrapper" style="display:none;">
#       <div id="mapoutput">
#       </div>
#       <div id="map_canvas2" style="height: 500px;">
#       </div>
#      </div>
#      <table width="648">
#       <tr valign="bottom">
#        <td width="48">
#         <b>
#          Rank
#         </b>
#        </td>
#        <td width="150">
#         <b>
#          <a href="#" onclick="rsf('sb','ASC');">
#           Population Density ▼
#          </a>
#         </b>
#        </td>
#        <td width="450">
#         <b>
#          County / Population
#         </b>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         1.
#        </td>
#        <td>
#         10,839.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-philadelphia">
#          Philadelphia, PA
#         </a>
#         / 1,546,920
#        </td>
#       </tr>
#       <tr>
#        <td>
#         2.
#        </td>
#        <td>
#         2,942.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-delaware">
#          Delaware, PA
#         </a>
#         / 560,775
#        </td>
#       </tr>
#       <tr>
#        <td>
#         3.
#        </td>
#        <td>
#         1,661.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-montgomery">
#          Montgomery, PA
#         </a>
#         / 809,372
#        </td>
#       </tr>
#       <tr>
#        <td>
#         4.
#        </td>
#        <td>
#         1,651.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-allegheny">
#          Allegheny, PA
#         </a>
#         / 1,229,172
#        </td>
#       </tr>
#       <tr>
#        <td>
#         5.
#        </td>
#        <td>
#         1,018.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-lehigh">
#          Lehigh, PA
#         </a>
#         / 354,537
#        </td>
#       </tr>
#       <tr>
#        <td>
#         6.
#        </td>
#        <td>
#         1,007.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-bucks">
#          Bucks, PA
#         </a>
#         / 626,205
#        </td>
#       </tr>
#       <tr>
#        <td>
#         7.
#        </td>
#        <td>
#         792.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-northampton">
#          Northampton, PA
#         </a>
#         / 299,225
#        </td>
#       </tr>
#       <tr>
#        <td>
#         8.
#        </td>
#        <td>
#         667.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-chester">
#          Chester, PA
#         </a>
#         / 506,422
#        </td>
#       </tr>
#       <tr>
#        <td>
#         9.
#        </td>
#        <td>
#         535.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-lancaster">
#          Lancaster, PA
#         </a>
#         / 526,839
#        </td>
#       </tr>
#       <tr>
#        <td>
#         10.
#        </td>
#        <td>
#         483.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-dauphin">
#          Dauphin, PA
#         </a>
#         / 269,946
#        </td>
#       </tr>
#       <tr>
#        <td>
#         11.
#        </td>
#        <td>
#         481.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-york">
#          York, PA
#         </a>
#         / 438,052
#        </td>
#       </tr>
#       <tr>
#        <td>
#         12.
#        </td>
#        <td>
#         477.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-berks">
#          Berks, PA
#         </a>
#         / 413,016
#        </td>
#       </tr>
#       <tr>
#        <td>
#         13.
#        </td>
#        <td>
#         460.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-lackawanna">
#          Lackawanna, PA
#         </a>
#         / 214,023
#        </td>
#       </tr>
#       <tr>
#        <td>
#         14.
#        </td>
#        <td>
#         435.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-cumberland">
#          Cumberland, PA
#         </a>
#         / 239,420
#        </td>
#       </tr>
#       <tr>
#        <td>
#         15.
#        </td>
#        <td>
#         383.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-beaver">
#          Beaver, PA
#         </a>
#         / 170,124
#        </td>
#       </tr>
#       <tr>
#        <td>
#         16.
#        </td>
#        <td>
#         372.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-lebanon">
#          Lebanon, PA
#         </a>
#         / 135,184
#        </td>
#       </tr>
#       <tr>
#        <td>
#         17.
#        </td>
#        <td>
#         353.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-luzerne">
#          Luzerne, PA
#         </a>
#         / 320,392
#        </td>
#       </tr>
#       <tr>
#        <td>
#         18.
#        </td>
#        <td>
#         350.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-westmoreland">
#          Westmoreland, PA
#         </a>
#         / 362,587
#        </td>
#       </tr>
#       <tr>
#        <td>
#         19.
#        </td>
#        <td>
#         272.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-monroe">
#          Monroe, PA
#         </a>
#         / 168,342
#        </td>
#       </tr>
#       <tr>
#        <td>
#         20.
#        </td>
#        <td>
#         247.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-lawrence">
#          Lawrence, PA
#         </a>
#         / 89,859
#        </td>
#       </tr>
#       <tr>
#        <td>
#         21.
#        </td>
#        <td>
#         241.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-washington">
#          Washington, PA
#         </a>
#         / 208,157
#        </td>
#       </tr>
#       <tr>
#        <td>
#         22.
#        </td>
#        <td>
#         240.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-blair">
#          Blair, PA
#         </a>
#         / 126,708
#        </td>
#       </tr>
#       <tr>
#        <td>
#         23.
#        </td>
#        <td>
#         232.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-butler">
#          Butler, PA
#         </a>
#         / 185,034
#        </td>
#       </tr>
#       <tr>
#        <td>
#         24.
#        </td>
#        <td>
#         203.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-cambria">
#          Cambria, PA
#         </a>
#         / 140,835
#        </td>
#       </tr>
#       <tr>
#        <td>
#         25.
#        </td>
#        <td>
#         197.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-northumberland">
#          Northumberland, PA
#         </a>
#         / 94,294
#        </td>
#       </tr>
#       <tr>
#        <td>
#         26.
#        </td>
#        <td>
#         196.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-franklin">
#          Franklin, PA
#         </a>
#         / 151,517
#        </td>
#       </tr>
#       <tr>
#        <td>
#         27.
#        </td>
#        <td>
#         194.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-adams">
#          Adams, PA
#         </a>
#         / 101,566
#        </td>
#       </tr>
#       <tr>
#        <td>
#         28.
#        </td>
#        <td>
#         188.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-schuylkill">
#          Schuylkill, PA
#         </a>
#         / 147,146
#        </td>
#       </tr>
#       <tr>
#        <td>
#         29.
#        </td>
#        <td>
#         179.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-erie">
#          Erie, PA
#         </a>
#         / 280,132
#        </td>
#       </tr>
#       <tr>
#        <td>
#         30.
#        </td>
#        <td>
#         169.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-fayette">
#          Fayette, PA
#         </a>
#         / 135,376
#        </td>
#       </tr>
#       <tr>
#        <td>
#         31.
#        </td>
#        <td>
#         169.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-mercer">
#          Mercer, PA
#         </a>
#         / 115,739
#        </td>
#       </tr>
#       <tr>
#        <td>
#         32.
#        </td>
#        <td>
#         167.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-carbon">
#          Carbon, PA
#         </a>
#         / 64,874
#        </td>
#       </tr>
#       <tr>
#        <td>
#         33.
#        </td>
#        <td>
#         141.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-union">
#          Union, PA
#         </a>
#         / 44,955
#        </td>
#       </tr>
#       <tr>
#        <td>
#         34.
#        </td>
#        <td>
#         140.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-centre">
#          Centre, PA
#         </a>
#         / 156,240
#        </td>
#       </tr>
#       <tr>
#        <td>
#         35.
#        </td>
#        <td>
#         139.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-montour">
#          Montour, PA
#         </a>
#         / 18,475
#        </td>
#       </tr>
#       <tr>
#        <td>
#         36.
#        </td>
#        <td>
#         136.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-columbia">
#          Columbia, PA
#         </a>
#         / 67,089
#        </td>
#       </tr>
#       <tr>
#        <td>
#         37.
#        </td>
#        <td>
#         120.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-snyder">
#          Snyder, PA
#         </a>
#         / 39,922
#        </td>
#       </tr>
#       <tr>
#        <td>
#         38.
#        </td>
#        <td>
#         112.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-mifflin">
#          Mifflin, PA
#         </a>
#         / 46,705
#        </td>
#       </tr>
#       <tr>
#        <td>
#         39.
#        </td>
#        <td>
#         105.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-indiana">
#          Indiana, PA
#         </a>
#         / 88,301
#        </td>
#       </tr>
#       <tr>
#        <td>
#         40.
#        </td>
#        <td>
#         103.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-armstrong">
#          Armstrong, PA
#         </a>
#         / 68,343
#        </td>
#       </tr>
#       <tr>
#        <td>
#         41.
#        </td>
#        <td>
#         100.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-pike">
#          Pike, PA
#         </a>
#         / 56,883
#        </td>
#       </tr>
#       <tr>
#        <td>
#         42.
#        </td>
#        <td>
#         93.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-lycoming">
#          Lycoming, PA
#         </a>
#         / 116,676
#        </td>
#       </tr>
#       <tr>
#        <td>
#         43.
#        </td>
#        <td>
#         84.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-crawford">
#          Crawford, PA
#         </a>
#         / 87,801
#        </td>
#       </tr>
#       <tr>
#        <td>
#         44.
#        </td>
#        <td>
#         82.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-perry">
#          Perry, PA
#         </a>
#         / 45,788
#        </td>
#       </tr>
#       <tr>
#        <td>
#         45.
#        </td>
#        <td>
#         79.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-venango">
#          Venango, PA
#         </a>
#         / 54,265
#        </td>
#       </tr>
#       <tr>
#        <td>
#         46.
#        </td>
#        <td>
#         71.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-somerset">
#          Somerset, PA
#         </a>
#         / 77,011
#        </td>
#       </tr>
#       <tr>
#        <td>
#         47.
#        </td>
#        <td>
#         70.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-clearfield">
#          Clearfield, PA
#         </a>
#         / 81,472
#        </td>
#       </tr>
#       <tr>
#        <td>
#         48.
#        </td>
#        <td>
#         69.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-wyoming">
#          Wyoming, PA
#         </a>
#         / 28,229
#        </td>
#       </tr>
#       <tr>
#        <td>
#         49.
#        </td>
#        <td>
#         69.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-wayne">
#          Wayne, PA
#         </a>
#         / 51,967
#        </td>
#       </tr>
#       <tr>
#        <td>
#         50.
#        </td>
#        <td>
#         68.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-jefferson">
#          Jefferson, PA
#         </a>
#         / 44,935
#        </td>
#       </tr>
#       <tr>
#        <td>
#         51.
#        </td>
#        <td>
#         66.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-greene">
#          Greene, PA
#         </a>
#         / 38,171
#        </td>
#       </tr>
#       <tr>
#        <td>
#         52.
#        </td>
#        <td>
#         64.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-clarion">
#          Clarion, PA
#         </a>
#         / 39,437
#        </td>
#       </tr>
#       <tr>
#        <td>
#         53.
#        </td>
#        <td>
#         63.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-juniata">
#          Juniata, PA
#         </a>
#         / 24,793
#        </td>
#       </tr>
#       <tr>
#        <td>
#         54.
#        </td>
#        <td>
#         53.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-bradford">
#          Bradford, PA
#         </a>
#         / 62,510
#        </td>
#       </tr>
#       <tr>
#        <td>
#         55.
#        </td>
#        <td>
#         51.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-huntingdon">
#          Huntingdon, PA
#         </a>
#         / 45,950
#        </td>
#       </tr>
#       <tr>
#        <td>
#         56.
#        </td>
#        <td>
#         51.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-susquehanna">
#          Susquehanna, PA
#         </a>
#         / 42,708
#        </td>
#       </tr>
#       <tr>
#        <td>
#         57.
#        </td>
#        <td>
#         48.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-bedford">
#          Bedford, PA
#         </a>
#         / 49,332
#        </td>
#       </tr>
#       <tr>
#        <td>
#         58.
#        </td>
#        <td>
#         45.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-warren">
#          Warren, PA
#         </a>
#         / 41,218
#        </td>
#       </tr>
#       <tr>
#        <td>
#         59.
#        </td>
#        <td>
#         44.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-clinton">
#          Clinton, PA
#         </a>
#         / 39,611
#        </td>
#       </tr>
#       <tr>
#        <td>
#         60.
#        </td>
#        <td>
#         43.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-mckean">
#          Mckean, PA
#         </a>
#         / 43,024
#        </td>
#       </tr>
#       <tr>
#        <td>
#         61.
#        </td>
#        <td>
#         37.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-elk">
#          Elk, PA
#         </a>
#         / 31,584
#        </td>
#       </tr>
#       <tr>
#        <td>
#         62.
#        </td>
#        <td>
#         37.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-tioga">
#          Tioga, PA
#         </a>
#         / 42,358
#        </td>
#       </tr>
#       <tr>
#        <td>
#         63.
#        </td>
#        <td>
#         33.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-fulton">
#          Fulton, PA
#         </a>
#         / 14,747
#        </td>
#       </tr>
#       <tr>
#        <td>
#         64.
#        </td>
#        <td>
#         17.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-forest">
#          Forest, PA
#         </a>
#         / 7,649
#        </td>
#       </tr>
#       <tr>
#        <td>
#         65.
#        </td>
#        <td>
#         16.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-potter">
#          Potter, PA
#         </a>
#         / 17,451
#        </td>
#       </tr>
#       <tr>
#        <td>
#         66.
#        </td>
#        <td>
#         14.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-sullivan">
#          Sullivan, PA
#         </a>
#         / 6,400
#        </td>
#       </tr>
#       <tr>
#        <td>
#         67.
#        </td>
#        <td>
#         12.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-pa-cameron">
#          Cameron, PA
#         </a>
#         / 4,939
#        </td>
#       </tr>
#      </table>
#      <p>
#       Please note that we only rank locations with 'Population Density' data. The rank above might not be a complete list. Locations without 'Population Density' data are not listed.
#      </p>
#      <script src="http://maps.google.com/maps/api/js?sensor=false" type="text/javascript">
#      </script>
#      <script>
#       var infowindow;
# var map;
# var showDataFact = 0.2;
# var markers=[];
# var curDataTLat = 0;
# var curDataBLat = 0;
# var curDataLLng = 0;
# var curDataRLng = 0;
# var reboundmap = 1;
#
# var allPlaces = [];
# var placestr = "1|40.0093755|-75.133345|<b># 1.</b><br><a href='r.php?i=30-pa-philadelphia' target='_blank'>Philadelphia, PA / 1,546,920</a><br>10,839.8/sq mi||2|39.9166704|-75.398786|<b># 2.</b><br><a href='r.php?i=30-pa-delaware' target='_blank'>Delaware, PA / 560,775</a><br>2,942.1/sq mi||3|40.2099992|-75.370201|<b># 3.</b><br><a href='r.php?i=30-pa-montgomery' target='_blank'>Montgomery, PA / 809,372</a><br>1,661.3/sq mi||4|40.4689204|-79.980919|<b># 4.</b><br><a href='r.php?i=30-pa-allegheny' target='_blank'>Allegheny, PA / 1,229,172</a><br>1,651.0/sq mi||5|40.6142409|-75.590626|<b># 5.</b><br><a href='r.php?i=30-pa-lehigh' target='_blank'>Lehigh, PA / 354,537</a><br>1,018.1/sq mi||6|40.3368872|-75.10706|<b># 6.</b><br><a href='r.php?i=30-pa-bucks' target='_blank'>Bucks, PA / 626,205</a><br>1,007.0/sq mi||7|40.7527913|-75.307446|<b># 7.</b><br><a href='r.php?i=30-pa-northampton' target='_blank'>Northampton, PA / 299,225</a><br>792.9/sq mi||8|39.9739654|-75.749732|<b># 8.</b><br><a href='r.php?i=30-pa-chester' target='_blank'>Chester, PA / 506,422</a><br>667.0/sq mi||9|40.0419921|-76.250198|<b># 9.</b><br><a href='r.php?i=30-pa-lancaster' target='_blank'>Lancaster, PA / 526,839</a><br>535.5/sq mi||10|40.4125646|-76.792634|<b># 10.</b><br><a href='r.php?i=30-pa-dauphin' target='_blank'>Dauphin, PA / 269,946</a><br>483.6/sq mi||11|39.921839|-76.728446|<b># 11.</b><br><a href='r.php?i=30-pa-york' target='_blank'>York, PA / 438,052</a><br>481.0/sq mi||12|40.4139565|-75.926859|<b># 12.</b><br><a href='r.php?i=30-pa-berks' target='_blank'>Berks, PA / 413,016</a><br>477.1/sq mi||13|41.4402497|-75.609586|<b># 13.</b><br><a href='r.php?i=30-pa-lackawanna' target='_blank'
# 			placeToUse.push(allPlaces[i]);
# 			foundCounter++;
# 			if (foundCounter>150){
# 				foundCounter=-1;
# 				break;
# 			}
# 		}
# 	}
#
# 	if (placeToUse.length>0){
# 		var bounds = new google.maps.LatLngBounds ();
# 		for (var i = 0; i < placeToUse.length; i++) {
# 			var oneplace = placeToUse[i];
# 			var latLng = new google.maps.LatLng(parseFloat(oneplace[1]), parseFloat(oneplace[2]));
# 			bounds.extend(latLng);
# 			var iconCmp = parseInt(oneplace[0]);
# 			if (iconCmp>99) iconCmp = 0;
# 			var marker = new google.maps.Marker({
# 				position: latLng,
# 				map: map,
# 				title: oneplace[0],
# 				icon: new google.maps.MarkerImage(
# 					'/img/n.png',
# 					new google.maps.Size(21, 22),
# 					new google.maps.Point((31*iconCmp), 0)
# 				)
# 			});
#
# 			contInfo = oneplace[3];
# 			(function(i, marker, contInfo) {
# 				google.maps.event.addListener(marker, 'click', function() {
# 					if (!infowindow) {
# 						infowindow = new google.maps.InfoWindow();
# 					}
# 					infowindow.setContent(contInfo);
# 					infowindow.open(map, marker);
# 				});
# 			})(i, marker, contInfo);
# 			markers.push(marker);
# 		}
# 		if (reboundmap==1){
# 			reboundmap=-1;
# 			map.fitBounds(bounds);
# 		}
# 	}
# 	if (foundCounter>0){
# 		document.getElementById("mapoutput").innerHTML = "Full Results. Zoom in to refine. Click icon to show name.";
# 	}else{
# 		document.getElementById("mapoutput").innerHTML = "<font color='Red'>Partial Results</font>. Zoom in to see more. Click icon to show name.";
# 	}
# }
#
# function showOnMap(map, doReload){
# 	var zoom = map.getZoom();
# 	var bounds = map.getBounds();
# 	var southWest = bounds.getSouthWest();
# 	var northEast = bounds.getNorthEast();
#
# 	var latSpan = northEast.lat() - southWest.lat();
# 	var lngSpan = northEast.lng() - southWest.lng();
# 	if (lngSpan<0) lngSpan = lngSpan + 360;
# 	var thisTLat = northEast.lat();
# 	var thisBLat = southWest.lat();
# 	var thisLLng = southWest.lng();
# 	var thisRLng = northEast.lng();
#
# 	if ((doReload==1)||(thisTLat>curDataTLat)||(thisBLat<curDataBLat)||(thisLLng<curDataLLng)||(thisRLng>curDataRLng)){
# 		curDataTLat = northEast.lat() + latSpan*showDataFact;
# 		curDataBLat = southWest.lat() - latSpan*showDataFact;
# 		curDataLLng = southWest.lng() - lngSpan*showDataFact;
# 		curDataRLng = northEast.lng() + lngSpan*showDataFact;
# 		if (reboundmap==-1){
# 			reboundmap = 0;
# 		}else{
# 			clearMarkers();
# 			plotMarkers(curDataTLat, curDataBLat, curDataLLng, curDataRLng);
# 		}
# 	}
# }
# function loadFullMap(){
# 	gObj("mapwrapper").style.display = 'block';
# 	var options = {
# 		zoom: 3,
# 		center: new google.maps.LatLng(40.9042486, -77.828062),
# 		scrollwheel: false,
# 		mapTypeId: google.maps.MapTypeId.ROADMAP
# 	};
# 	map = new google.maps.Map(document.getElementById('map_canvas2'), options);
# 	google.maps.event.addListener(map, 'zoom_changed', function() {
# 		showOnMap(map, 1);
# 	});
# 	google.maps.event.addListener(map, 'bounds_changed', function() {
# 		showOnMap(map, 0);
# 	});
# }
# function clearMarkers() {
# 	if (markers) {
# 		for (i in markers) {
# 			markers[i].setMap(null);
# 		}
# 	}
# 	markers=[];
# }
#      </script>
#      <form action="pennsylvania-state--population-density--county-rank.htm" method="get" name="hsF">
#       <input name="hl" type="hidden" value=""/>
#       <input name="hlst" type="hidden" value=""/>
#       <input name="wist" type="hidden" value=""/>
#       <input name="yr" type="hidden" value=""/>
#       <input name="dis" type="hidden" value=""/>
#       <input name="sb" type="hidden" value="DESC"/>
#       <input name="plow" type="hidden" value=""/>
#       <input name="phigh" type="hidden" value=""/>
#       <input name="ps" type="hidden" value=""/>
#      </form>
#     </div>
#     <div id="hmenu">
#      <script type="text/javascript">
#       <!--
# window.google_analytics_uacct = "UA-12906387-4";
# google_ad_client = "ca-pub-1187797442630842";
# /* USA.com_main_right_300x250 */
# google_ad_slot = "6987722783";
# google_ad_width = 300;
# google_ad_height = 250;
# //-->
#      </script>
#      <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#      </script>
#      <style>
#       border-radius:3px;
# 	border: 1px solid #4fa4c3;
# 	background: #deedf2;
# 	padding: 5px;
#
# .tpcitem{
# 	margin-left:10px;
# 	display:block;
# 	font-size:10px;
# }
# .searchbox{
# 	border-radius:3px;
# 	background: #ecf4f6;
# 	border: 1px solid #1d5895;
# 	margin-top:5px;
# }
# .searchboxhead{
# 	font-size: 16px;
# 	font-weight: bold;
# 	color: #ffffff;
# 	background: #1d5895;
# 	padding: 3px;
# 	font-weight:bold;
# }
# .bigsubmit{
# 	font-size: 14px;
# 	font-weight: bold;
# 	width:100px;
# 	height:30px;
# }
#      </style>
#      <form action="#" method="get" name="rsF">
#       <div class="searchbox">
#        <div class="searchboxhead">
#         Refine Your Ranking
#        </div>
#        <div style="padding-left:4px;">
#         <input name="itemtorank" type="hidden" value=""/>
#         <span id="itemtorankerror">
#         </span>
#         <div id="itemtorankcontent">
#         </div>
#         <br/>
#         <span id="rankingscopeerror">
#         </span>
#         <div class="big">
#          <b>
#           Pick Your Location:
#          </b>
#         </div>
#         <div style="padding-left:5px;">
#          <label for="withinloc">
#           <input checked="" id="withinloc" name="rankingscope" onclick="switchScope('1')" type="radio" value="1"/>
#           Within a Location
#          </label>
#         </div>
#         <div id="withinLocationDiv" style="padding-top:5px;padding-left:31px;">
#          <select name="rankWithin" onchange="changeScope(1,'');">
#           <option value="us">
#            The Entire U.S.
#           </option>
#           <option selected="" value="state">
#            State
#           </option>
#           <option value="metro-area">
#            Metro Area
#           </option>
#           <option value="county">
#            County
#           </option>
#           <option value="city">
#            City
#           </option>
#           <option value="school-district">
#            School District
#           </option>
#           <option value="zip-code">
#            Zip
#           </option>
#          </select>
#          <select id="rankWithin2" name="rankWithin2" onchange="changeScope(2,'');" style="display:none;width:260px;">
#          </select>
#          <select id="rankWithin3" name="rankWithin3" style="display:none;width:260px;">
#          </select>
#         </div>
#         <div style="padding-left:5px;">
#          <label for="withinpoint">
#           <input id="withinpoint" name="rankingscope" onclick="switchScope('0')" type="radio" value="0"/>
#           Rank within a Distance of a Point
#          </label>
#         </div>
#         <div id="withinPointDiv" style="display:none;padding-top:5px;padding-left:26px;">
#          within
#          <input name="ml" size="1" type="text" value=""/>
#          miles of
#          <input name="lc" size="5" type="text" value="pennsylvania-state"/>
#          (e.g. a zip code)
#         </div>
#         <span id="rankoferror">
#         </span>
#         <div style="padding-top:15px;">
#          <span class="big">
#           <b>
#            Rank By:
#           </b>
#          </span>
#         </div>
#         <div style="padding-top:5px;padding-left:15px;">
#          <select name="rankOf" onchange="loadItemsToRank(document.rsF.itemtorank.value);">
#           <option value="state">
#            State
#           </option>
#           <option value="metro-area">
#            Metro Area
#           </option>
#           <option selected="" value="county">
#            County
#           </option>
#           <option value="city">
#            City
#           </option>
#           <option value="school-district">
#            School District
#           </option>
#           <option value="zip-code">
#            Zip
#           </option>
#           <option value="census-tract">
#            Census Tract
#           </option>
#           <option value="block-group">
#            Census Block Group
#           </option>
#           <option value="block">
#            Census Block
#           </option>
#          </select>
#         </div>
#         <div>
#          <div id="datadateDiv" style="padding-top:15px;">
#           <span class="big">
#            <b>
#             Select Date of Data:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <select name="datadate" style="width:270px;">
#             <option value="9000">
#              American Community Survey 2010-2014
#             </option>
#             <option value="8000">
#              U.S. Census 2010
#             </option>
#             <option value="6000">
#              American Community Survey 2008-2012
#             </option>
#             <option value="3000">
#              American Community Survey 2006-2010
#             </option>
#             <option value="2000">
#              American Community Survey 2005-2009
#             </option>
#             <option value="1000">
#              U.S. Census 2000
#             </option>
#            </select>
#           </div>
#          </div>
#          <div id="limitToStateDiv" style="display:none;padding-top:15px;">
#           <span class="big">
#            <b>
#             Limit to the State of:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <select name="limitToState">
#             <option value="">
#              Please Select
#             </option>
#             <option value="AL">
#              Alabama
#             </option>
#             <option value="AK">
#              Alaska
#             </option>
#             <option value="AZ">
#              Arizona
#             </option>
#             <option value="AR">
#              Arkansas
#             </option>
#             <option value="CA">
#              California
#             </option>
#             <option value="CO">
#              Colorado
#             </option>
#             <option value="CT">
#              Connecticut
#             </option>
#             <option value="DE">
#              Delaware
#             </option>
#             <option value="DC">
#              District of Columbia
#             </option>
#             <option value="FL">
#              Florida
#             </option>
#             <option value="GA">
#              Georgia
#             </option>
#             <option value="HI">
#              Hawaii
#             </option>
#             <option value="ID">
#              Idaho
#             </option>
#             <option value="IL">
#              Illinois
#             </option>
#             <option value="IN">
#              Indiana
#             </option>
#             <option value="IA">
#              Iowa
#             </option>
#             <option value="KS">
#              Kansas
#             </option>
#             <option value="KY">
#              Kentucky
#             </option>
#             <option value="LA">
#              Louisiana
#             </option>
#             <option value="ME">
#              Maine
#             </option>
#             <option value="MD">
#              Maryland
#             </option>
#             <option value="MA">
#              Massachusetts
#             </option>
#             <option value="MI">
#              Michigan
#             </option>
#             <option value="MN">
#              Minnesota
#             </option>
#             <option value="MS">
#              Mississippi
#             </option>
#             <option value="MO">
#              Missouri
#             </option>
#             <option value="MT">
#              Montana
#             </option>
#             <option value="NE">
#              Nebraska
#             </option>
#             <option value="NV">
#              Nevada
#             </option>
#             <option value="NH">
#              New Hampshire
#             </option>
#             <option value="NJ">
#              New Jersey
#             </option>
#             <option value="NM">
#              New Mexico
#             </option>
#             <option value="NY">
#              New York
#             </option>
#             <option value="NC">
#              North Carolina
#             </option>
#             <option value="ND">
#              North Dakota
#             </option>
#             <option value="OH">
#              Ohio
#             </option>
#             <option value="OK">
#              Oklahoma
#             </option>
#             <option value="OR">
#              Oregon
#             </option>
#             <option value="PA">
#              Pennsylvania
#             </option>
#             <option value="RI">
#              Rhode Island
#             </option>
#             <option value="SC">
#              South Carolina
#             </option>
#             <option value="SD">
#              South Dakota
#             </option>
#             <option value="TN">
#              Tennessee
#             </option>
#             <option value="TX">
#              Texas
#             </option>
#             <option value="UT">
#              Utah
#             </option>
#             <option value="VT">
#              Vermont
#             </option>
#             <option value="VA">
#              Virginia
#             </option>
#             <option value="WA">
#              Washington
#             </option>
#             <option value="WV">
#              West Virginia
#             </option>
#             <option value="WI">
#              Wisconsin
#             </option>
#             <option value="WY">
#              Wyoming
#             </option>
#            </select>
#           </div>
#          </div>
#          <div style="padding-top:10px;">
#           <span class="big">
#            <b>
#             Limit to Locations with Population:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <input name="poplow" size="3" type="text" value=""/>
#            to
#            <input name="pophigh" size="3" type="text" value=""/>
#            (number only, can be blank)
#           </div>
#          </div>
#         </div>
#         <p align="center">
#          <input class="bigsubmit" onclick="sendForm();return false;" type="submit" value="Submit"/>
#         </p>
#        </div>
#       </div>
#      </form>
#      <script>
#       rankOfChanged = 1;
# loadItemsToRank("population-density",-1);
# switchScope('1');
# highlightScope1='pennsylvania-state';
# highlightScope2='';
# changeScope(1,'');
#      </script>
#      <br/>
#      <div id="hotranking">
#       Popular Rankings
#      </div>
#      <div class="hotranks">
#       <div>
#        <a href="/rank/us--population-growth-rate--state-rank.htm?tag=Fastest+Growing+States+in+U.S.">
#         Fastest
#        </a>
#        /
#        <a href="/rank/us--population-growth-rate--state-rank.htm?sb=ASC&amp;tag=Slowest+Growing+States+in+U.S.">
#         Slowest
#        </a>
#        Growing States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--employed-male-civilian-population-percentage--state-rank.htm?yr=3000&amp;tag=Best+States+in+U.S.+by+%+of+Males+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/us--employed-male-civilian-population-percentage--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Worst+States+in+U.S.+by+%+of+Males+Employed">
#         Worst
#        </a>
#        States in U.S. by % of Males Employed
#       </div>
#       <div>
#        <a href="/rank/us--employed-female-civilian-population-percentage--state-rank.htm?yr=3000&amp;tag=Best+States+in+U.S.+by+%+of+Females+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/us--employed-female-civilian-population-percentage--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Worst+States+in+U.S.+by+%+of+Females+Employed">
#         Worst
#        </a>
#        States in U.S. by % of Females Employed
#       </div>
#       <div>
#        <a href="/rank/us--crime-index--state-rank.htm?tag=Best+States+by+Crime+Rate+in+U.S.">
#         Best
#        </a>
#        /
#        <a href="/rank/us--crime-index--state-rank.htm?sb=DESC&amp;tag=Worst+States+by+Crime+Rate+in+U.S.">
#         Worst
#        </a>
#        States by Crime Rate in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-household-income--state-rank.htm?yr=3000&amp;tag=Richest+States+by+Income+in+U.S.">
#         Richest
#        </a>
#        /
#        <a href="/rank/us--median-household-income--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Poorest+States+by+Income+in+U.S.">
#         Poorest
#        </a>
#        States by Income in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--house-median-value--state-rank.htm?yr=3000&amp;tag=Most+Expensive+Homes+by+State+in+U.S.">
#         Most Expensive
#        </a>
#        /
#        <a href="/rank/us--house-median-value--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Cheapest+Homes+by+State+in+U.S.">
#         Cheapest
#        </a>
#        Homes by State in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--average-education-index--state-rank.htm?yr=3000&amp;tag=Most+Educated+States+in+U.S.">
#         Most
#        </a>
#        /
#        <a href="/rank/us--average-education-index--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Least+Educated+States+in+U.S.">
#         Least
#        </a>
#        Educated States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--total-population--state-rank.htm?tag=Most+Populated+States+in+U.S.">
#         Most
#        </a>
#        /
#        <a href="/rank/us--total-population--state-rank.htm?sb=ASC&amp;tag=Least+Populated+States+in+U.S.">
#         Least
#        </a>
#        Populated States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--land-area--state-rank.htm?tag=Largest+States+by+Area+in+U.S.">
#         Largest
#        </a>
#        /
#        <a href="/rank/us--land-area--state-rank.htm?sb=ASC&amp;tag=Smallest+States+by+Area+in+U.S.">
#         Smallest
#        </a>
#        States by Area in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-household-income--county-rank.htm?tag=Richest+Counties+by+Income+in+U.S.">
#         Richest
#        </a>
#        /
#        <a href="/rank/us--median-household-income--county-rank.htm?sb=ASC&amp;tag=Poorest+Counties+by+Income+in+U.S.">
#         Poorest
#        </a>
#        Counties by Income in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--population-growth-rate--county-rank.htm?tag=Fastest+Growing+Counties+in+U.S.">
#         Fastest
#        </a>
#        /
#        <a href="/rank/us--population-growth-rate--county-rank.htm?sb=ASC&amp;tag=Slowest+Growing+Counties+in+U.S.">
#         Slowest
#        </a>
#        Growing Counties in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--average-education-index--county-rank.htm?yr=3000&amp;tag=Most+Educated+Counties+in+U.S.">
#         Most
#        </a>
#        /
#        <a href="/rank/us--average-education-index--county-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Least+Educated+Counties+in+U.S.">
#         Least
#        </a>
#        Educated Counties in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-age--state-rank.htm?tag=Youngest+States+in+U.S.">
#         Youngest
#        </a>
#        /
#        <a href="/rank/us--median-age--state-rank.htm?sb=DESC&amp;tag=Oldest+States+in+U.S.">
#         Oldest
#        </a>
#        States in U.S.
#       </div>
#       <div>
#        <a href="/rank/us--median-age--county-rank.htm?tag=Youngest+Counties+in+U.S.">
#         Youngest
#        </a>
#        /
#        <a href="/rank/us--median-age--county-rank.htm?sb=DESC&amp;tag=Oldest+Counties+in+U.S.">
#         Oldest
#        </a>
#        Counties in U.S.
#       </div>
#      </div>
#     </div>
#     <div id="clear">
#     </div>
#    </div>
#   </div>
#   <div id="fo">
#    <div id="ftop">
#    </div>
#    <div id="f">
#     <div class="fleft">
#      The
#      <a href="http://www.usa.com">
#       USA.com
#      </a>
#      website and domain are privately owned and are not operated by or affiliated with any government or municipal authority.
#      <br/>
#      © 2020 World Media Group, LLC.
#      <!--(0.0032858848571777)-->
#     </div>
#     <div class="fmenu">
#      <a href="/about-us.php">
#       about us
#      </a>
#      |
#      <a href="/contact-us.php">
#       contact us
#      </a>
#      |
#      <a href="/scam-warning.php">
#       usa.com alerts
#      </a>
#      |
#      <a href="/terms-of-use.php">
#       terms of use
#      </a>
#      |
#      <a href="/privacy-policy.php">
#       privacy policy
#      </a>
#     </div>
#     <div id="clear">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-12906387-4']);
# _gaq.push(['_setDomainName', 'www.usa.com']);
# _gaq.push(['_trackPageview']);
# (function() {
# 	var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# })();
# <tr><td>46.</td><td>71.2/sq mi</td><td><a href="r.php?i=30-pa-somerset">Somerset, PA</a> / 77,011</td></tr>
# <tr><td>47.</td><td>70.6/sq mi</td><td><a href="r.php?i=30-pa-clearfield">Clearfield, PA</a> / 81,472</td></tr>
# <tr><td>48.</td><td>69.7/sq mi</td><td><a href="r.php?i=30-pa-wyoming">Wyoming, PA</a> / 28,229</td></tr>
# <tr><td>49.</td><td>69.2/sq mi</td><td><a href="r.php?i=30-pa-wayne">Wayne, PA</a> / 51,967</td></tr>
# <tr><td>50.</td><td>68.4/sq mi</td><td><a href="r.php?i=30-pa-jefferson">Jefferson, PA</a> / 44,935</td></tr>
# <tr><td>51.</td><td>66.0/sq mi</td><td><a href="r.php?i=30-pa-greene">Greene, PA</a> / 38,171</td></tr>
# <tr><td>52.</td><td>64.7/sq mi</td><td><a href="r.php?i=30-pa-clarion">Clarion, PA</a> / 39,437</td></tr>
# <tr><td>53.</td><td>63.0/sq mi</td><td><a href="r.php?i=30-pa-juniata">Juniata, PA</a> / 24,793</td></tr>
# <tr><td>54.</td><td>53.8/sq mi</td><td><a href="r.php?i=30-pa-bradford">Bradford, PA</a> / 62,510</td></tr>
# <tr><td>55.</td><td>51.7/sq mi</td><td><a href="r.php?i=30-pa-huntingdon">Huntingdon, PA</a> / 45,950</td></tr>
# <tr><td>56.</td><td>51.3/sq mi</td><td><a href="r.php?i=30-pa-susquehanna">Susquehanna, PA</a> / 42,708</td></tr>
# <tr><td>57.</td><td>48.5/sq mi</td><td><a href="r.php?i=30-pa-bedford">Bedford, PA</a> / 49,332</td></tr>
# <tr><td>58.</td><td>45.9/sq mi</td><td><a href="r.php?i=30-pa-warren">Warren, PA</a> / 41,218</td></tr>
# <tr><td>59.</td><td>44.2/sq mi</td><td><a href="r.php?i=30-pa-clinton">Clinton, PA</a> / 39,611</td></tr>
# <tr><td>60.</td><td>43.7/sq mi</td><td><a href="r.php?i=30-pa-mckean">Mckean, PA</a> / 43,024</td></tr>
# <tr><td>61.</td><td>37.9/sq mi</td><td><a href="r.php?i=30-pa-elk">Elk, PA</a> / 31,584</td></tr>
# <tr><td>62.</td><td>37.3/sq mi</td><td><a href="r.php?i=30-pa-tioga">Tioga, PA</a> / 42,358</td></tr>
# <tr><td>63.</td><td>33.7/sq mi</td><td><a href="r.php?i=30-pa-fulton">Fulton, PA</a> / 14,747</td></tr>
# <tr><td>64.</td><td>17.8/sq mi</td><td><a href="r.php?i=30-pa-forest">Forest, PA</a> / 7,649</td></tr>
# <tr><td>65.</td><td>16.1/sq mi</td><td><a href="r.php?i=30-pa-potter">Potter, PA</a> / 17,451</td></tr>
# <tr><td>66.</td><td>14.1/sq mi</td><td><a href="r.php?i=30-pa-sullivan">Sullivan, PA</a> / 6,400</td></tr>
# <tr><td>67.</td><td>12.4/sq mi</td><td><a href="r.php?i=30-pa-cameron">Cameron, PA</a> / 4,939</td></tr>
# </table>

# %%
output_rows = []
for table_row in table.findAll('tr'):
    columns = table_row.findAll('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    output_rows.append(output_row)
    
with open('Density Penn.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(output_rows)
