# %%
from bs4 import BeautifulSoup
import requests
import csv
from IPython.core.display import display, HTML

# %%
url = 'http://www.usa.com/rank/kansas-state--population-density--county-rank.htm?yr=9000&dis=&wist=&plow=&phigh='
response = requests.get(url)

response.status_code

soup = BeautifulSoup(response.text, "lxml")

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <title>
#    Kansas Population Density County Rank
#   </title>
#   <meta content="Kansas Population Density County Rank" name="description"/>
#   <script src="rank-js.php" type="text/javascript">
#   </script>
#   <script src="search-form.js" type="text/javascript">
#   </script>
#   <link href="http://www.usa.com/rank/kansas-state--population-density--county-rank.htm" rel="canonical"/>
#   <link href="/g.css" rel="stylesheet" type="text/css"/>
#   <script src="/js/common.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div id="h">
#    <div id="hinlogo">
#     <a href="/">
#      <img alt="USA.com" height="46" src="/img/USA.png" width="193"/>
#     </a>
#    </div>
#    <div class="topsearchc">
#     <div class="topsearchhead">
#      Local Data Search
#     </div>
#     <div class="search_div">
#      <table>
#       <form action="/locations.php" method="get" name="tsm">
#        <tr>
#         <td>
#          <input name="Submit" onclick="return tyhOnSubmit();" style="width:1px;height:1px;color:#fff;padding:0px;" type="submit" value="Submit"/>
#          <input autocomplete="off" name="q" onblur="searchinputprocess(0);" onfocus="searchinputprocess(1);" type="text" value="Search State, County, City, Zip Code, or Area Code"/>
#         </td>
#         <td>
#          <a href="#" onclick="document.tsm.submit();">
#           <div class="navsearch">
#           </div>
#          </a>
#         </td>
#        </tr>
#       </form>
#      </table>
#     </div>
#     <div class="tyhshadow" id="tyhshadow">
#      <div class="tyhoutput" id="tyhoutput">
#      </div>
#     </div>
#     <script>
#      tyhInit();
#     </script>
#    </div>
#   </div>
#   <div>
#   </div>
#   <div id="mo">
#    <div id="m">
#     <div id="hcontent">
#      <div class="small">
#       <a href="/">
#        USA.com
#       </a>
#       /
#       <a href="/rank/">
#        Ranks
#       </a>
#       /
#       <a href="kansas-state--population-density--county-rank.htm">
#        Kansas Population Density County Rank
#       </a>
#      </div>
#      <h1>
#       Kansas Population Density County Rank
#      </h1>
#      <p>
#       A total of 105 results found.
#       <span id="highlightOnTheTop">
#       </span>
#       <span id="showonmaptext">
#        <b>
#         <a href="#" onclick="loadFullMap();gObj('showonmaptext').style.display='none';return false;">
#          Show Results on Map
#         </a>
#        </b>
#       </span>
#       .
#      </p>
#      <div id="mapwrapper" style="display:none;">
#       <div id="mapoutput">
#       </div>
#       <div id="map_canvas2" style="height: 500px;">
#       </div>
#      </div>
#      <table width="648">
#       <tr valign="bottom">
#        <td width="48">
#         <b>
#          Rank
#         </b>
#        </td>
#        <td width="150">
#         <b>
#          <a href="#" onclick="rsf('sb','ASC');">
#           Population Density ▼
#          </a>
#         </b>
#        </td>
#        <td width="450">
#         <b>
#          County / Population
#         </b>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         1.
#        </td>
#        <td>
#         1,167.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-johnson">
#          Johnson, KS
#         </a>
#         / 560,025
#        </td>
#       </tr>
#       <tr>
#        <td>
#         2.
#        </td>
#        <td>
#         1,021.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-wyandotte">
#          Wyandotte, KS
#         </a>
#         / 159,466
#        </td>
#       </tr>
#       <tr>
#        <td>
#         3.
#        </td>
#        <td>
#         499.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-sedgwick">
#          Sedgwick, KS
#         </a>
#         / 503,788
#        </td>
#       </tr>
#       <tr>
#        <td>
#         4.
#        </td>
#        <td>
#         321.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-shawnee">
#          Shawnee, KS
#         </a>
#         / 178,600
#        </td>
#       </tr>
#       <tr>
#        <td>
#         5.
#        </td>
#        <td>
#         239.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-douglas">
#          Douglas, KS
#         </a>
#         / 113,703
#        </td>
#       </tr>
#       <tr>
#        <td>
#         6.
#        </td>
#        <td>
#         165.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-leavenworth">
#          Leavenworth, KS
#         </a>
#         / 77,687
#        </td>
#       </tr>
#       <tr>
#        <td>
#         7.
#        </td>
#        <td>
#         119.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-riley">
#          Riley, KS
#         </a>
#         / 74,478
#        </td>
#       </tr>
#       <tr>
#        <td>
#         8.
#        </td>
#        <td>
#         90.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-geary">
#          Geary, KS
#         </a>
#         / 36,458
#        </td>
#       </tr>
#       <tr>
#        <td>
#         9.
#        </td>
#        <td>
#         77.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-saline">
#          Saline, KS
#         </a>
#         / 55,793
#        </td>
#       </tr>
#       <tr>
#        <td>
#         10.
#        </td>
#        <td>
#         66.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-crawford">
#          Crawford, KS
#         </a>
#         / 39,277
#        </td>
#       </tr>
#       <tr>
#        <td>
#         11.
#        </td>
#        <td>
#         64.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-harvey">
#          Harvey, KS
#         </a>
#         / 34,797
#        </td>
#       </tr>
#       <tr>
#        <td>
#         12.
#        </td>
#        <td>
#         55.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-miami">
#          Miami, KS
#         </a>
#         / 32,765
#        </td>
#       </tr>
#       <tr>
#        <td>
#         13.
#        </td>
#        <td>
#         53.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-montgomery">
#          Montgomery, KS
#         </a>
#         / 34,602
#        </td>
#       </tr>
#       <tr>
#        <td>
#         14.
#        </td>
#        <td>
#         50.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-reno">
#          Reno, KS
#         </a>
#         / 64,223
#        </td>
#       </tr>
#       <tr>
#        <td>
#         15.
#        </td>
#        <td>
#         45.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-butler">
#          Butler, KS
#         </a>
#         / 65,927
#        </td>
#       </tr>
#       <tr>
#        <td>
#         16.
#        </td>
#        <td>
#         44.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-franklin">
#          Franklin, KS
#         </a>
#         / 25,834
#        </td>
#       </tr>
#       <tr>
#        <td>
#         17.
#        </td>
#        <td>
#         39.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-lyon">
#          Lyon, KS
#         </a>
#         / 33,510
#        </td>
#       </tr>
#       <tr>
#        <td>
#         18.
#        </td>
#        <td>
#         38.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-atchison">
#          Atchison, KS
#         </a>
#         / 16,737
#        </td>
#       </tr>
#       <tr>
#        <td>
#         19.
#        </td>
#        <td>
#         36.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-seward">
#          Seward, KS
#         </a>
#         / 23,319
#        </td>
#       </tr>
#       <tr>
#        <td>
#         20.
#        </td>
#        <td>
#         35.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-cherokee">
#          Cherokee, KS
#         </a>
#         / 21,179
#        </td>
#       </tr>
#       <tr>
#        <td>
#         21.
#        </td>
#        <td>
#         34.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-jefferson">
#          Jefferson, KS
#         </a>
#         / 18,932
#        </td>
#       </tr>
#       <tr>
#        <td>
#         22.
#        </td>
#        <td>
#         32.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-mcpherson">
#          Mcpherson, KS
#         </a>
#         / 29,308
#        </td>
#       </tr>
#       <tr>
#        <td>
#         23.
#        </td>
#        <td>
#         32.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-labette">
#          Labette, KS
#         </a>
#         / 21,225
#        </td>
#       </tr>
#       <tr>
#        <td>
#         24.
#        </td>
#        <td>
#         32.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-ellis">
#          Ellis, KS
#         </a>
#         / 28,878
#        </td>
#       </tr>
#       <tr>
#        <td>
#         25.
#        </td>
#        <td>
#         32.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-cowley">
#          Cowley, KS
#         </a>
#         / 36,201
#        </td>
#       </tr>
#       <tr>
#        <td>
#         26.
#        </td>
#        <td>
#         31.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-ford">
#          Ford, KS
#         </a>
#         / 34,604
#        </td>
#       </tr>
#       <tr>
#        <td>
#         27.
#        </td>
#        <td>
#         30.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-barton">
#          Barton, KS
#         </a>
#         / 27,566
#        </td>
#       </tr>
#       <tr>
#        <td>
#         28.
#        </td>
#        <td>
#         28.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-finney">
#          Finney, KS
#         </a>
#         / 37,099
#        </td>
#       </tr>
#       <tr>
#        <td>
#         29.
#        </td>
#        <td>
#         28.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-neosho">
#          Neosho, KS
#         </a>
#         / 16,453
#        </td>
#       </tr>
#       <tr>
#        <td>
#         30.
#        </td>
#        <td>
#         26.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-allen">
#          Allen, KS
#         </a>
#         / 13,212
#        </td>
#       </tr>
#       <tr>
#        <td>
#         31.
#        </td>
#        <td>
#         25.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-pottawatomie">
#          Pottawatomie, KS
#         </a>
#         / 22,338
#        </td>
#       </tr>
#       <tr>
#        <td>
#         32.
#        </td>
#        <td>
#         23.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-bourbon">
#          Bourbon, KS
#         </a>
#         / 14,913
#        </td>
#       </tr>
#       <tr>
#        <td>
#         33.
#        </td>
#        <td>
#         23.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-dickinson">
#          Dickinson, KS
#         </a>
#         / 19,641
#        </td>
#       </tr>
#       <tr>
#        <td>
#         34.
#        </td>
#        <td>
#         22.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-osage">
#          Osage, KS
#         </a>
#         / 16,165
#        </td>
#       </tr>
#       <tr>
#        <td>
#         35.
#        </td>
#        <td>
#         20.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-jackson">
#          Jackson, KS
#         </a>
#         / 13,464
#        </td>
#       </tr>
#       <tr>
#        <td>
#         36.
#        </td>
#        <td>
#         20.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-sumner">
#          Sumner, KS
#         </a>
#         / 23,763
#        </td>
#       </tr>
#       <tr>
#        <td>
#         37.
#        </td>
#        <td>
#         19.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-doniphan">
#          Doniphan, KS
#         </a>
#         / 7,904
#        </td>
#       </tr>
#       <tr>
#        <td>
#         38.
#        </td>
#        <td>
#         17.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-brown">
#          Brown, KS
#         </a>
#         / 9,926
#        </td>
#       </tr>
#       <tr>
#        <td>
#         39.
#        </td>
#        <td>
#         16.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-wilson">
#          Wilson, KS
#         </a>
#         / 9,177
#        </td>
#       </tr>
#       <tr>
#        <td>
#         40.
#        </td>
#        <td>
#         15.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-linn">
#          Linn, KS
#         </a>
#         / 9,551
#        </td>
#       </tr>
#       <tr>
#        <td>
#         41.
#        </td>
#        <td>
#         14.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-nemaha">
#          Nemaha, KS
#         </a>
#         / 10,136
#        </td>
#       </tr>
#       <tr>
#        <td>
#         42.
#        </td>
#        <td>
#         13.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-rice">
#          Rice, KS
#         </a>
#         / 10,050
#        </td>
#       </tr>
#       <tr>
#        <td>
#         43.
#        </td>
#        <td>
#         13.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-grant">
#          Grant, KS
#         </a>
#         / 7,856
#        </td>
#       </tr>
#       <tr>
#        <td>
#         44.
#        </td>
#        <td>
#         13.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-anderson">
#          Anderson, KS
#         </a>
#         / 7,962
#        </td>
#       </tr>
#       <tr>
#        <td>
#         45.
#        </td>
#        <td>
#         13.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-pratt">
#          Pratt, KS
#         </a>
#         / 9,758
#        </td>
#       </tr>
#       <tr>
#        <td>
#         46.
#        </td>
#        <td>
#         13.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-cloud">
#          Cloud, KS
#         </a>
#         / 9,414
#        </td>
#       </tr>
#       <tr>
#        <td>
#         47.
#        </td>
#        <td>
#         13.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-marion">
#          Marion, KS
#         </a>
#         / 12,401
#        </td>
#       </tr>
#       <tr>
#        <td>
#         48.
#        </td>
#        <td>
#         13.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-coffey">
#          Coffey, KS
#         </a>
#         / 8,493
#        </td>
#       </tr>
#       <tr>
#        <td>
#         49.
#        </td>
#        <td>
#         12.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-clay">
#          Clay, KS
#         </a>
#         / 8,460
#        </td>
#       </tr>
#       <tr>
#        <td>
#         50.
#        </td>
#        <td>
#         11.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-marshall">
#          Marshall, KS
#         </a>
#         / 10,042
#        </td>
#       </tr>
#       <tr>
#        <td>
#         51.
#        </td>
#        <td>
#         9.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-pawnee">
#          Pawnee, KS
#         </a>
#         / 6,959
#        </td>
#       </tr>
#       <tr>
#        <td>
#         52.
#        </td>
#        <td>
#         9.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-kingman">
#          Kingman, KS
#         </a>
#         / 7,820
#        </td>
#       </tr>
#       <tr>
#        <td>
#         53.
#        </td>
#        <td>
#         8.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-ellsworth">
#          Ellsworth, KS
#         </a>
#         / 6,443
#        </td>
#       </tr>
#       <tr>
#        <td>
#         54.
#        </td>
#        <td>
#         8.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-wabaunsee">
#          Wabaunsee, KS
#         </a>
#         / 7,034
#        </td>
#       </tr>
#       <tr>
#        <td>
#         55.
#        </td>
#        <td>
#         8.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-mitchell">
#          Mitchell, KS
#         </a>
#         / 6,324
#        </td>
#       </tr>
#       <tr>
#        <td>
#         56.
#        </td>
#        <td>
#         8.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-ottawa">
#          Ottawa, KS
#         </a>
#         / 6,075
#        </td>
#       </tr>
#       <tr>
#        <td>
#         57.
#        </td>
#        <td>
#         8.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-morris">
#          Morris, KS
#         </a>
#         / 5,808
#        </td>
#       </tr>
#       <tr>
#        <td>
#         58.
#        </td>
#        <td>
#         7.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-stevens">
#          Stevens, KS
#         </a>
#         / 5,744
#        </td>
#       </tr>
#       <tr>
#        <td>
#         59.
#        </td>
#        <td>
#         7.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-russell">
#          Russell, KS
#         </a>
#         / 6,959
#        </td>
#       </tr>
#       <tr>
#        <td>
#         60.
#        </td>
#        <td>
#         7.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-thomas">
#          Thomas, KS
#         </a>
#         / 7,947
#        </td>
#       </tr>
#       <tr>
#        <td>
#         61.
#        </td>
#        <td>
#         7.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-harper">
#          Harper, KS
#         </a>
#         / 5,906
#        </td>
#       </tr>
#       <tr>
#        <td>
#         62.
#        </td>
#        <td>
#         7.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-haskell">
#          Haskell, KS
#         </a>
#         / 4,198
#        </td>
#       </tr>
#       <tr>
#        <td>
#         63.
#        </td>
#        <td>
#         7.0/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-gray">
#          Gray, KS
#         </a>
#         / 6,043
#        </td>
#       </tr>
#       <tr>
#        <td>
#         64.
#        </td>
#        <td>
#         6.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-scott">
#          Scott, KS
#         </a>
#         / 4,965
#        </td>
#       </tr>
#       <tr>
#        <td>
#         65.
#        </td>
#        <td>
#         6.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-republic">
#          Republic, KS
#         </a>
#         / 4,868
#        </td>
#       </tr>
#       <tr>
#        <td>
#         66.
#        </td>
#        <td>
#         6.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-woodson">
#          Woodson, KS
#         </a>
#         / 3,246
#        </td>
#       </tr>
#       <tr>
#        <td>
#         67.
#        </td>
#        <td>
#         6.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-norton">
#          Norton, KS
#         </a>
#         / 5,628
#        </td>
#       </tr>
#       <tr>
#        <td>
#         68.
#        </td>
#        <td>
#         6.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-washington">
#          Washington, KS
#         </a>
#         / 5,717
#        </td>
#       </tr>
#       <tr>
#        <td>
#         69.
#        </td>
#        <td>
#         6.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-phillips">
#          Phillips, KS
#         </a>
#         / 5,560
#        </td>
#       </tr>
#       <tr>
#        <td>
#         70.
#        </td>
#        <td>
#         5.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-rooks">
#          Rooks, KS
#         </a>
#         / 5,174
#        </td>
#       </tr>
#       <tr>
#        <td>
#         71.
#        </td>
#        <td>
#         5.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-sherman">
#          Sherman, KS
#         </a>
#         / 6,078
#        </td>
#       </tr>
#       <tr>
#        <td>
#         72.
#        </td>
#        <td>
#         5.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-greenwood">
#          Greenwood, KS
#         </a>
#         / 6,495
#        </td>
#       </tr>
#       <tr>
#        <td>
#         73.
#        </td>
#        <td>
#         5.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-chautauqua">
#          Chautauqua, KS
#         </a>
#         / 3,572
#        </td>
#       </tr>
#       <tr>
#        <td>
#         74.
#        </td>
#        <td>
#         5.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-stafford">
#          Stafford, KS
#         </a>
#         / 4,363
#        </td>
#       </tr>
#       <tr>
#        <td>
#         75.
#        </td>
#        <td>
#         4.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-edwards">
#          Edwards, KS
#         </a>
#         / 3,006
#        </td>
#       </tr>
#       <tr>
#        <td>
#         76.
#        </td>
#        <td>
#         4.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-meade">
#          Meade, KS
#         </a>
#         / 4,444
#        </td>
#       </tr>
#       <tr>
#        <td>
#         77.
#        </td>
#        <td>
#         4.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-kearny">
#          Kearny, KS
#         </a>
#         / 3,950
#        </td>
#       </tr>
#       <tr>
#        <td>
#         78.
#        </td>
#        <td>
#         4.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-rush">
#          Rush, KS
#         </a>
#         / 3,222
#        </td>
#       </tr>
#       <tr>
#        <td>
#         79.
#        </td>
#        <td>
#         4.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-lincoln">
#          Lincoln, KS
#         </a>
#         / 3,180
#        </td>
#       </tr>
#       <tr>
#        <td>
#         80.
#        </td>
#        <td>
#         4.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-morton">
#          Morton, KS
#         </a>
#         / 3,159
#        </td>
#       </tr>
#       <tr>
#        <td>
#         81.
#        </td>
#        <td>
#         4.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-barber">
#          Barber, KS
#         </a>
#         / 4,898
#        </td>
#       </tr>
#       <tr>
#        <td>
#         82.
#        </td>
#        <td>
#         4.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-osborne">
#          Osborne, KS
#         </a>
#         / 3,811
#        </td>
#       </tr>
#       <tr>
#        <td>
#         83.
#        </td>
#        <td>
#         4.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-smith">
#          Smith, KS
#         </a>
#         / 3,779
#        </td>
#       </tr>
#       <tr>
#        <td>
#         84.
#        </td>
#        <td>
#         4.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-elk">
#          Elk, KS
#         </a>
#         / 2,734
#        </td>
#       </tr>
#       <tr>
#        <td>
#         85.
#        </td>
#        <td>
#         3.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-chase">
#          Chase, KS
#         </a>
#         / 2,746
#        </td>
#       </tr>
#       <tr>
#        <td>
#         86.
#        </td>
#        <td>
#         3.5/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-kiowa">
#          Kiowa, KS
#         </a>
#         / 2,529
#        </td>
#       </tr>
#       <tr>
#        <td>
#         87.
#        </td>
#        <td>
#         3.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-jewell">
#          Jewell, KS
#         </a>
#         / 3,060
#        </td>
#       </tr>
#       <tr>
#        <td>
#         88.
#        </td>
#        <td>
#         3.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-trego">
#          Trego, KS
#         </a>
#         / 2,959
#        </td>
#       </tr>
#       <tr>
#        <td>
#         89.
#        </td>
#        <td>
#         3.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-decatur">
#          Decatur, KS
#         </a>
#         / 2,915
#        </td>
#       </tr>
#       <tr>
#        <td>
#         90.
#        </td>
#        <td>
#         3.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-stanton">
#          Stanton, KS
#         </a>
#         / 2,187
#        </td>
#       </tr>
#       <tr>
#        <td>
#         91.
#        </td>
#        <td>
#         3.1/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-wichita">
#          Wichita, KS
#         </a>
#         / 2,220
#        </td>
#       </tr>
#       <tr>
#        <td>
#         92.
#        </td>
#        <td>
#         2.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-graham">
#          Graham, KS
#         </a>
#         / 2,602
#        </td>
#       </tr>
#       <tr>
#        <td>
#         93.
#        </td>
#        <td>
#         2.9/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-ness">
#          Ness, KS
#         </a>
#         / 3,104
#        </td>
#       </tr>
#       <tr>
#        <td>
#         94.
#        </td>
#        <td>
#         2.8/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-sheridan">
#          Sheridan, KS
#         </a>
#         / 2,540
#        </td>
#       </tr>
#       <tr>
#        <td>
#         95.
#        </td>
#        <td>
#         2.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-cheyenne">
#          Cheyenne, KS
#         </a>
#         / 2,695
#        </td>
#       </tr>
#       <tr>
#        <td>
#         96.
#        </td>
#        <td>
#         2.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-hamilton">
#          Hamilton, KS
#         </a>
#         / 2,632
#        </td>
#       </tr>
#       <tr>
#        <td>
#         97.
#        </td>
#        <td>
#         2.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-gove">
#          Gove, KS
#         </a>
#         / 2,786
#        </td>
#       </tr>
#       <tr>
#        <td>
#         98.
#        </td>
#        <td>
#         2.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-logan">
#          Logan, KS
#         </a>
#         / 2,783
#        </td>
#       </tr>
#       <tr>
#        <td>
#         99.
#        </td>
#        <td>
#         2.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-comanche">
#          Comanche, KS
#         </a>
#         / 1,911
#        </td>
#       </tr>
#       <tr>
#        <td>
#         100.
#        </td>
#        <td>
#         2.4/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-rawlins">
#          Rawlins, KS
#         </a>
#         / 2,553
#        </td>
#       </tr>
#       <tr>
#        <td>
#         101.
#        </td>
#        <td>
#         2.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-lane">
#          Lane, KS
#         </a>
#         / 1,652
#        </td>
#       </tr>
#       <tr>
#        <td>
#         102.
#        </td>
#        <td>
#         2.3/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-hodgeman">
#          Hodgeman, KS
#         </a>
#         / 1,941
#        </td>
#       </tr>
#       <tr>
#        <td>
#         103.
#        </td>
#        <td>
#         2.2/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-clark">
#          Clark, KS
#         </a>
#         / 2,170
#        </td>
#       </tr>
#       <tr>
#        <td>
#         104.
#        </td>
#        <td>
#         1.7/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-wallace">
#          Wallace, KS
#         </a>
#         / 1,569
#        </td>
#       </tr>
#       <tr>
#        <td>
#         105.
#        </td>
#        <td>
#         1.6/sq mi
#        </td>
#        <td>
#         <a href="r.php?i=30-ks-greeley">
#          Greeley, KS
#         </a>
#         / 1,223
#        </td>
#       </tr>
#      </table>
#      <p>
#       Please note that we only rank locations with 'Population Density' data. The rank above might not be a complete list. Locations without 'Population Density' data are not listed.
#      </p>
#      <script src="http://maps.google.com/maps/api/js?sensor=false" type="text/javascript">
#      </script>
#      <script>
#       var infowindow;
# var map;
# var showDataFact = 0.2;
# var markers=[];
# var curDataTLat = 0;
# var curDataBLat = 0;
# var curDataLLng = 0;
# var curDataRLng = 0;
# var reboundmap = 1;
#
# var allPlaces = [];
# var placestr = "1|38.8839065|-94.822329|<b># 1.</b><br><a href='r.php?i=30-ks-johnson' target='_blank'>Johnson, KS / 560,025</a><br>1,167.0/sq mi||2|39.1153842|-94.763086|<b># 2.</b><br><a href='r.php?i=30-ks-wyandotte' target='_blank'>Wyandotte, KS / 159,466</a><br>1,021.0/sq mi||3|37.683807|-97.45945|<b># 3.</b><br><a href='r.php?i=30-ks-sedgwick' target='_blank'>Sedgwick, KS / 503,788</a><br>499.2/sq mi||4|39.0418052|-95.755663|<b># 4.</b><br><a href='r.php?i=30-ks-shawnee' target='_blank'>Shawnee, KS / 178,600</a><br>321.4/sq mi||5|38.8965726|-95.290529|<b># 5.</b><br><a href='r.php?i=30-ks-douglas' target='_blank'>Douglas, KS / 113,703</a><br>239.6/sq mi||6|39.1895108|-95.038977|<b># 6.</b><br><a href='r.php?i=30-ks-leavenworth' target='_blank'>Leavenworth, KS / 77,687</a><br>165.7/sq mi||7|39.2912114|-96.727488|<b># 7.</b><br><a href='r.php?i=30-ks-riley' target='_blank'>Riley, KS / 74,478</a><br>119.7/sq mi||8|39.0021553|-96.768038|<b># 8.</b><br><a href='r.php?i=30-ks-geary' target='_blank'>Geary, KS / 36,458</a><br>90.1/sq mi||9|38.7863268|-97.650153|<b># 9.</b><br><a href='r.php?i=30-ks-saline' target='_blank'>Saline, KS / 55,793</a><br>77.3/sq mi||10|37.5056283|-94.85394|<b># 10.</b><br><a href='r.php?i=30-ks-crawford' target='_blank'>Crawford, KS / 39,277</a><br>66.0/sq mi||11|38.0501436|-97.436706|<b># 11.</b><br><a href='r.php?i=30-ks-harvey' target='_blank'>Harvey, KS / 34,797</a><br>64.4/sq mi||12|38.5667718|-94.832962|<b># 12.</b><br><a href='r.php?i=30-ks-miami' target='_blank'>Miami, KS / 32,765</a><br>55.5/sq mi||13|37.1895369|-95.742402|<b># 13.</b><br><a href='r.php?i=30-ks-montgomery' target='_blank'>Montgomery, KS / 34,602</a><br>53.1/sq mi||14|37.9481849|-98.078346|<b># 14.</b><br><a href='r.php?i=30-ks-reno' target='_blank'>Reno, KS / 64,223</a><br>50.5/sq mi||15|37.7736811|-96.838761|<b># 15.</b><br><a href='r.php?i=30-ks-butler' target='_blank'>Butler, KS / 65,927</a><br>45.6/sq mi||16|38.5580187|-95.278961|<b># 16.</b><br><a href='r.php?i=30-ks-franklin' target='_blank'>Franklin, KS / 25,834</a><br>44.8/sq mi||17|38.4554978|-96.161588|<b># 17.</b><br><a href='r.php?i=30-ks-lyon' target='_blank'>Lyon, KS / 33,510</a><br>39.2/sq mi||18|39.5325441|-95.313397|<b># 18.</b><br><a href='r.php?i=30-ks-atchison' target='_blank'>Atchison, KS / 16,737</a><br>38.6/sq mi||19|37.1805849|-100.85474|<b># 19.</b><br><a href='r.php?i=30-ks-seward' target='_blank'>Seward, KS / 23,319</a><br>36.4/sq mi||20|37.1693922|-94.845697|<b># 20.</b><br><a href='r.php?i=30-ks-cherokee' target='_blank'>Cherokee, KS / 21,179</a><br>35.8/sq mi||21|39.239644|-95.375314|<b># 21.</b><br><a href='r.php?i=30-ks-jefferson' target='_blank'>Jefferson, KS / 18,932</a><br>34.0/sq mi||22|38.395812|-97.647489|<b># 22.</b><br><a href='r.php?i=30-ks-mcpherson' target='_blank'>Mcpherson, KS / 29,308</a><br>32.5/sq mi||23|37.1914676|-95.297473|<b># 23.</b><br><a href='r.php?i=30-ks-labette' target='_blank'>Labette, KS / 21,225</a><br>32.5/sq mi||24|38.9145957|-99.317329|<b># 24.</b><br><a href='r.php?i=30-ks-ellis' target='_blank'>Ellis, KS / 28,878</a><br>32.1/sq mi||25|37.2345068|-96.837246|<b># 25.</b><br><a href='r.php?i=30-ks-cowley' target='_blank'>Cowley, KS / 36,201</a><br>32.0/sq mi||26|37.6883653|-99.884734|<b># 26.</b><br><a href='r.php?i=30-ks-ford' target='_blank'>Ford, KS / 34,604</a><br>31.5/sq mi||27|38.4812394|-98.767837|<b># 27.</b><br><a href='r.php?i=30-ks-barton' target='_blank'>Barton, KS / 27,566</a><br>30.6/sq mi||28|38.0498552|-100.739928|<b># 28.</b><br><a href='r.php?i=30-ks-finney' target='_blank'>Finney, KS / 37,099</a><br>28.5/sq mi||29|37.5642833|-95.315682|<b># 29.</b><br><a href='r.php?i=30-ks-neosho' target='_blank'>Neosho, KS / 16,453</a><br>28.5/sq mi||30|37.8842285|-95.300944|<b># 30.</b><br><a href='r.php?i=30-ks-allen' target='_blank'>Allen, KS / 13,212</a><br>26.1/sq mi||31|39.3821868|-96.337112|<b># 31.</b><br><a href='r.php?i=30-ks-pottawatomie' target='_blank'>Pottawatomie, KS / 22,338</a><br>25.9/sq mi| ...
# var places=placestr.split("||");
# for (var i = 0; i < places.length; i++) {
# 	if ((""+places[i]).length>0){
# 		allPlaces.push(places[i].split("|"));
# 	}
# }
#
# function plotMarkers(curDataTLatin, curDataBLatin, curDataLLngin, curDataRLngin){
# 	var placeToUse = [];
# 	var foundCounter=0;
# 	for (var i = 0; i < allPlaces.length; i++) {
# 		if ((allPlaces[i][1]>curDataBLatin)&&(allPlaces[i][1]<curDataTLatin)&&(allPlaces[i][2]>curDataLLngin)&&(allPlaces[i][2]<curDataRLngin)){
# 			placeToUse.push(allPlaces[i]);
# 			foundCounter++;
# 			if (foundCounter>150){
# 				foundCounter=-1;
# 				break;
# 			}
# 		}
# 	}
#
# 	if (placeToUse.length>0){
# 		var bounds = new google.maps.LatLngBounds ();
# 		for (var i = 0; i < placeToUse.length; i++) {
# 			var oneplace = placeToUse[i];
# 			var latLng = new google.maps.LatLng(parseFloat(oneplace[1]), parseFloat(oneplace[2]));
# 			bounds.extend(latLng);
# 			var iconCmp = parseInt(oneplace[0]);
# 			if (iconCmp>99) iconCmp = 0;
# 			var marker = new google.maps.Marker({
# 				position: latLng,
# 				map: map,
# 				title: oneplace[0],
# 				icon: new google.maps.MarkerImage(
# 					'/img/n.png',
# 					new google.maps.Size(21, 22),
# 					new google.maps.Point((31*iconCmp), 0)
# 				)
# 			});
#
# 			contInfo = oneplace[3];
# 			(function(i, marker, contInfo) {
# 				google.maps.event.addListener(marker, 'click', function() {
# 					if (!infowindow) {
# 						infowindow = new google.maps.InfoWindow();
# 					}
# 					infowindow.setContent(contInfo);
# 					infowindow.open(map, marker);
# 				});
# 			})(i, marker, contInfo);
# 			markers.push(marker);
# 		}
# 		if (reboundmap==1){
# 			reboundmap=-1;
# 			map.fitBounds(bounds);
# 		}
# 	}
# 	if (foundCounter>0){
# 		document.getElementById("mapoutput").innerHTML = "Full Results. Zoom in to refine. Click icon to show name.";
# 	}else{
# 		document.getElementById("mapoutput").innerHTML = "<font color='Red'>Partial Results</font>. Zoom in to see more. Click icon to show name.";
# 	}
# }
#
# function showOnMap(map, doReload){
# 	var zoom = map.getZoom();
# 	var bounds = map.getBounds();
# 	var southWest = bounds.getSouthWest();
# 	var northEast = bounds.getNorthEast();
#
# 	var latSpan = northEast.lat() - southWest.lat();
# 	var lngSpan = northEast.lng() - southWest.lng();
# 	if (lngSpan<0) lngSpan = lngSpan + 360;
# 	var thisTLat = northEast.lat();
# 	var thisBLat = southWest.lat();
# 	var thisLLng = southWest.lng();
# 	var thisRLng = northEast.lng();
#
# 	if ((doReload==1)||(thisTLat>curDataTLat)||(thisBLat<curDataBLat)||(thisLLng<curDataLLng)||(thisRLng>curDataRLng)){
# 		curDataTLat = northEast.lat() + latSpan*showDataFact;
# 		curDataBLat = southWest.lat() - latSpan*showDataFact;
# 		curDataLLng = southWest.lng() - lngSpan*showDataFact;
# 		curDataRLng = northEast.lng() + lngSpan*showDataFact;
# 		if (reboundmap==-1){
# 			reboundmap = 0;
# 		}else{
# 			clearMarkers();
# 			plotMarkers(curDataTLat, curDataBLat, curDataLLng, curDataRLng);
# 		}
# 	}
# }
# function loadFullMap(){
# 	gObj("mapwrapper").style.display = 'block';
# 	var options = {
# 		zoom: 3,
# 		center: new google.maps.LatLng(38.4985464, -98.383429),
# 		scrollwheel: false,
# 		mapTypeId: google.maps.MapTypeId.ROADMAP
# 	};
# 	map = new google.maps.Map(document.getElementById('map_canvas2'), options);
# 	google.maps.event.addListener(map, 'zoom_changed', function() {
# 		showOnMap(map, 1);
# 	});
# 	google.maps.event.addListener(map, 'bounds_changed', function() {
# 		showOnMap(map, 0);
# 	});
# }
# function clearMarkers() {
# 	if (markers) {
# 		for (i in markers) {
# 			markers[i].setMap(null);
# 		}
# 	}
# 	markers=[];
# }
#      </script>
#      <form action="kansas-state--population-density--county-rank.htm" method="get" name="hsF">
#       <input name="hl" type="hidden" value=""/>
#       <input name="hlst" type="hidden" value=""/>
#       <input name="wist" type="hidden" value=""/>
#       <input name="yr" type="hidden" value="9000"/>
#       <input name="dis" type="hidden" value=""/>
#       <input name="sb" type="hidden" value="DESC"/>
#       <input name="plow" type="hidden" value=""/>
#       <input name="phigh" type="hidden" value=""/>
#       <input name="ps" type="hidden" value=""/>
#      </form>
#     </div>
#     <div id="hmenu">
#      <script type="text/javascript">
#       <!--
# window.google_analytics_uacct = "UA-12906387-4";
# google_ad_client = "ca-pub-1187797442630842";
# /* USA.com_main_right_300x250 */
# google_ad_slot = "6987722783";
# google_ad_width = 300;
# google_ad_height = 250;
# //-->
#      </script>
#      <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#      </script>
#      <style>
#       border-radius:3px;
# 	border: 1px solid #4fa4c3;
# 	background: #deedf2;
# 	padding: 5px;
#
# .tpcitem{
# 	margin-left:10px;
# 	display:block;
# 	font-size:10px;
# }
# .searchbox{
# 	border-radius:3px;
# 	background: #ecf4f6;
# 	border: 1px solid #1d5895;
# 	margin-top:5px;
# }
# .searchboxhead{
# 	font-size: 16px;
# 	font-weight: bold;
# 	color: #ffffff;
# 	background: #1d5895;
# 	padding: 3px;
# 	font-weight:bold;
# }
# .bigsubmit{
# 	font-size: 14px;
# 	font-weight: bold;
# 	width:100px;
# 	height:30px;
# }
#      </style>
#      <form action="#" method="get" name="rsF">
#       <div class="searchbox">
#        <div class="searchboxhead">
#         Refine Your Ranking
#        </div>
#        <div style="padding-left:4px;">
#         <input name="itemtorank" type="hidden" value=""/>
#         <span id="itemtorankerror">
#         </span>
#         <div id="itemtorankcontent">
#         </div>
#         <br/>
#         <span id="rankingscopeerror">
#         </span>
#         <div class="big">
#          <b>
#           Pick Your Location:
#          </b>
#         </div>
#         <div style="padding-left:5px;">
#          <label for="withinloc">
#           <input checked="" id="withinloc" name="rankingscope" onclick="switchScope('1')" type="radio" value="1"/>
#           Within a Location
#          </label>
#         </div>
#         <div id="withinLocationDiv" style="padding-top:5px;padding-left:31px;">
#          <select name="rankWithin" onchange="changeScope(1,'');">
#           <option value="us">
#            The Entire U.S.
#           </option>
#           <option selected="" value="state">
#            State
#           </option>
#           <option value="metro-area">
#            Metro Area
#           </option>
#           <option value="county">
#            County
#           </option>
#           <option value="city">
#            City
#           </option>
#           <option value="school-district">
#            School District
#           </option>
#           <option value="zip-code">
#            Zip
#           </option>
#          </select>
#          <select id="rankWithin2" name="rankWithin2" onchange="changeScope(2,'');" style="display:none;width:260px;">
#          </select>
#          <select id="rankWithin3" name="rankWithin3" style="display:none;width:260px;">
#          </select>
#         </div>
#         <div style="padding-left:5px;">
#          <label for="withinpoint">
#           <input id="withinpoint" name="rankingscope" onclick="switchScope('0')" type="radio" value="0"/>
#           Rank within a Distance of a Point
#          </label>
#         </div>
#         <div id="withinPointDiv" style="display:none;padding-top:5px;padding-left:26px;">
#          within
#          <input name="ml" size="1" type="text" value=""/>
#          miles of
#          <input name="lc" size="5" type="text" value="kansas-state"/>
#          (e.g. a zip code)
#         </div>
#         <span id="rankoferror">
#         </span>
#         <div style="padding-top:15px;">
#          <span class="big">
#           <b>
#            Rank By:
#           </b>
#          </span>
#         </div>
#         <div style="padding-top:5px;padding-left:15px;">
#          <select name="rankOf" onchange="loadItemsToRank(document.rsF.itemtorank.value);">
#           <option value="state">
#            State
#           </option>
#           <option value="metro-area">
#            Metro Area
#           </option>
#           <option selected="" value="county">
#            County
#           </option>
#           <option value="city">
#            City
#           </option>
#           <option value="school-district">
#            School District
#           </option>
#           <option value="zip-code">
#            Zip
#           </option>
#           <option value="census-tract">
#            Census Tract
#           </option>
#           <option value="block-group">
#            Census Block Group
#           </option>
#           <option value="block">
#            Census Block
#           </option>
#          </select>
#         </div>
#         <div>
#          <div id="datadateDiv" style="padding-top:15px;">
#           <span class="big">
#            <b>
#             Select Date of Data:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <select name="datadate" style="width:270px;">
#             <option selected="" value="9000">
#              American Community Survey 2010-2014
#             </option>
#             <option value="8000">
#              U.S. Census 2010
#             </option>
#             <option value="6000">
#              American Community Survey 2008-2012
#             </option>
#             <option value="3000">
#              American Community Survey 2006-2010
#             </option>
#             <option value="2000">
#              American Community Survey 2005-2009
#             </option>
#             <option value="1000">
#              U.S. Census 2000
#             </option>
#            </select>
#           </div>
#          </div>
#          <div id="limitToStateDiv" style="display:none;padding-top:15px;">
#           <span class="big">
#            <b>
#             Limit to the State of:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <select name="limitToState">
#             <option value="">
#              Please Select
#             </option>
#             <option value="AL">
#              Alabama
#             </option>
#             <option value="AK">
#              Alaska
#             </option>
#             <option value="AZ">
#              Arizona
#             </option>
#             <option value="AR">
#              Arkansas
#             </option>
#             <option value="CA">
#              California
#             </option>
#             <option value="CO">
#              Colorado
#             </option>
#             <option value="CT">
#              Connecticut
#             </option>
#             <option value="DE">
#              Delaware
#             </option>
#             <option value="DC">
#              District of Columbia
#             </option>
#             <option value="FL">
#              Florida
#             </option>
#             <option value="GA">
#              Georgia
#             </option>
#             <option value="HI">
#              Hawaii
#             </option>
#             <option value="ID">
#              Idaho
#             </option>
#             <option value="IL">
#              Illinois
#             </option>
#             <option value="IN">
#              Indiana
#             </option>
#             <option value="IA">
#              Iowa
#             </option>
#             <option value="KS">
#              Kansas
#             </option>
#             <option value="KY">
#              Kentucky
#             </option>
#             <option value="LA">
#              Louisiana
#             </option>
#             <option value="ME">
#              Maine
#             </option>
#             <option value="MD">
#              Maryland
#             </option>
#             <option value="MA">
#              Massachusetts
#             </option>
#             <option value="MI">
#              Michigan
#             </option>
#             <option value="MN">
#              Minnesota
#             </option>
#             <option value="MS">
#              Mississippi
#             </option>
#             <option value="MO">
#              Missouri
#             </option>
#             <option value="MT">
#              Montana
#             </option>
#             <option value="NE">
#              Nebraska
#             </option>
#             <option value="NV">
#              Nevada
#             </option>
#             <option value="NH">
#              New Hampshire
#             </option>
#             <option value="NJ">
#              New Jersey
#             </option>
#             <option value="NM">
#              New Mexico
#             </option>
#             <option value="NY">
#              New York
#             </option>
#             <option value="NC">
#              North Carolina
#             </option>
#             <option value="ND">
#              North Dakota
#             </option>
#             <option value="OH">
#              Ohio
#             </option>
#             <option value="OK">
#              Oklahoma
#             </option>
#             <option value="OR">
#              Oregon
#             </option>
#             <option value="PA">
#              Pennsylvania
#             </option>
#             <option value="RI">
#              Rhode Island
#             </option>
#             <option value="SC">
#              South Carolina
#             </option>
#             <option value="SD">
#              South Dakota
#             </option>
#             <option value="TN">
#              Tennessee
#             </option>
#             <option value="TX">
#              Texas
#             </option>
#             <option value="UT">
#              Utah
#             </option>
#             <option value="VT">
#              Vermont
#             </option>
#             <option value="VA">
#              Virginia
#             </option>
#             <option value="WA">
#              Washington
#             </option>
#             <option value="WV">
#              West Virginia
#             </option>
#             <option value="WI">
#              Wisconsin
#             </option>
#             <option value="WY">
#              Wyoming
#             </option>
#            </select>
#           </div>
#          </div>
#          <div style="padding-top:10px;">
#           <span class="big">
#            <b>
#             Limit to Locations with Population:
#            </b>
#           </span>
#           <div style="padding-top:5px;padding-left:15px;">
#            <input name="poplow" size="3" type="text" value=""/>
#            to
#            <input name="pophigh" size="3" type="text" value=""/>
#            (number only, can be blank)
#           </div>
#          </div>
#         </div>
#         <p align="center">
#          <input class="bigsubmit" onclick="sendForm();return false;" type="submit" value="Submit"/>
#         </p>
#        </div>
#       </div>
#      </form>
#      <script>
#       rankOfChanged = 1;
# loadItemsToRank("population-density",-1);
# switchScope('1');
# highlightScope1='kansas-state';
# highlightScope2='';
# changeScope(1,'');
#      </script>
#      <br/>
#      <div id="hotranking">
#       Popular Rankings
#      </div>
#      <div class="hotranks">
#       <div>
#        <a href="/rank/california-state--population-growth-rate--city-rank.htm?tag=Fastest+Growing+Cities+in+CA">
#         Fastest
#        </a>
#        /
#        <a href="/rank/california-state--population-growth-rate--city-rank.htm?sb=ASC&amp;tag=Slowest+Growing+Cities+in+CA">
#         Slowest
#        </a>
#        Growing Cities in CA
#       </div>
#       <div>
#        <a href="/rank/us--population-growth-rate--state-rank.htm?tag=Fastest+Growing+States+in+U.S.">
#         Fastest
#        </a>
#        /
#        <a href="/rank/us--population-growth-rate--state-rank.htm?sb=ASC&amp;tag=Slowest+Growing+States+in+U.S.">
#         Slowest
#        </a>
#        Growing States in U.S.
#       </div>
#       <div>
#        <a href="/rank/california-state--employed-male-civilian-population-percentage--city-rank.htm?yr=3000&amp;tag=Best+Cities+in+CA+by+%+of+Males+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/california-state--employed-male-civilian-population-percentage--city-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Worst+Cities+in+CA+by+%+of+Males+Employed">
#         Worst
#        </a>
#        Cities in CA by % of Males Employed
#       </div>
#       <div>
#        <a href="/rank/us--employed-male-civilian-population-percentage--state-rank.htm?yr=3000&amp;tag=Best+States+in+U.S.+by+%+of+Males+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/us--employed-male-civilian-population-percentage--state-rank.htm?yr=3000&amp;sb=ASC&amp;Worst+States+in+U.S.+by+%+of+Males+Employed">
#         Worst
#        </a>
#        States in U.S. by % of Males Employed
#       </div>
#       <div>
#        <a href="/rank/california-state--employed-female-civilian-population-percentage--city-rank.htm?yr=3000&amp;tag=Best+Cities+in+CA+by+%+of+Females+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/california-state--employed-female-civilian-population-percentage--city-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Worst+Cities+in+CA+by+%+of+Females+Employed">
#         Worst
#        </a>
#        Cities in CA by % of Females Employed
#       </div>
#       <div>
#        <a href="/rank/us--employed-female-civilian-population-percentage--state-rank.htm?yr=3000&amp;tag=Best+States+in+U.S.+by+%+of+Females+Employed">
#         Best
#        </a>
#        /
#        <a href="/rank/us--employed-female-civilian-population-percentage--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Best+States+in+U.S.+by+%+of+Females+Employed">
#         Worst
#        </a>
#        States in U.S. by % of Females Employed
#       </div>
#       <div>
#        <a href="/rank/california-state--crime-index--city-rank.htm?tag=Best+Cities+by+Crime+Rate+in+CA">
#         Best
#        </a>
#        /
#        <a href="/rank/california-state--crime-index--city-rank.htm?sb=DESC&amp;tag=Worst+Cities+by+Crime+Rate+in+CA">
#         Worst
#        </a>
#        Cities by Crime Rate in CA
#       </div>
#       <div>
#        <a href="/rank/us--crime-index--state-rank.htm?tag=Best+States+by+Crime+Rate+in+U.S.">
#         Best
#        </a>
#        /
#        <a href="/rank/us--crime-index--state-rank.htm?sb=DESC&amp;tag=Worst+States+by+Crime+Rate+in+U.S.">
#         Worst
#        </a>
#        States by Crime Rate in U.S.
#       </div>
#       <div>
#        <a href="/rank/california-state--median-household-income--city-rank.htm?yr=3000&amp;tag=Richest+Cities+by+Income+in+CA">
#         Richest
#        </a>
#        /
#        <a href="/rank/california-state--median-household-income--city-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Poorest+Cities+by+Income+in+CA">
#         Poorest
#        </a>
#        Cities by Income in CA
#       </div>
#       <div>
#        <a href="/rank/us--median-household-income--state-rank.htm?yr=3000&amp;tag=Richest+States+by+Income+in+U.S.">
#         Richest
#        </a>
#        /
#        <a href="/rank/us--median-household-income--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Poorest+States+by+Income+in+U.S.">
#         Poorest
#        </a>
#        States by Income in U.S.
#       </div>
#       <div>
#        <a href="/rank/california-state--house-median-value--city-rank.htm?yr=3000&amp;tag=Most+Expensive+Homes+by+City+in+CA">
#         Most Expensive
#        </a>
#        /
#        <a href="/rank/california-state--house-median-value--city-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Cheapest+Homes+by+City+in+CA">
#         Cheapest
#        </a>
#        Homes by City in CA
#       </div>
#       <div>
#        <a href="/rank/us--house-median-value--state-rank.htm?yr=3000&amp;tag=Most+Expensive+Homes+by+State+in+U.S.">
#         Most Expensive
#        </a>
#        /
#        <a href="/rank/us--house-median-value--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Cheapest+Homes+by+State+in+U.S.">
#         Cheapest
#        </a>
#        Homes by State in U.S.
#       </div>
#       <div>
#        <a href="/rank/california-state--average-education-index--city-rank.htm?yr=3000&amp;tag=Most+Educated+Cities+in+CA">
#         Most
#        </a>
#        /
#        <a href="/rank/california-state--average-education-index--city-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Least+Educated+Cities+in+CA">
#         Least
#        </a>
#        Educated Cities in CA
#       </div>
#       <div>
#        <a href="/rank/us--average-education-index--state-rank.htm?yr=3000&amp;tag=Most+Educated+States+in+U.S.">
#         Most
#        </a>
#        /
#        <a href="/rank/us--average-education-index--state-rank.htm?yr=3000&amp;sb=ASC&amp;tag=Least+Educated+States+in+U.S.">
#         Least
#        </a>
#        Educated States in U.S.
#       </div>
#      </div>
#     </div>
#     <div id="clear">
#     </div>
#    </div>
#   </div>
#   <div id="fo">
#    <div id="ftop">
#    </div>
#    <div id="f">
#     <div class="fleft">
#      The
#      <a href="http://www.usa.com">
#       USA.com
#      </a>
#      website and domain are privately owned and are not operated by or affiliated with any government or municipal authority.
#      <br/>
#      © 2020 World Media Group, LLC.
#      <!--(0.0049409866333008)-->
#     </div>
#     <div class="fmenu">
#      <a href="/about-us.php">
#       about us
#      </a>
#      |
#      <a href="/contact-us.php">
#       contact us
#      </a>
#      |
#      <a href="/scam-warning.php">
#       usa.com alerts
#      </a>
#      |
#      <a href="/terms-of-use.php">
#       terms of use
#      </a>
#      |
#      <a href="/privacy-policy.php">
#       privacy policy
#      </a>
#     </div>
#     <div id="clear">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-12906387-4']);
# _gaq.push(['_setDomainName', 'www.usa.com']);
# _gaq.push(['_trackPageview']);
# (function() {
# 	var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# })();
#   </script>
#  </body>
# </html>

# %%
table = soup.find_all('table')[1]
table
# Out:
# <table width="648"><tr valign="bottom"><td width="48"><b>Rank</b></td><td width="150"><b><a href="#" onclick="rsf('sb','ASC');">Population Density ▼</a></b></td><td width="450"><b>County / Population</b></td></tr><tr><td>1.</td><td>1,167.0/sq mi</td><td><a href="r.php?i=30-ks-johnson">Johnson, KS</a> / 560,025</td></tr>
# <tr><td>2.</td><td>1,021.0/sq mi</td><td><a href="r.php?i=30-ks-wyandotte">Wyandotte, KS</a> / 159,466</td></tr>
# <tr><td>3.</td><td>499.2/sq mi</td><td><a href="r.php?i=30-ks-sedgwick">Sedgwick, KS</a> / 503,788</td></tr>
# <tr><td>4.</td><td>321.4/sq mi</td><td><a href="r.php?i=30-ks-shawnee">Shawnee, KS</a> / 178,600</td></tr>
# <tr><td>5.</td><td>239.6/sq mi</td><td><a href="r.php?i=30-ks-douglas">Douglas, KS</a> / 113,703</td></tr>
# <tr><td>6.</td><td>165.7/sq mi</td><td><a href="r.php?i=30-ks-leavenworth">Leavenworth, KS</a> / 77,687</td></tr>
# <tr><td>7.</td><td>119.7/sq mi</td><td><a href="r.php?i=30-ks-riley">Riley, KS</a> / 74,478</td></tr>
# <tr><td>8.</td><td>90.1/sq mi</td><td><a href="r.php?i=30-ks-geary">Geary, KS</a> / 36,458</td></tr>
# <tr><td>9.</td><td>77.3/sq mi</td><td><a href="r.php?i=30-ks-saline">Saline, KS</a> / 55,793</td></tr>
# <tr><td>10.</td><td>66.0/sq mi</td><td><a href="r.php?i=30-ks-crawford">Crawford, KS</a> / 39,277</td></tr>
# <tr><td>11.</td><td>64.4/sq mi</td><td><a href="r.php?i=30-ks-harvey">Harvey, KS</a> / 34,797</td></tr>
# <tr><td>12.</td><td>55.5/sq mi</td><td><a href="r.php?i=30-ks-miami">Miami, KS</a> / 32,765</td></tr>
# <tr><td>13.</td><td>53.1/sq mi</td><td><a href="r.php?i=30-ks-montgomery">Montgomery, KS</a> / 34,602</td></tr>
# <tr><td>14.</td><td>50.5/sq mi</td><td><a href="r.php?i=30-ks-reno">Reno, KS</a> / 64,223</td></tr>
# <tr><td>15.</td><td>45.6/sq mi</td><td><a href="r.php?i=30-ks-butler">Butler, KS</a> / 65,927</td></tr>
# <tr><td>16.</td><td>44.8/sq mi</td><td><a href="r.php?i=30-ks-franklin">Franklin, KS</a> / 25,834</td></tr>
# <tr><td>17.</td><td>39.2/sq mi</td><td><a href="r.php?i=30-ks-lyon">Lyon, KS</a> / 33,510</td></tr>
# <tr><td>18.</td><td>38.6/sq mi</td><td><a href="r.php?i=30-ks-atchison">Atchison, KS</a> / 16,737</td></tr>
# <tr><td>19.</td><td>36.4/sq mi</td><td><a href="r.php?i=30-ks-seward">Seward, KS</a> / 23,319</td></tr>
# <tr><td>20.</td><td>35.8/sq mi</td><td><a href="r.php?i=30-ks-cherokee">Cherokee, KS</a> / 21,179</td></tr>
# <tr><td>21.</td><td>34.0/sq mi</td><td><a href="r.php?i=30-ks-jefferson">Jefferson, KS</a> / 18,932</td></tr>
# <tr><td>22.</td><td>32.5/sq mi</td><td><a href="r.php?i=30-ks-mcpherson">Mcpherson, KS</a> / 29,308</td></tr>
# <tr><td>23.</td><td>32.5/sq mi</td><td><a href="r.php?i=30-ks-labette">Labette, KS</a> / 21,225</td></tr>
# <tr><td>24.</td><td>32.1/sq mi</td><td><a href="r.php?i=30-ks-ellis">Ellis, KS</a> / 28,878</td></tr>
# <tr><td>25.</td><td>32.0/sq mi</td><td><a href="r.php?i=30-ks-cowley">Cowley, KS</a> / 36,201</td></tr>
# <tr><td>26.</td><td>31.5/sq mi</td><td><a href="r.php?i=30-ks-ford">Ford, KS</a> / 34,604</td></tr>
# <tr><td>27.</td><td>30.6/sq mi</td><td><a href="r.php?i=30-ks-barton">Barton, KS</a> / 27,566</td></tr>
# <tr><td>28.</td><td>28.5/sq mi</td><td><a href="r.php?i=30-ks-finney">Finney, KS</a> / 37,099</td></tr>
# <tr><td>29.</td><td>28.5/sq mi</td><td><a href="r.php?i=30-ks-neosho">Neosho, KS</a> / 16,453</td></tr>
# <tr><td>30.</td><td>26.1/sq mi</td><td><a href="r.php?i=30-ks-allen">Allen, KS</a> / 13,212</td></tr>
# <tr><td>31.</td><td>25.9/sq mi</td><td><a href="r.php?i=30-ks-pottawatomie">Pottawatomie, KS</a> / 22,338</td></tr>
# <tr><td>32.</td><td>23.3/sq mi</td><td><a href="r.php?i=30-ks-bourbon">Bourbon, KS</a> / 14,913</td></tr>
# <tr><td>33.</td><td>23.1/sq mi</td><td><a href="r.php?i=30-ks-dickinson">Dickinson, KS</a> / 19,641</td></tr>
# <tr><td>34.</td><td>22.5/sq mi</td><td><a href="r.php?i=30-ks-osage">Osage, KS</a> / 16,165</td></tr>
# <tr><td>35.</td><td>20.5/sq mi</td><td><a href="r.php?i=30-ks-jackson">Jackson, KS</a> / 13,464</td></tr>
# <tr><td>36.</td><td>20.1/sq mi</td><td><a href="r.php?i=30-ks-sumner">Sumner, KS</a> / 23,763</td></tr>
# <tr><td>37.</td><td>19.8/sq mi</td><td><a href="r.php?i=30-ks-doniphan">Doniphan, KS</a> / 7,904</td></tr>
# <tr><td>38.</td><td>17.3/sq mi</td><td><a href="r.php?i=30-ks-brown">Brown, KS</a> / 9,926</td></tr>
# <tr><td>39.</td><td>16.0/sq mi</td><td><a href="r.php?i=30-ks-wilson">Wilson, KS</a> / 9,177</td></tr>
# <tr><td>40.</td><td>15.8/sq mi</td><td><a href="r.php?i=30-ks-linn">Linn, KS</a> / 9,551</td></tr>
# <tr><td>41.</td><td>14.1/sq mi</td><td><a href="r.php?i=30-ks-nemaha">Nemaha, KS</a> / 10,136</td></tr>
# <tr><td>42.</td><td>13.8/sq mi</td><td><a href="r.php?i=30-ks-rice">Rice, KS</a> / 10,050</td></tr>
# <tr><td>43.</td><td>13.7/sq mi</td><td><a href="r.php?i=30-ks-grant">Grant, KS</a> / 7,856</td></tr>
# <tr><td>44.</td><td>13.6/sq mi</td><td><a href="r.php?i=30-ks-anderson">Anderson, KS</a> / 7,962</td></tr>
# <tr><td>45.</td><td>13.3/sq mi</td><td><a href="r.php?i=30-ks-pratt">Pratt, KS</a> / 9,758</td></tr>
# <tr><td>46.</td><td>13.1/sq mi</td><td><a href="r.php?i=30-ks-cloud">Cloud, KS</a> / 9,414</td></tr>
# <tr><td>47.</td><td>13.0/sq mi</td><td><a href="r.php?i=30-ks-marion">Marion, KS</a> / 12,401</td></tr>
# <tr><td>48.</td><td>13.0/sq mi</td><td><a href="r.php?i=30-ks-coffey">Coffey, KS</a> / 8,493</td></tr>
# <tr><td>49.</td><td>12.9/sq mi</td><td><a href="r.php?i=30-ks-clay">Clay, KS</a> / 8,460</td></tr>
# <tr><td>50.</td><td>11.1/sq mi</td><td><a href="r.php?i=30-ks-marshall">Marshall, KS</a> / 10,042</td></tr>
# <tr><td>51.</td><td>9.2/sq mi</td><td><a href="r.php?i=30-ks-pawnee">Pawnee, KS</a> / 6,959</td></tr>
# <tr><td>52.</td><td>9.0/sq mi</td><td><a href="r.php?i=30-ks-kingman">Kingman, KS</a> / 7,820</td></tr>
# <tr><td>53.</td><td>8.9/sq mi</td><td><a href="r.php?i=30-ks-ellsworth">Ellsworth, KS</a> / 6,443</td></tr>
# <tr><td>54.</td><td>8.8/sq mi</td><td><a href="r.php?i=30-ks-wabaunsee">Wabaunsee, KS</a> / 7,034</td></tr>
# <tr><td>55.</td><td>8.8/sq mi</td><td><a href="r.php?i=30-ks-mitchell">Mitchell, KS</a> / 6,324</td></tr>
# <tr><td>56.</td><td>8.4/sq mi</td><td><a href="r.php?i=30-ks-ottawa">Ottawa, KS</a> / 6,075</td></tr>
# <tr><td>57.</td><td>8.3/sq mi</td><td><a href="r.php?i=30-ks-morris">Morris, KS</a> / 5,808</td></tr>
# <tr><td>58.</td><td>7.9/sq mi</td><td><a href="r.php?i=30-ks-stevens">Stevens, KS</a> / 5,744</td></tr>
# <tr><td>59.</td><td>7.7/sq mi</td><td><a href="r.php?i=30-ks-russell">Russell, KS</a> / 6,959</td></tr>
# <tr><td>60.</td><td>7.4/sq mi</td><td><a href="r.php?i=30-ks-thomas">Thomas, KS</a> / 7,947</td></tr>
# <tr><td>61.</td><td>7.4/sq mi</td><td><a href="r.php?i=30-ks-harper">Harper, KS</a> / 5,906</td></tr>
# <tr><td>62.</td><td>7.3/sq mi</td><td><a href="r.php?i=30-ks-haskell">Haskell, KS</a> / 4,198</td></tr>
# <tr><td>63.</td><td>7.0/sq mi</td><td><a href="r.php?i=30-ks-gray">Gray, KS</a> / 6,043</td></tr>
# <tr><td>64.</td><td>6.9/sq mi</td><td><a href="r.php?i=30-ks-scott">Scott, KS</a> / 4,965</td></tr>
# <tr><td>65.</td><td>6.8/sq mi</td><td><a href="r.php?i=30-ks-republic">Republic, KS</a> / 4,868</td></tr>
# <tr><td>66.</td><td>6.4/sq mi</td><td><a href="r.php?i=30-ks-woodson">Woodson, KS</a> / 3,246</td></tr>
# <tr><td>67.</td><td>6.4/sq mi</td><td><a href="r.php?i=30-ks-norton">Norton, KS</a> / 5,628</td></tr>
# <tr><td>68.</td><td>6.4/sq mi</td><td><a href="r.php?i=30-ks-washington">Washington, KS</a> / 5,717</td></tr>
# <tr><td>69.</td><td>6.2/sq mi</td><td><a href="r.php?i=30-ks-phillips">Phillips, KS</a> / 5,560</td></tr>
# <tr><td>70.</td><td>5.8/sq mi</td><td><a href="r.php?i=30-ks-rooks">Rooks, KS</a> / 5,174</td></tr>
# <tr><td>71.</td><td>5.8/sq mi</td><td><a href="r.php?i=30-ks-sherman">Sherman, KS</a> / 6,078</td></tr>
# <tr><td>72.</td><td>5.6/sq mi</td><td><a href="r.php?i=30-ks-greenwood">Greenwood, KS</a> / 6,495</td></tr>
# <tr><td>73.</td><td>5.5/sq mi</td><td><a href="r.php?i=30-ks-chautauqua">Chautauqua, KS</a> / 3,572</td></tr>
# <tr><td>74.</td><td>5.5/sq mi</td><td><a href="r.php?i=30-ks-stafford">Stafford, KS</a> / 4,363</td></tr>
# <tr><td>75.</td><td>4.8/sq mi</td><td><a href="r.php?i=30-ks-edwards">Edwards, KS</a> / 3,006</td></tr>
# <tr><td>76.</td><td>4.5/sq mi</td><td><a href="r.php?i=30-ks-meade">Meade, KS</a> / 4,444</td></tr>
# <tr><td>77.</td><td>4.5/sq mi</td><td><a href="r.php?i=30-ks-kearny">Kearny, KS</a> / 3,950</td></tr>
# <tr><td>78.</td><td>4.5/sq mi</td><td><a href="r.php?i=30-ks-rush">Rush, KS</a> / 3,222</td></tr>
# <tr><td>79.</td><td>4.4/sq mi</td><td><a href="r.php?i=30-ks-lincoln">Lincoln, KS</a> / 3,180</td></tr>
# <tr><td>80.</td><td>4.3/sq mi</td><td><a href="r.php?i=30-ks-morton">Morton, KS</a> / 3,159</td></tr>
# <tr><td>81.</td><td>4.3/sq mi</td><td><a href="r.php?i=30-ks-barber">Barber, KS</a> / 4,898</td></tr>
# <tr><td>82.</td><td>4.3/sq mi</td><td><a href="r.php?i=30-ks-osborne">Osborne, KS</a> / 3,811</td></tr>
# <tr><td>83.</td><td>4.2/sq mi</td><td><a href="r.php?i=30-ks-smith">Smith, KS</a> / 3,779</td></tr>
# <tr><td>84.</td><td>4.2/sq mi</td><td><a href="r.php?i=30-ks-elk">Elk, KS</a> / 2,734</td></tr>
# <tr><td>85.</td><td>3.5/sq mi</td><td><a href="r.php?i=30-ks-chase">Chase, KS</a> / 2,746</td></tr>
# <tr><td>86.</td><td>3.5/sq mi</td><td><a href="r.php?i=30-ks-kiowa">Kiowa, KS</a> / 2,529</td></tr>
# <tr><td>87.</td><td>3.3/sq mi</td><td><a href="r.php?i=30-ks-jewell">Jewell, KS</a> / 3,060</td></tr>
# <tr><td>88.</td><td>3.3/sq mi</td><td><a href="r.php?i=30-ks-trego">Trego, KS</a> / 2,959</td></tr>
# <tr><td>89.</td><td>3.3/sq mi</td><td><a href="r.php?i=30-ks-decatur">Decatur, KS</a> / 2,915</td></tr>
# <tr><td>90.</td><td>3.2/sq mi</td><td><a href="r.php?i=30-ks-stanton">Stanton, KS</a> / 2,187</td></tr>
# <tr><td>91.</td><td>3.1/sq mi</td><td><a href="r.php?i=30-ks-wichita">Wichita, KS</a> / 2,220</td></tr>
# <tr><td>92.</td><td>2.9/sq mi</td><td><a href="r.php?i=30-ks-graham">Graham, KS</a> / 2,602</td></tr>
# <tr><td>93.</td><td>2.9/sq mi</td><td><a href="r.php?i=30-ks-ness">Ness, KS</a> / 3,104</td></tr>
# <tr><td>94.</td><td>2.8/sq mi</td><td><a href="r.php?i=30-ks-sheridan">Sheridan, KS</a> / 2,540</td></tr>
# <tr><td>95.</td><td>2.6/sq mi</td><td><a href="r.php?i=30-ks-cheyenne">Cheyenne, KS</a> / 2,695</td></tr>
# <tr><td>96.</td><td>2.6/sq mi</td><td><a href="r.php?i=30-ks-hamilton">Hamilton, KS</a> / 2,632</td></tr>
# <tr><td>97.</td><td>2.6/sq mi</td><td><a href="r.php?i=30-ks-gove">Gove, KS</a> / 2,786</td></tr>
# <tr><td>98.</td><td>2.6/sq mi</td><td><a href="r.php?i=30-ks-logan">Logan, KS</a> / 2,783</td></tr>
# <tr><td>99.</td><td>2.4/sq mi</td><td><a href="r.php?i=30-ks-comanche">Comanche, KS</a> / 1,911</td></tr>
# <tr><td>100.</td><td>2.4/sq mi</td><td><a href="r.php?i=30-ks-rawlins">Rawlins, KS</a> / 2,553</td></tr>
# <tr><td>101.</td><td>2.3/sq mi</td><td><a href="r.php?i=30-ks-lane">Lane, KS</a> / 1,652</td></tr>
# <tr><td>102.</td><td>2.3/sq mi</td><td><a href="r.php?i=30-ks-hodgeman">Hodgeman, KS</a> / 1,941</td></tr>
# <tr><td>103.</td><td>2.2/sq mi</td><td><a href="r.php?i=30-ks-clark">Clark, KS</a> / 2,170</td></tr>
# <tr><td>104.</td><td>1.7/sq mi</td><td><a href="r.php?i=30-ks-wallace">Wallace, KS</a> / 1,569</td></tr>
# <tr><td>105.</td><td>1.6/sq mi</td><td><a href="r.php?i=30-ks-greeley">Greeley, KS</a> / 1,223</td></tr>
# </table>

# %%
output_rows = []
for table_row in table.findAll('tr'):
    columns = table_row.findAll('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    output_rows.append(output_row)
    
with open('DensityKan.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(output_rows)
