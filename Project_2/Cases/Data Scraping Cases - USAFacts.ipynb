# %%
from bs4 import BeautifulSoup
import requests
from IPython.core.display import display, HTML
import csv

# %%
url = 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/'

response = requests.get(url)

response.status_code

page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
script_soup = [row for row in soup.find_all('script')]
cases_dict = script_soup[8]

# %%
county_stats = script_soup[8].contents[0]
county_stats.find(':"49"')
# Out:
# 443335

# %%
county_stats = county_stats[403106:443188]
county_stats
# Out:
# '{"stateFips":"48","countyFips":"001","statePopulation":28995881,"countyPopulation":57735,"confirmed":2821,"confirmedPopulation":4886.117606304668,"deaths":36},{"stateFips":"48","countyFips":"003","statePopulation":28995881,"countyPopulation":18705,"confirmed":457,"confirmedPopulation":2443.197006148089,"deaths":10},{"stateFips":"48","countyFips":"005","statePopulation":28995881,"countyPopulation":86715,"confirmed":2189,"confirmedPopulation":2524.3614138269045,"deaths":83},{"stateFips":"48","countyFips":"007","statePopulation":28995881,"countyPopulation":23510,"confirmed":335,"confirmedPopulation":1424.9255635899617,"deaths":18},{"stateFips":"48","countyFips":"009","statePopulation":28995881,"countyPopulation":8553,"confirmed":88,"confirmedPopulation":1028.8787559920497,"deaths":1},{"stateFips":"48","countyFips":"011","statePopulation":28995881,"countyPopulation":1887,"confirmed":13,"confirmedPopulation":688.924218335983,"deaths":1},{"stateFips":"48","countyFips":"013","statePopulation":28995881,"countyPopulation":51153,"confirmed":1166,"confirmedPopulation":2279.4362012003203,"deaths":32},{"stateFips":"48","countyFips":"015","statePopulation":28995881,"countyPopulation":30032,"confirmed":502,"confirmedPopulation":1671.550346297283,"deaths":9},{"stateFips":"48","countyFips":"017","statePopulation":28995881,"countyPopulation":7000,"confirmed":228,"confirmedPopulation":3257.142857142857,"deaths":5},{"stateFips":"48","countyFips":"019","statePopulation":28995881,"countyPopulation":23112,"confirmed":160,"confirmedPopulation":692.2810661128418,"deaths":8},{"stateFips":"48","countyFips":"021","statePopulation":28995881,"countyPopulation":88723,"confirmed":1865,"confirmedPopulation":2102.0479469810534,"deaths":30},{"stateFips":"48","countyFips":"023","statePopulation":28995881,"countyPopulation":3509,"confirmed":20,"confirmedPopulation":569.9629524080934,"deaths":1},{"stateFips":"48","countyFips":"025","statePopulation":28995881,"countyPopulation":32565,"confirmed":1838,"confirmedPopulation":5644.096422539536,"deaths":36},{"stateFips":"48","countyFips":"027","statePopulation":28995881,"countyPopulation":362924,"confirmed":5623,"confirmedPopulation":1549.3601966251888,"deaths":89},{"stateFips":"48","countyFips":"029","statePopulation":28995881,"countyPopulation":2003554,"confirmed":58678,"confirmedPopulation":2928.6957077273682,"deaths":1332},{"stateFips":"48","countyFips":"031","statePopulation":28995881,"countyPopulation":11931,"confirmed":145,"confirmedPopulation":1215.321431564831,"deaths":5},{"stateFips":"48","countyFips":"033","statePopulation":28995881,"countyPopulation":654,"confirmed":1,"confirmedPopulation":152.90519877675843,"deaths":0},{"stateFips":"48","countyFips":"035","statePopulation":28995881,"countyPopulation":18685,"confirmed":351,"confirmedPopulation":1878.5121755418786,"deaths":6},{"stateFips":"48","countyFips":"037","statePopulation":28995881,"countyPopulation":93245,"confirmed":1439,"confirmedPopulation":1543.2462866641642,"deaths":55},{"stateFips":"48","countyFips":"039","statePopulation":28995881,"countyPopulation":374264,"confirmed":11575,"confirmedPopulation":3092.7366778530663,"deaths":171},{"stateFips":"48","countyFips":"041","statePopulation":28995881,"countyPopulation":229211,"confirmed":6622,"confirmedPopulation":2889.0411018668387,"deaths":64},{"stateFips":"48","countyFips":"043","statePopulation":28995881,"countyPopulation":9203,"confirmed":220,"confirmedPopulation":2390.5248288601542,"deaths":4},{"stateFips":"48","countyFips":"045","statePopulation":28995881,"countyPopulation":1546,"confirmed":15,"confirmedPopulation":970.2457956015525,"deaths":1},{"stateFips":"48","countyFips":"047","statePopulation":28995881,"countyPopulation":7093,"confirmed":325,"confirmedPopulation":4581.98223600733,"deaths":22},{"stateFips":"48","countyFips":"049","statePopulation":28995881,"countyPopulation":37864,"confirmed":592,"confirmedPopulation":1563.4903866469472,"deaths":25},{"stateFips":"48","countyFips":"051","state ...

# %%
county_stats = county_stats.replace("}", "")
county_stats = county_stats.replace("{", "")
county_list = []
county_list = county_stats.split(',')

csv_table = []
for i in range(254):
    csv_nested = []
    csv_nested = county_list[i*7:i*7+7]
    csv_table.append(csv_nested)

with open('CaseTEX.csv', 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerows(csv_table)
